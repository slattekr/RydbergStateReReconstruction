# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import tensorflow as tf

# %% [markdown]
# # Train 1-D RNN with VMC

# %%
from train_VMC import Train_w_VMC

energy = []
variance = []
cost = []

def main():
    config = {
        'name': 'test', # A very random name for each experiment
        'Lx': 4,  # number of sites in x-direction                    
        'Ly': 4,  # number of sites in the y-direction
        'V': 7,
        'Omega': 1,
        'delta': 1,
        
        'nh': 32,  # number of memory/hidden units
        'lr': 1e-3,  # learning rate
        'weight_sharing': True,
        'trunc': 100,
        'seed': 1234,
        
        'RNN': 'OneD',
        'VMC_epochs':500,
        'Data_epochs':0,
        
        'ns': 1000,
        'batch_size': 100,
        'data_step': 100,
        
        'Print':True,
        'Write_Data': False,
        'Plot': True
        }
    
    return Train_w_VMC(config,energy,variance,cost)


if __name__ == "__main__":
    model,e,v,c = main()
# Out:
# Training a one-D RNN wave function with 32 hidden units and shared weights.
# 2022-11-04 11:31:36.321414: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# gru/gru_cell/kernel:0 (192,)
# gru/gru_cell/recurrent_kernel:0 (3072,)
# gru/gru_cell/bias:0 (192,)
# dense/kernel:0 (64,)
# dense/bias:0 (2,)
# The sum of params is 3522
# The experimental parameters are: V = 7, delta = 1, Omega = 1.
# The system is an array of 4 by 4 Rydberg Atoms.
# Step #1
# Energy = 1.2656675577163696
# Variance = 25.565061569213867
#
# Step #2
# Energy = 1.218800663948059
# Variance = 24.996923446655273
#
# Step #3
# Energy = 1.086065411567688
# Variance = 22.251766204833984
#
# Step #4
# Energy = 1.0323177576065063
# ...

# %% [markdown]
# # Train 1-D RNN with Data

# %%
from train_data import Train_w_Data

energy = []
variance = []
cost = []

def main():
    config = {
        'name': 'test', # A very random name for each experiment
        'Lx': 4,  # number of sites in x-direction                    
        'Ly': 4,  # number of sites in the y-direction
        'V': 7,
        'Omega': 1,
        'delta': 1,
        
        'nh': 32,  # number of memory/hidden units
        'lr': 1e-3,  # learning rate
        'weight_sharing': True,
        'trunc': 100,
        'seed': 1234,
        
        'RNN': 'OneD',
        'VMC_epochs':0,
        'Data_epochs':500,
        
        'ns': 1000,
        'batch_size': 100,
        'data_step': 100,
        
        'Print':True,
        'Write_Data': False,
        'Plot': True
        }
    
    return Train_w_Data(config,energy,variance,cost)


if __name__ == "__main__":
    model,e,v,c = main()

# %% [markdown]
# # Train 1-D RNN with Data then VMC

# %%
from train_hybrid import run_DataPlusVMC

energy = []
variance = []

def main():
    config = {
        'name': 'test', # A very random name for each experiment
        'Lx': 4,  # number of sites in x-direction                    
        'Ly': 4,  # number of sites in the y-direction
        'V': 7,
        'Omega': 1,
        'delta': 1,
        
        'nh': 32,  # number of memory/hidden units
        'lr': 1e-3,  # learning rate
        'weight_sharing': True,
        'trunc': 100,
        'seed': 1234,
        
        'RNN': 'OneD',
        'VMC_epochs':200,
        'Data_epochs':300,
        
        'ns': 1000,
        'batch_size': 100,
        'data_step': 100,
        
        'Print':True,
        'Write_Data': False,
        'Plot': True
        }
    
    return run_DataPlusVMC(config,energy,variance)


if __name__ == "__main__":
    model,e,v = main()
