# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import tensorflow as tf

# %%
from train_data import Train_w_Data

# %%
import sys
sys.path.append('..')
from train_VMC import Train_w_VMC
from dset_helpers import load_exact_Es
from plots import plot_E, plot_var, plot_loss

# %%
exact_E = load_exact_Es(4)

# %% [markdown]
# # VMC Training

# %% [markdown]
# Here it doesn't seem like there is anything particularly wrong with the new OneD RNN

# %% [markdown]
# One thing to notice is how much smoother the convergence is for the old OneD RNN... it has noticeably better results too.

# %% [markdown]
# ### Old OneD RNN

# %%
def main():
    config = {
        'name': 'Benchmark_VMC_OneD_oldRNN', # A name for each experiment
        'Lx': 4,  # number of sites in x-direction                    
        'Ly': 4,  # number of sites in the y-direction
        'V': 7.,
        'Omega': 1.,
        'delta': 1.,
        'sweep_rate':15,
        
        'nh': 32,  # number of memory/hidden units
        'lr': 1e-3,  # learning rate
        'weight_sharing': True,
        'trunc': 100,
        'seed': 1234,
        
        'RNN': 'OneD',
        'version':'Old',
        'MDGRU': True,
        'VMC_epochs':1000,
        'Data_epochs':0,
        
        'ns': 1000,
        'batch_size': 100,
        
        'Print':True,
        'Write_Data': True,
        'CKPT':False,
        'Plot': True
        }
    
    return Train_w_VMC(config)


if __name__ == "__main__":
    model_old,e_old,v_old,c_old = main()
# Out:
# Training a one-D RNN wave function with 32 hidden units and shared weights.
# OneD RNN used in previous Rydberg project.
# gru_3/gru_cell_3/kernel:0 (192,)
# gru_3/gru_cell_3/recurrent_kernel:0 (3072,)
# gru_3/gru_cell_3/bias:0 (192,)
# dense_1/kernel:0 (64,)
# dense_1/bias:0 (2,)
# The sum of params is 3522
# The experimental parameters are: V = 7.0, delta = 1.0, Omega = 1.0.
# The system is an array of 4 by 4 Rydberg Atoms.
# getting energy function!
# CKPT OFF. Initializing from scratch.
# Tracing!
# Tracing!
# Step #50
# Energy = -0.22474130988121033
# Variance = 1.104772925376892
#
# Saved training quantitites for step 50 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #100
# Energy = -0.2777749001979828
# Variance = 0.8381213545799255
#
# Saved training quantitites for step 100 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #150
# Energy = -0.2831549644470215
# Variance = 0.7345073223114014
#
# Saved training quantitites for step 150 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #200
# Energy = -0.30625244975090027
# Variance = 0.5755668878555298
#
# Saved training quantitites for step 200 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #250
# Energy = -0.33001792430877686
# Variance = 0.420626163482666
#
# Saved training quantitites for step 250 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #300
# Energy = -0.3357964754104614
# Variance = 0.4078245759010315
#
# Saved training quantitites for step 300 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #350
# Energy = -0.33947351574897766
# Variance = 0.34853315353393555
#
# Saved training quantitites for step 350 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #400
# Energy = -0.3638165295124054
# Variance = 0.2976810336112976
#
# Saved training quantitites for step 400 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #450
# Energy = -0.3784137964248657
# Variance = 0.20788875222206116
#
# Saved training quantitites for step 450 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #500
# Energy = -0.3872739374637604
# Variance = 0.16480761766433716
#
# Saved training quantitites for step 500 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #550
# Energy = -0.4009783864021301
# Variance = 0.12295776605606079
#
# Saved training quantitites for step 550 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #600
# Energy = -0.4137606918811798
# Variance = 0.08335410058498383
#
# Saved training quantitites for step 600 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #650
# Energy = -0.4192943871021271
# Variance = 0.05627358332276344
#
# Saved training quantitites for step 650 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #700
# Energy = -0.42026758193969727
# Variance = 0.054833777248859406
#
# Saved training quantitites for step 700 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #750
# Energy = -0.4212586581707001
# Variance = 0.04965265840291977
#
# Saved training quantitites for step 750 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #800
# Energy = -0.42266416549682617
# Variance = 0.046692587435245514
#
# Saved training quantitites for step 800 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #850
# Energy = -0.4250979423522949
# Variance = 0.07287868857383728
#
# Saved training quantitites for step 850 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #900
# Energy = -0.42545226216316223
# Variance = 0.07133309543132782
#
# Saved training quantitites for step 900 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #950
# Energy = -0.42609313130378723
# Variance = 0.0399569608271122
#
# Saved training quantitites for step 950 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #1000
# Energy = -0.4270375669002533
# Variance = 0.06096433848142624
#
# Saved training quantitites for step 1000 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.

# %%
plot_E(e_old,exact_E,16,len(e_old))
# Out:
# Final Energy -0.4260842038525475 (Exact Energy is -0.4534132086591546)
# Final Error after 1000 epochs is 0.02732900480660705
# The lowest energy achieved by the model was -0.429092675447464.
# -0.4260842038525475

# %%
plot_var(v_old,16,len(v_old))
# Out:
# Final Variance after 1000 epochs is 0.06912094809942776
# 0.06912094809942776

# %% [markdown]
# ### New OneD RNN

# %%
def main():
    config = {
        'name': 'Benchmark_VMC_OneD_oldRNN', # A name for each experiment
        'Lx': 4,  # number of sites in x-direction                    
        'Ly': 4,  # number of sites in the y-direction
        'V': 7.,
        'Omega': 1.,
        'delta': 1.,
        'sweep_rate':15,
        
        'nh': 32,  # number of memory/hidden units
        'lr': 1e-3,  # learning rate
        'weight_sharing': True,
        'trunc': 100,
        'seed': 1234,
        
        'RNN': 'OneD',
        'version':'New',
        'MDGRU': True,
        'VMC_epochs':1000,
        'Data_epochs':0,
        
        'ns': 1000,
        'batch_size': 100,
        
        'Print':True,
        'Write_Data': True,
        'CKPT':False,
        'Plot': True
        }
    
    return Train_w_VMC(config)


if __name__ == "__main__":
    model_new,e_new,v_new,c_new = main()
# Out:
# 2022-12-13 16:18:17.506275: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Training a one-D RNN wave function with 32 hidden units and shared weights.
# OneD RNN adapted from Heisenberg-Kagome project.
# gru/gru_cell/kernel:0 (192,)
# gru/gru_cell/recurrent_kernel:0 (3072,)
# gru/gru_cell/bias:0 (192,)
# RNNWF_dense_0/kernel:0 (64,)
# RNNWF_dense_0/bias:0 (2,)
# The sum of params is 3522
# The experimental parameters are: V = 7.0, delta = 1.0, Omega = 1.0.
# The system is an array of 4 by 4 Rydberg Atoms.
# getting energy function!
# CKPT OFF. Initializing from scratch.
# Tracing!
# Tracing!
# Step #50
# Energy = -0.22474130988121033
# Variance = 1.1047730445861816
#
# Saved training quantitites for step 50 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #100
# Energy = -0.2777749001979828
# Variance = 0.8381213545799255
#
# Saved training quantitites for step 100 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #150
# Energy = -0.2831549644470215
# Variance = 0.7345073223114014
#
# Saved training quantitites for step 150 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #200
# Energy = -0.30625244975090027
# Variance = 0.5755668878555298
#
# Saved training quantitites for step 200 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #250
# Energy = -0.33001792430877686
# Variance = 0.4206261932849884
#
# Saved training quantitites for step 250 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #300
# Energy = -0.3357964754104614
# Variance = 0.4078245759010315
#
# Saved training quantitites for step 300 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #350
# Energy = -0.33947351574897766
# Variance = 0.34853315353393555
#
# Saved training quantitites for step 350 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #400
# Energy = -0.3638165295124054
# Variance = 0.29768106341362
#
# Saved training quantitites for step 400 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #450
# Energy = -0.3784137964248657
# Variance = 0.20788872241973877
#
# Saved training quantitites for step 450 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #500
# Energy = -0.3872739374637604
# Variance = 0.16480758786201477
#
# Saved training quantitites for step 500 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #550
# Energy = -0.4009783864021301
# Variance = 0.12295777350664139
#
# Saved training quantitites for step 550 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #600
# Energy = -0.4137606918811798
# Variance = 0.08335410803556442
#
# Saved training quantitites for step 600 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #650
# Energy = -0.4192943871021271
# Variance = 0.05627358332276344
#
# Saved training quantitites for step 650 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #700
# Energy = -0.42026758193969727
# Variance = 0.05483376979827881
#
# Saved training quantitites for step 700 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #750
# Energy = -0.4212586581707001
# Variance = 0.049652665853500366
#
# Saved training quantitites for step 750 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #800
# Energy = -0.42266416549682617
# Variance = 0.04669259116053581
#
# Saved training quantitites for step 800 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #850
# Energy = -0.4250979721546173
# Variance = 0.07287871092557907
#
# Saved training quantitites for step 850 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #900
# Energy = -0.42545226216316223
# Variance = 0.07133309543132782
#
# Saved training quantitites for step 900 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #950
# Energy = -0.42609313130378723
# Variance = 0.03995698690414429
#
# Saved training quantitites for step 950 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.
# Step #1000
# Energy = -0.4270375967025757
# Variance = 0.060964372009038925
#
# Saved training quantitites for step 1000 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_VMC_OneD_oldRNN.

# %%
plot_E(e_new,exact_E,16,len(e_new))
# Out:
# Final Energy -0.42608421047528583 (Exact Energy is -0.4534132086591546)
# Final Error after 1000 epochs is 0.027328998183868747
# The lowest energy achieved by the model was -0.4290926456451416.
# -0.42608421047528583

# %%
plot_var(v_new,16,len(v_new))
# Out:
# Final Variance after 1000 epochs is 0.0691209224363168
# 0.0691209224363168

# %% [markdown]
# # Data Training

# %% [markdown]
# Here, we see that something really is weird with the training of the new OneD RNN...

# %% [markdown]
# ### Old OneD RNN

# %%
def main():
    config = {
        'name': 'Benchmark_Data_OneD_old', # A name for each experiment
        'Lx': 4,  # number of sites in x-direction                    
        'Ly': 4,  # number of sites in the y-direction
        'V': 7.,
        'Omega': 1.,
        'delta': 1.,
        'sweep_rate':15,
        
        'nh': 32,  # number of memory/hidden units
        'lr': 1e-3,  # learning rate
        'weight_sharing': True,
        'trunc': 100,
        'seed': 1234,
        
        'RNN': 'OneD',
        'version':'Old',
        'MDGRU': True,
        'VMC_epochs':0,
        'Data_epochs':500,
        
        'ns': 1000,
        'batch_size': 100,
        
        'Print':True,
        'Write_Data': True,
        'CKPT':False,
        'Plot': True
        }
    
    return Train_w_Data(config)


if __name__ == "__main__":
    model_old,e_old,v_old,c_old = main()
# Out:
# Training a one-D RNN wave function with 32 hidden units and shared weights.
# OneD RNN used in previous Rydberg project.
# gru_4/gru_cell_4/kernel:0 (192,)
# gru_4/gru_cell_4/recurrent_kernel:0 (3072,)
# gru_4/gru_cell_4/bias:0 (192,)
# dense_1/kernel:0 (64,)
# dense_1/bias:0 (2,)
# The sum of params is 3522
# The experimental parameters are: V = 7.0, delta = 1.0, Omega = 1.0.
# The system is an array of 4 by 4 Rydberg Atoms
# getting energy function!
# CKPT OFF. Initializing from scratch.
# Tracing!
# Tracing!
# Step #1
# Energy = 0.5703042149543762
# Variance = 15.686445236206055
#
# Step #2
# Energy = 0.10815521329641342
# Variance = 7.038118839263916
#
# Step #3
# Energy = -0.02074720896780491
# Variance = 5.02666711807251
#
# Step #4
# Energy = -0.06224315986037254
# Variance = 4.092535495758057
#
# Step #5
# Energy = -0.0297061949968338
# Variance = 4.989920139312744
#
# Step #6
# Energy = -0.01933187246322632
# Variance = 5.05437707901001
#
# Step #7
# Energy = -0.04150921851396561
# Variance = 4.142836570739746
#
# Step #8
# Energy = -0.11473602056503296
# Variance = 3.583805799484253
#
# Step #9
# Energy = -0.10378292202949524
# Variance = 3.2860515117645264
#
# Step #10
# Energy = -0.1356358528137207
# Variance = 3.3757572174072266
#
# Saved training quantitites for step 10 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #11
# Energy = -0.11877728998661041
# Variance = 2.899604082107544
#
# Step #12
# Energy = -0.17603608965873718
# Variance = 2.435917854309082
#
# Step #13
# Energy = -0.16453437507152557
# Variance = 2.470036029815674
#
# Step #14
# Energy = -0.2118712067604065
# Variance = 2.0401077270507812
#
# Step #15
# Energy = -0.2182241529226303
# Variance = 1.7854748964309692
#
# Step #16
# Energy = -0.23392392694950104
# Variance = 1.476064682006836
#
# Step #17
# Energy = -0.2575322389602661
# Variance = 1.4401381015777588
#
# Step #18
# Energy = -0.2515616714954376
# Variance = 1.4991096258163452
#
# Step #19
# Energy = -0.25287503004074097
# Variance = 1.467796802520752
#
# Step #20
# Energy = -0.24959304928779602
# Variance = 1.4289883375167847
#
# Saved training quantitites for step 20 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #21
# Energy = -0.2582967281341553
# Variance = 1.4449214935302734
#
# Step #22
# Energy = -0.24984677135944366
# Variance = 1.5382513999938965
#
# Step #23
# Energy = -0.27583372592926025
# Variance = 1.2950102090835571
#
# Step #24
# Energy = -0.288568913936615
# Variance = 1.0913664102554321
#
# Step #25
# Energy = -0.2895847260951996
# Variance = 1.19673490524292
#
# Step #26
# Energy = -0.30263030529022217
# Variance = 1.079041838645935
#
# Step #27
# Energy = -0.32011616230010986
# Variance = 0.8747525811195374
#
# Step #28
# Energy = -0.3402537405490875
# Variance = 0.7536289095878601
#
# Step #29
# Energy = -0.34251195192337036
# Variance = 0.7512231469154358
#
# Step #30
# Energy = -0.35193198919296265
# Variance = 0.5957948565483093
#
# Saved training quantitites for step 30 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #31
# Energy = -0.36048126220703125
# Variance = 0.5903024673461914
#
# Step #32
# Energy = -0.3408450186252594
# Variance = 0.689567506313324
#
# Step #33
# Energy = -0.36546099185943604
# Variance = 0.5226982831954956
#
# Step #34
# Energy = -0.3692784905433655
# Variance = 0.5270431041717529
#
# Step #35
# Energy = -0.37262678146362305
# Variance = 0.5140505433082581
#
# Step #36
# Energy = -0.3654569685459137
# Variance = 0.5447182655334473
#
# Step #37
# Energy = -0.38248443603515625
# Variance = 0.4052281379699707
#
# Step #38
# Energy = -0.3775811195373535
# Variance = 0.5149537324905396
#
# Step #39
# Energy = -0.3671038746833801
# Variance = 0.5462416410446167
#
# Step #40
# Energy = -0.3708004057407379
# Variance = 0.487373948097229
#
# Saved training quantitites for step 40 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #41
# Energy = -0.374483197927475
# Variance = 0.45495373010635376
#
# Step #42
# Energy = -0.3872787356376648
# Variance = 0.37080273032188416
#
# Step #43
# Energy = -0.39479753375053406
# Variance = 0.31390026211738586
#
# Step #44
# Energy = -0.3941008448600769
# Variance = 0.3324596881866455
#
# Step #45
# Energy = -0.39714452624320984
# Variance = 0.3132396936416626
#
# Step #46
# Energy = -0.39905548095703125
# Variance = 0.31516021490097046
#
# Step #47
# Energy = -0.3883805274963379
# Variance = 0.35330700874328613
#
# Step #48
# Energy = -0.3774169087409973
# Variance = 0.4444396495819092
#
# Step #49
# Energy = -0.39654287695884705
# Variance = 0.32851824164390564
#
# Step #50
# Energy = -0.4046975374221802
# Variance = 0.2816688120365143
#
# Saved training quantitites for step 50 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #51
# Energy = -0.39993277192115784
# Variance = 0.3086753785610199
#
# Step #52
# Energy = -0.39107248187065125
# Variance = 0.36186084151268005
#
# Step #53
# Energy = -0.4026404619216919
# Variance = 0.2918010652065277
#
# Step #54
# Energy = -0.4030206799507141
# Variance = 0.26480627059936523
#
# Step #55
# Energy = -0.39454203844070435
# Variance = 0.3281136453151703
#
# Step #56
# Energy = -0.40656664967536926
# Variance = 0.28098180890083313
#
# Step #57
# Energy = -0.4002474844455719
# Variance = 0.28472277522087097
#
# Step #58
# Energy = -0.41271257400512695
# Variance = 0.22386634349822998
#
# Step #59
# Energy = -0.4098665714263916
# Variance = 0.24027325212955475
#
# Step #60
# Energy = -0.40234094858169556
# Variance = 0.2952328324317932
#
# Saved training quantitites for step 60 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #61
# Energy = -0.39751577377319336
# Variance = 0.3288640081882477
#
# Step #62
# Energy = -0.39518943428993225
# Variance = 0.2943156957626343
#
# Step #63
# Energy = -0.3951099216938019
# Variance = 0.30071473121643066
#
# Step #64
# Energy = -0.4065707325935364
# Variance = 0.23939508199691772
#
# Step #65
# Energy = -0.40642333030700684
# Variance = 0.22763098776340485
#
# Step #66
# Energy = -0.40430140495300293
# Variance = 0.26311004161834717
#
# Step #67
# Energy = -0.4030899405479431
# Variance = 0.27176547050476074
#
# Step #68
# Energy = -0.3924379348754883
# Variance = 0.3474331498146057
#
# Step #69
# Energy = -0.40148839354515076
# Variance = 0.3009953200817108
#
# Step #70
# Energy = -0.3964540958404541
# Variance = 0.3135380148887634
#
# Saved training quantitites for step 70 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #71
# Energy = -0.3985522389411926
# Variance = 0.2924191951751709
#
# Step #72
# Energy = -0.39477741718292236
# Variance = 0.35128694772720337
#
# Step #73
# Energy = -0.4054691195487976
# Variance = 0.24406293034553528
#
# Step #74
# Energy = -0.41058871150016785
# Variance = 0.24716895818710327
#
# Step #75
# Energy = -0.39626988768577576
# Variance = 0.30351343750953674
#
# Step #76
# Energy = -0.4024234116077423
# Variance = 0.2942894995212555
#
# Step #77
# Energy = -0.40304335951805115
# Variance = 0.2645075023174286
#
# Step #78
# Energy = -0.4096328020095825
# Variance = 0.2728117108345032
#
# Step #79
# Energy = -0.4026064872741699
# Variance = 0.2903149425983429
#
# Step #80
# Energy = -0.41078874468803406
# Variance = 0.26396021246910095
#
# Saved training quantitites for step 80 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #81
# Energy = -0.407708078622818
# Variance = 0.25742632150650024
#
# Step #82
# Energy = -0.4103752672672272
# Variance = 0.2763877511024475
#
# Step #83
# Energy = -0.4047376811504364
# Variance = 0.31566107273101807
#
# Step #84
# Energy = -0.40415579080581665
# Variance = 0.28266221284866333
#
# Step #85
# Energy = -0.4037051200866699
# Variance = 0.25484350323677063
#
# Step #86
# Energy = -0.4140808582305908
# Variance = 0.23666130006313324
#
# Step #87
# Energy = -0.4115384519100189
# Variance = 0.2398308515548706
#
# Step #88
# Energy = -0.40613314509391785
# Variance = 0.2602558732032776
#
# Step #89
# Energy = -0.4175832271575928
# Variance = 0.18243993818759918
#
# Step #90
# Energy = -0.4118248522281647
# Variance = 0.23738326132297516
#
# Saved training quantitites for step 90 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #91
# Energy = -0.4015611410140991
# Variance = 0.29481321573257446
#
# Step #92
# Energy = -0.40817487239837646
# Variance = 0.23163995146751404
#
# Step #93
# Energy = -0.41219332814216614
# Variance = 0.25088268518447876
#
# Step #94
# Energy = -0.413930743932724
# Variance = 0.24154327809810638
#
# Step #95
# Energy = -0.41500285267829895
# Variance = 0.22304511070251465
#
# Step #96
# Energy = -0.4135534167289734
# Variance = 0.21127673983573914
#
# Step #97
# Energy = -0.40244072675704956
# Variance = 0.3023317754268646
#
# Step #98
# Energy = -0.39771586656570435
# Variance = 0.3474232852458954
# Step #99
# Energy = -0.4214535653591156
# Variance = 0.16592377424240112
#
# Step #100
# Energy = -0.41271135210990906
# Variance = 0.2252092808485031
#
# Saved training quantitites for step 100 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #101
# Energy = -0.4080137610435486
# Variance = 0.31812506914138794
#
# Step #102
# Energy = -0.4169140160083771
# Variance = 0.21805225312709808
#
# Step #103
# Energy = -0.4086340665817261
# Variance = 0.26644209027290344
#
# Step #104
# Energy = -0.41579654812812805
# Variance = 0.2148090898990631
#
# Step #105
# Energy = -0.41013550758361816
# Variance = 0.2577205300331116
#
# Step #106
# Energy = -0.4104306995868683
# Variance = 0.23273403942584991
#
# Step #107
# Energy = -0.4192867577075958
# Variance = 0.19909034669399261
#
# Step #108
# Energy = -0.41788896918296814
# Variance = 0.21303895115852356
#
# Step #109
# Energy = -0.4240534007549286
# Variance = 0.19273117184638977
#
# Step #110
# Energy = -0.4143127501010895
# Variance = 0.2077624797821045
#
# Saved training quantitites for step 110 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #111
# Energy = -0.40851500630378723
# Variance = 0.26338788866996765
#
# Step #112
# Energy = -0.4138522446155548
# Variance = 0.2602216303348541
#
# Step #113
# Energy = -0.4205324649810791
# Variance = 0.20126062631607056
#
# Step #114
# Energy = -0.4183555245399475
# Variance = 0.17568561434745789
#
# Step #115
# Energy = -0.41538453102111816
# Variance = 0.2219855785369873
#
# Step #116
# Energy = -0.4159349501132965
# Variance = 0.1826755255460739
#
# Step #117
# Energy = -0.4210415184497833
# Variance = 0.1926776021718979
#
# Step #118
# Energy = -0.42068538069725037
# Variance = 0.17238469421863556
#
# Step #119
# Energy = -0.42098551988601685
# Variance = 0.21507439017295837
#
# Step #120
# Energy = -0.4279932379722595
# Variance = 0.1774064302444458
#
# Saved training quantitites for step 120 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #121
# Energy = -0.4208603501319885
# Variance = 0.17053425312042236
#
# Step #122
# Energy = -0.4205036759376526
# Variance = 0.1856808364391327
#
# Step #123
# Energy = -0.4188292324542999
# Variance = 0.1920015513896942
#
# Step #124
# Energy = -0.42488348484039307
# Variance = 0.15685269236564636
#
# Step #125
# Energy = -0.4147487282752991
# Variance = 0.23024356365203857
#
# Step #126
# Energy = -0.41730156540870667
# Variance = 0.21999883651733398
#
# Step #127
# Energy = -0.4158160984516144
# Variance = 0.2037973701953888
#
# Step #128
# Energy = -0.4194734990596771
# Variance = 0.20464631915092468
#
# Step #129
# Energy = -0.42047736048698425
# Variance = 0.20716404914855957
#
# Step #130
# Energy = -0.4277639091014862
# Variance = 0.15282519161701202
#
# Saved training quantitites for step 130 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #131
# Energy = -0.4225888252258301
# Variance = 0.18864545226097107
#
# Step #132
# Energy = -0.4174298048019409
# Variance = 0.16806945204734802
#
# Step #133
# Energy = -0.42009276151657104
# Variance = 0.1659168154001236
#
# Step #134
# Energy = -0.4230896532535553
# Variance = 0.17519499361515045
#
# Step #135
# Energy = -0.4227294325828552
# Variance = 0.17468160390853882
#
# Step #136
# Energy = -0.4214725196361542
# Variance = 0.1859835833311081
#
# Step #137
# Energy = -0.4220135509967804
# Variance = 0.2044202983379364
#
# Step #138
# Energy = -0.41820982098579407
# Variance = 0.19443382322788239
#
# Step #139
# Energy = -0.4231117069721222
# Variance = 0.17279589176177979
#
# Step #140
# Energy = -0.4179408550262451
# Variance = 0.2396984100341797
#
# Saved training quantitites for step 140 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #141
# Energy = -0.4215667247772217
# Variance = 0.1850346028804779
#
# Step #142
# Energy = -0.42261427640914917
# Variance = 0.18523290753364563
#
# Step #143
# Energy = -0.424923837184906
# Variance = 0.16954532265663147
#
# Step #144
# Energy = -0.42564821243286133
# Variance = 0.15749268233776093
#
# Step #145
# Energy = -0.4242875277996063
# Variance = 0.1734936237335205
#
# Step #146
# Energy = -0.4201332926750183
# Variance = 0.1720248907804489
#
# Step #147
# Energy = -0.4201686680316925
# Variance = 0.34761106967926025
#
# Step #148
# Energy = -0.4194737672805786
# Variance = 0.20321446657180786
#
# Step #149
# Energy = -0.42164453864097595
# Variance = 0.1948166787624359
#
# Step #150
# Energy = -0.4237483739852905
# Variance = 0.1662483811378479
#
# Saved training quantitites for step 150 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #151
# Energy = -0.4140245020389557
# Variance = 0.266086608171463
#
# Step #152
# Energy = -0.4274507462978363
# Variance = 0.12246476858854294
#
# Step #153
# Energy = -0.4235877990722656
# Variance = 0.17551687359809875
#
# Step #154
# Energy = -0.4218296408653259
# Variance = 0.20651288330554962
#
# Step #155
# Energy = -0.41456863284111023
# Variance = 0.24892348051071167
#
# Step #156
# Energy = -0.42880314588546753
# Variance = 0.1665424257516861
#
# Step #157
# Energy = -0.42213138937950134
# Variance = 0.16559772193431854
#
# Step #158
# Energy = -0.424223929643631
# Variance = 0.160596564412117
#
# Step #159
# Energy = -0.4243471622467041
# Variance = 0.16584622859954834
#
# Step #160
# Energy = -0.41849541664123535
# Variance = 0.2022894322872162
#
# Saved training quantitites for step 160 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #161
# Energy = -0.42997416853904724
# Variance = 0.13666604459285736
#
# Step #162
# Energy = -0.4176185429096222
# Variance = 0.21640731394290924
#
# Step #163
# Energy = -0.4268384277820587
# Variance = 0.1401037573814392
#
# Step #164
# Energy = -0.42415475845336914
# Variance = 0.17529821395874023
#
# Step #165
# Energy = -0.42270323634147644
# Variance = 0.18177850544452667
#
# Step #166
# Energy = -0.4298251271247864
# Variance = 0.14475548267364502
#
# Step #167
# Energy = -0.43309715390205383
# Variance = 0.14300225675106049
#
# Step #168
# Energy = -0.4297354519367218
# Variance = 0.13080774247646332
#
# Step #169
# Energy = -0.4249272346496582
# Variance = 0.17572729289531708
#
# Step #170
# Energy = -0.43100327253341675
# Variance = 0.1615976244211197
#
# Saved training quantitites for step 170 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #171
# Energy = -0.4211258590221405
# Variance = 0.18543297052383423
#
# Step #172
# Energy = -0.425441712141037
# Variance = 0.15847203135490417
#
# Step #173
# Energy = -0.4241841435432434
# Variance = 0.1530720591545105
#
# Step #174
# Energy = -0.42363664507865906
# Variance = 0.16441190242767334
#
# Step #175
# Energy = -0.4265285134315491
# Variance = 0.15965774655342102
#
# Step #176
# Energy = -0.4282648265361786
# Variance = 0.13680818676948547
#
# Step #177
# Energy = -0.43086302280426025
# Variance = 0.10535649955272675
#
# Step #178
# Energy = -0.4195297658443451
# Variance = 0.1995193511247635
#
# Step #179
# Energy = -0.4309145510196686
# Variance = 0.11387614160776138
#
# Step #180
# Energy = -0.4267939329147339
# Variance = 0.1768462359905243
#
# Saved training quantitites for step 180 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #181
# Energy = -0.42624297738075256
# Variance = 0.164870947599411
#
# Step #182
# Energy = -0.42295604944229126
# Variance = 0.18364936113357544
#
# Step #183
# Energy = -0.4295729100704193
# Variance = 0.12271123379468918
#
# Step #184
# Energy = -0.42538899183273315
# Variance = 0.14323437213897705
#
# Step #185
# Energy = -0.4236511290073395
# Variance = 0.1814073622226715
#
# Step #186
# Energy = -0.4296371340751648
# Variance = 0.135400652885437
#
# Step #187
# Energy = -0.4329948425292969
# Variance = 0.12826916575431824
#
# Step #188
# Energy = -0.42871570587158203
# Variance = 0.12887319922447205
#
# Step #189
# Energy = -0.4328233003616333
# Variance = 0.11133836954832077
#
# Step #190
# Energy = -0.4236755073070526
# Variance = 0.15142245590686798
#
# Saved training quantitites for step 190 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #191
# Energy = -0.42570778727531433
# Variance = 0.13699065148830414
#
# Step #192
# Energy = -0.42819494009017944
# Variance = 0.1397322714328766
#
# Step #193
# Energy = -0.4311979413032532
# Variance = 0.13034465909004211
#
# Step #194
# Energy = -0.43096300959587097
# Variance = 0.1368999183177948
#
# Step #195
# Energy = -0.431143581867218
# Variance = 0.13874033093452454
#
# Step #196
# Energy = -0.4315422773361206
# Variance = 0.1406824290752411
#
# Step #197
# Energy = -0.4352372884750366
# Variance = 0.12286148220300674
#
# Step #198
# Energy = -0.42663586139678955
# Variance = 0.14600008726119995
#
# Step #199
# Energy = -0.43217477202415466
# Variance = 0.10439049452543259
#
# Step #200
# Energy = -0.43472692370414734
# Variance = 0.11360810697078705
#
# Saved training quantitites for step 200 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #201
# Energy = -0.43433141708374023
# Variance = 0.11480088531970978
#
# Step #202
# Energy = -0.4307767450809479
# Variance = 0.14664573967456818
#
# Step #203
# Energy = -0.43300360441207886
# Variance = 0.12126808613538742
#
# Step #204
# Energy = -0.42936453223228455
# Variance = 0.10408520698547363
#
# Step #205
# Energy = -0.43193018436431885
# Variance = 0.1392776519060135
#
# Step #206
# Energy = -0.4370999038219452
# Variance = 0.11823916435241699
#
# Step #207
# Energy = -0.43076854944229126
# Variance = 0.11448810994625092
#
# Step #208
# Energy = -0.43588924407958984
# Variance = 0.09851016849279404
#
# Step #209
# Energy = -0.4319852888584137
# Variance = 0.11561685055494308
#
# Step #210
# Energy = -0.43505382537841797
# Variance = 0.08518964797258377
#
# Saved training quantitites for step 210 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #211
# Energy = -0.4325619041919708
# Variance = 0.13518379628658295
#
# Step #212
# Energy = -0.43435367941856384
# Variance = 0.09327174723148346
#
# Step #213
# Energy = -0.4294061064720154
# Variance = 0.1166314035654068
#
# Step #214
# Energy = -0.43364715576171875
# Variance = 0.10937388241291046
#
# Step #215
# Energy = -0.43422430753707886
# Variance = 0.11174940317869186
#
# Step #216
# Energy = -0.43521350622177124
# Variance = 0.10089943557977676
#
# Step #217
# Energy = -0.4327809810638428
# Variance = 0.09466350078582764
#
# Step #218
# Energy = -0.4395309388637543
# Variance = 0.07448183745145798
#
# Step #219
# Energy = -0.4389529228210449
# Variance = 0.07719230651855469
#
# Step #220
# Energy = -0.43515545129776
# Variance = 0.09721720963716507
#
# Saved training quantitites for step 220 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #221
# Energy = -0.437507301568985
# Variance = 0.08490972965955734
#
# Step #222
# Energy = -0.43590015172958374
# Variance = 0.09676403552293777
#
# Step #223
# Energy = -0.43423497676849365
# Variance = 0.10331180691719055
#
# Step #224
# Energy = -0.43767932057380676
# Variance = 0.08492355048656464
#
# Step #225
# Energy = -0.4358140230178833
# Variance = 0.07395854592323303
#
# Step #226
# Energy = -0.4370512366294861
# Variance = 0.1427689641714096
#
# Step #227
# Energy = -0.433932363986969
# Variance = 0.08639580011367798
#
# Step #228
# Energy = -0.43759259581565857
# Variance = 0.09105639904737473
#
# Step #229
# Energy = -0.43471574783325195
# Variance = 0.09800555557012558
#
# Step #230
# Energy = -0.4372510015964508
# Variance = 0.09729235619306564
#
# Saved training quantitites for step 230 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #231
# Energy = -0.443764328956604
# Variance = 0.07499781996011734
#
# Step #232
# Energy = -0.43950068950653076
# Variance = 0.0712820291519165
#
# Step #233
# Energy = -0.43796923756599426
# Variance = 0.09960522502660751
#
# Step #234
# Energy = -0.4404085576534271
# Variance = 0.13488803803920746
#
# Step #235
# Energy = -0.43932250142097473
# Variance = 0.09054935723543167
#
# Step #236
# Energy = -0.4396546483039856
# Variance = 0.07584655284881592
#
# Step #237
# Energy = -0.44307807087898254
# Variance = 0.08655419945716858
#
# Step #238
# Energy = -0.4394064247608185
# Variance = 0.07812078297138214
#
# Step #239
# Energy = -0.4381161630153656
# Variance = 0.062100913375616074
#
# Step #240
# Energy = -0.4388873279094696
# Variance = 0.08398501574993134
#
# Saved training quantitites for step 240 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #241
# Energy = -0.4362584948539734
# Variance = 0.0766756534576416
#
# Step #242
# Energy = -0.4386994540691376
# Variance = 0.07728280872106552
#
# Step #243
# Energy = -0.44192254543304443
# Variance = 0.05766754597425461
#
# Step #244
# Energy = -0.4392579197883606
# Variance = 0.06924783438444138
#
# Step #245
# Energy = -0.4376167356967926
# Variance = 0.07726012915372849
#
# Step #246
# Energy = -0.4350380301475525
# Variance = 0.08897919207811356
#
# Step #247
# Energy = -0.44086363911628723
# Variance = 0.06394793093204498
#
# Step #248
# Energy = -0.44484570622444153
# Variance = 0.0659782662987709
#
# Step #249
# Energy = -0.4368746876716614
# Variance = 0.08733505755662918
#
# Step #250
# Energy = -0.4407753646373749
# Variance = 0.07582777738571167
#
# Saved training quantitites for step 250 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #251
# Energy = -0.43850260972976685
# Variance = 0.06403207033872604
#
# Step #252
# Energy = -0.4359681308269501
# Variance = 0.09113376587629318
#
# Step #253
# Energy = -0.44136902689933777
# Variance = 0.06605177372694016
#
# Step #254
# Energy = -0.43499550223350525
# Variance = 0.06978967785835266
#
# Step #255
# Energy = -0.4368292987346649
# Variance = 0.06615421921014786
#
# Step #256
# Energy = -0.43931883573532104
# Variance = 0.058273039758205414
#
# Step #257
# Energy = -0.44268596172332764
# Variance = 0.07299730181694031
#
# Step #258
# Energy = -0.4415975511074066
# Variance = 0.0774911493062973
#
# Step #259
# Energy = -0.44329461455345154
# Variance = 0.0977187231183052
#
# Step #260
# Energy = -0.44384363293647766
# Variance = 0.05685444921255112
#
# Saved training quantitites for step 260 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #261
# Energy = -0.4403257369995117
# Variance = 0.06837786734104156
#
# Step #262
# Energy = -0.44227930903434753
# Variance = 0.07062734663486481
#
# Step #263
# Energy = -0.43976786732673645
# Variance = 0.12917537987232208
#
# Step #264
# Energy = -0.43988338112831116
# Variance = 0.0606878362596035
#
# Step #265
# Energy = -0.443664014339447
# Variance = 0.06922273337841034
#
# Step #266
# Energy = -0.43934372067451477
# Variance = 0.06773506104946136
#
# Step #267
# Energy = -0.44171813130378723
# Variance = 0.060971613973379135
#
# Step #268
# Energy = -0.4424864649772644
# Variance = 0.07859735190868378
#
# Step #269
# Energy = -0.4411240220069885
# Variance = 0.04488662630319595
#
# Step #270
# Energy = -0.44291430711746216
# Variance = 0.0786466971039772
#
# Saved training quantitites for step 270 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #271
# Energy = -0.4448930025100708
# Variance = 0.05719873681664467
#
# Step #272
# Energy = -0.44261813163757324
# Variance = 0.052140869200229645
#
# Step #273
# Energy = -0.4412897229194641
# Variance = 0.05257401987910271
#
# Step #274
# Energy = -0.44312340021133423
# Variance = 0.05230749025940895
#
# Step #275
# Energy = -0.4383794367313385
# Variance = 0.053612109273672104
#
# Step #276
# Energy = -0.4411156475543976
# Variance = 0.08686311542987823
#
# Step #277
# Energy = -0.4423815906047821
# Variance = 0.044040925800800323
#
# Step #278
# Energy = -0.44047123193740845
# Variance = 0.05171004310250282
#
# Step #279
# Energy = -0.4387269914150238
# Variance = 0.09454970806837082
#
# Step #280
# Energy = -0.47599324584007263
# Variance = 18.875333786010742
#
# Saved training quantitites for step 280 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #281
# Energy = -0.44158875942230225
# Variance = 0.05816498398780823
#
# Step #282
# Energy = -0.4445037245750427
# Variance = 0.060163337737321854
#
# Step #283
# Energy = -0.4429767429828644
# Variance = 0.04517452418804169
#
# Step #284
# Energy = -0.44327932596206665
# Variance = 0.0795687735080719
#
# Step #285
# Energy = -0.4424108564853668
# Variance = 0.06704004853963852
#
# Step #286
# Energy = -0.4406103491783142
# Variance = 0.05052966997027397
#
# Step #287
# Energy = -0.4407409727573395
# Variance = 0.07800070941448212
#
# Step #288
# Energy = -0.4400533437728882
# Variance = 0.07577259838581085
#
# Step #289
# Energy = -0.4406917989253998
# Variance = 0.0787607729434967
#
# Step #290
# Energy = -0.44342902302742004
# Variance = 0.0846443846821785
#
# Saved training quantitites for step 290 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #291
# Energy = -0.43977850675582886
# Variance = 0.07451082020998001
#
# Step #292
# Energy = -0.444363534450531
# Variance = 0.11264999210834503
#
# Step #293
# Energy = -0.44466376304626465
# Variance = 0.29561033844947815
#
# Step #294
# Energy = -0.44351398944854736
# Variance = 0.049729544669389725
#
# Step #295
# Energy = -0.44659703969955444
# Variance = 0.0750228762626648
#
# Step #296
# Energy = -0.444649338722229
# Variance = 0.06304183602333069
#
# Step #297
# Energy = -0.4387679994106293
# Variance = 0.06264013051986694
#
# Step #298
# Energy = -0.4397415220737457
# Variance = 0.046720802783966064
#
# Step #299
# Energy = -0.44200626015663147
# Variance = 0.04899376630783081
#
# Step #300
# Energy = -0.4386675953865051
# Variance = 0.08168447762727737
#
# Saved training quantitites for step 300 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #301
# Energy = -0.4415968954563141
# Variance = 0.04821383208036423
#
# Step #302
# Energy = -0.44319915771484375
# Variance = 0.05353980511426926
#
# Step #303
# Energy = -0.4391480088233948
# Variance = 0.04773987457156181
#
# Step #304
# Energy = -0.4396496117115021
# Variance = 0.1196351945400238
#
# Step #305
# Energy = -0.44075942039489746
# Variance = 0.05070626363158226
#
# Step #306
# Energy = -0.4412784278392792
# Variance = 0.05523914471268654
#
# Step #307
# Energy = -0.44457653164863586
# Variance = 0.06509770452976227
#
# Step #308
# Energy = -0.443169504404068
# Variance = 0.04030328989028931
#
# Step #309
# Energy = -0.44445013999938965
# Variance = 0.08401168137788773
#
# Step #310
# Energy = -0.44233739376068115
# Variance = 0.04400975629687309
#
# Saved training quantitites for step 310 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #311
# Energy = -0.44175025820732117
# Variance = 0.043778419494628906
#
# Step #312
# Energy = -0.4401639997959137
# Variance = 0.06008807197213173
#
# Step #313
# Energy = -0.4436781406402588
# Variance = 0.057451240718364716
#
# Step #314
# Energy = -0.44236889481544495
# Variance = 0.09455053508281708
#
# Step #315
# Energy = -0.44188955426216125
# Variance = 0.06443578749895096
#
# Step #316
# Energy = -0.4441640079021454
# Variance = 0.06086307018995285
#
# Step #317
# Energy = -0.43868452310562134
# Variance = 0.04977981746196747
#
# Step #318
# Energy = -0.44089749455451965
# Variance = 0.06156373396515846
#
# Step #319
# Energy = -0.44134557247161865
# Variance = 0.049470506608486176
#
# Step #320
# Energy = -0.4427979588508606
# Variance = 0.07198277860879898
#
# Saved training quantitites for step 320 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #321
# Energy = -0.4417160153388977
# Variance = 0.05173513665795326
#
# Step #322
# Energy = -0.43938112258911133
# Variance = 0.0626358687877655
#
# Step #323
# Energy = -0.4424673318862915
# Variance = 0.06090585142374039
#
# Step #324
# Energy = -0.4413491189479828
# Variance = 0.1309858113527298
#
# Step #325
# Energy = -0.44184207916259766
# Variance = 0.0614345408976078
#
# Step #326
# Energy = -0.4410936236381531
# Variance = 0.04433672875165939
#
# Step #327
# Energy = -0.4406624138355255
# Variance = 0.0519072450697422
#
# Step #328
# Energy = -0.4432666599750519
# Variance = 0.05850847810506821
#
# Step #329
# Energy = -0.4386814534664154
# Variance = 0.06361519545316696
#
# Step #330
# Energy = -0.4448077082633972
# Variance = 0.046415604650974274
#
# Saved training quantitites for step 330 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #331
# Energy = -0.443332314491272
# Variance = 0.05953687056899071
#
# Step #332
# Energy = -0.440300315618515
# Variance = 0.052532490342855453
#
# Step #333
# Energy = -0.4408080577850342
# Variance = 0.06492143124341965
#
# Step #334
# Energy = -0.4522008001804352
# Variance = 1.4561889171600342
#
# Step #335
# Energy = -0.4481959939002991
# Variance = 0.4896555244922638
#
# Step #336
# Energy = -0.438656747341156
# Variance = 0.0565214604139328
#
# Step #337
# Energy = -0.44145190715789795
# Variance = 0.049974195659160614
#
# Step #338
# Energy = -0.4412684738636017
# Variance = 0.06074269488453865
#
# Step #339
# Energy = -0.4397989511489868
# Variance = 0.06257960945367813
#
# Step #340
# Energy = -0.4433455169200897
# Variance = 0.06023641303181648
#
# Saved training quantitites for step 340 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #341
# Energy = -0.4409702718257904
# Variance = 0.0632493793964386
#
# Step #342
# Energy = -0.4408608675003052
# Variance = 0.06469317525625229
#
# Step #343
# Energy = -0.44083118438720703
# Variance = 0.05578216537833214
#
# Step #344
# Energy = -0.4401956796646118
# Variance = 0.056557681411504745
#
# Step #345
# Energy = -0.4386182725429535
# Variance = 0.04794631898403168
#
# Step #346
# Energy = -0.4357488453388214
# Variance = 0.06012396141886711
#
# Step #347
# Energy = -0.44145315885543823
# Variance = 0.050373949110507965
#
# Step #348
# Energy = -0.44111937284469604
# Variance = 0.05962438881397247
#
# Step #349
# Energy = -0.4417092204093933
# Variance = 0.0777100995182991
#
# Step #350
# Energy = -0.44399896264076233
# Variance = 0.05110535770654678
#
# Saved training quantitites for step 350 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #351
# Energy = -0.4430429935455322
# Variance = 0.08616068959236145
#
# Step #352
# Energy = -0.44776061177253723
# Variance = 0.31846538186073303
#
# Step #353
# Energy = -0.4451480209827423
# Variance = 0.19455474615097046
#
# Step #354
# Energy = -0.4432294964790344
# Variance = 0.051031798124313354
#
# Step #355
# Energy = -0.4386879801750183
# Variance = 0.05166514590382576
#
# Step #356
# Energy = -0.4382232129573822
# Variance = 0.06545132398605347
#
# Step #357
# Energy = -0.4410230219364166
# Variance = 0.06392060220241547
#
# Step #358
# Energy = -0.4402828514575958
# Variance = 0.05653226748108864
#
# Step #359
# Energy = -0.4388091266155243
# Variance = 0.09351877868175507
#
# Step #360
# Energy = -0.4374859035015106
# Variance = 0.0643574520945549
#
# Saved training quantitites for step 360 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #361
# Energy = -0.442641019821167
# Variance = 0.044049642980098724
#
# Step #362
# Energy = -0.4407227039337158
# Variance = 0.06983055174350739
#
# Step #363
# Energy = -0.44084838032722473
# Variance = 0.044650848954916
#
# Step #364
# Energy = -0.4390946924686432
# Variance = 0.05839633196592331
#
# Step #365
# Energy = -0.4420526623725891
# Variance = 0.08187536150217056
#
# Step #366
# Energy = -0.44002121686935425
# Variance = 0.0713471919298172
#
# Step #367
# Energy = -0.43688663840293884
# Variance = 0.05535639822483063
#
# Step #368
# Energy = -0.4397335350513458
# Variance = 0.05981719121336937
#
# Step #369
# Energy = -0.43900299072265625
# Variance = 0.08082453161478043
#
# Step #370
# Energy = -0.44034168124198914
# Variance = 0.08114638924598694
#
# Saved training quantitites for step 370 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #371
# Energy = -0.44134920835494995
# Variance = 0.05238059163093567
#
# Step #372
# Energy = -0.4374266564846039
# Variance = 0.05117279663681984
#
# Step #373
# Energy = -0.4383098781108856
# Variance = 0.07217579334974289
#
# Step #374
# Energy = -0.4407121241092682
# Variance = 0.05570570379495621
#
# Step #375
# Energy = -0.4377767741680145
# Variance = 0.0684371143579483
#
# Step #376
# Energy = -0.44271349906921387
# Variance = 0.1322493851184845
#
# Step #377
# Energy = -0.44177186489105225
# Variance = 0.09274223446846008
#
# Step #378
# Energy = -0.44048699736595154
# Variance = 0.050926074385643005
#
# Step #379
# Energy = -0.4363706409931183
# Variance = 0.07523027062416077
#
# Step #380
# Energy = -0.4428839683532715
# Variance = 0.07750539481639862
#
# Saved training quantitites for step 380 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #381
# Energy = -0.4381890892982483
# Variance = 0.06297177076339722
#
# Step #382
# Energy = -0.4436718821525574
# Variance = 0.046991631388664246
#
# Step #383
# Energy = -0.4413450360298157
# Variance = 0.07677514851093292
#
# Step #384
# Energy = -0.4367539584636688
# Variance = 0.09303771704435349
#
# Step #385
# Energy = -0.4356461763381958
# Variance = 0.0479649119079113
#
# Step #386
# Energy = -0.44086021184921265
# Variance = 0.07921532541513443
#
# Step #387
# Energy = -0.4391164481639862
# Variance = 0.0678488165140152
#
# Step #388
# Energy = -0.4416200518608093
# Variance = 0.10151563584804535
#
# Step #389
# Energy = -0.43923497200012207
# Variance = 0.060759034007787704
#
# Step #390
# Energy = -0.4396900534629822
# Variance = 0.17981891334056854
#
# Saved training quantitites for step 390 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #391
# Energy = -0.4392455518245697
# Variance = 0.07893167436122894
#
# Step #392
# Energy = -0.43961700797080994
# Variance = 0.0975516214966774
#
# Step #393
# Energy = -0.43746086955070496
# Variance = 0.067137710750103
#
# Step #394
# Energy = -0.43931883573532104
# Variance = 0.08351650089025497
#
# Step #395
# Energy = -0.4415184259414673
# Variance = 0.050179623067379
#
# Step #396
# Energy = -0.4385341703891754
# Variance = 0.07450313121080399
#
# Step #397
# Energy = -0.43856000900268555
# Variance = 0.053140539675951004
#
# Step #398
# Energy = -0.43833696842193604
# Variance = 0.09456606954336166
#
# Step #399
# Energy = -0.4409911632537842
# Variance = 0.10308545082807541
#
# Step #400
# Energy = -0.441877156496048
# Variance = 0.08088628202676773
#
# Saved training quantitites for step 400 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #401
# Energy = -0.43671491742134094
# Variance = 0.11046524345874786
#
# Step #402
# Energy = -0.43758466839790344
# Variance = 0.05842646583914757
#
# Step #403
# Energy = -0.44097283482551575
# Variance = 0.05319533124566078
#
# Step #404
# Energy = -0.4419500529766083
# Variance = 0.08039460331201553
#
# Step #405
# Energy = -0.4439246952533722
# Variance = 0.12496887147426605
#
# Step #406
# Energy = -0.43569985032081604
# Variance = 0.05697819963097572
#
# Step #407
# Energy = -0.4354497194290161
# Variance = 0.05145871639251709
#
# Step #408
# Energy = -0.44082140922546387
# Variance = 0.05086454004049301
#
# Step #409
# Energy = -0.4392213225364685
# Variance = 0.08781574666500092
#
# Step #410
# Energy = -0.44194725155830383
# Variance = 0.07222115993499756
#
# Saved training quantitites for step 410 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #411
# Energy = -0.4411025941371918
# Variance = 0.05826607346534729
#
# Step #412
# Energy = -0.445463627576828
# Variance = 0.10962267965078354
#
# Step #413
# Energy = -0.44127580523490906
# Variance = 0.1159367710351944
#
# Step #414
# Energy = -0.43381035327911377
# Variance = 0.07594877481460571
#
# Step #415
# Energy = -0.43990930914878845
# Variance = 0.06279649585485458
#
# Step #416
# Energy = -0.44210633635520935
# Variance = 0.07069023698568344
#
# Step #417
# Energy = -0.4370594620704651
# Variance = 0.054315946996212006
#
# Step #418
# Energy = -0.43809521198272705
# Variance = 0.06632301211357117
#
# Step #419
# Energy = -0.43751636147499084
# Variance = 0.0720667913556099
#
# Step #420
# Energy = -0.4419451951980591
# Variance = 0.08257713168859482
#
# Saved training quantitites for step 420 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #421
# Energy = -0.4412629008293152
# Variance = 0.13762584328651428
#
# Step #422
# Energy = -0.44033482670783997
# Variance = 0.06065094470977783
#
# Step #423
# Energy = -0.43391022086143494
# Variance = 0.08615841716527939
#
# Step #424
# Energy = -0.44164830446243286
# Variance = 0.1083940789103508
#
# Step #425
# Energy = -0.4381909966468811
# Variance = 0.11210586875677109
#
# Step #426
# Energy = -0.4357773959636688
# Variance = 0.08640226721763611
#
# Step #427
# Energy = -0.43940937519073486
# Variance = 0.08599122613668442
#
# Step #428
# Energy = -0.43484410643577576
# Variance = 0.14288412034511566
#
# Step #429
# Energy = -0.43821629881858826
# Variance = 0.08602757751941681
#
# Step #430
# Energy = -0.4394891560077667
# Variance = 0.106669120490551
#
# Saved training quantitites for step 430 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #431
# Energy = -0.4373112916946411
# Variance = 0.09136984497308731
#
# Step #432
# Energy = -0.4357496201992035
# Variance = 0.06406640261411667
#
# Step #433
# Energy = -0.4384152889251709
# Variance = 0.061879392713308334
#
# Step #434
# Energy = -0.44138669967651367
# Variance = 0.09125743806362152
#
# Step #435
# Energy = -0.4364608824253082
# Variance = 0.12762589752674103
#
# Step #436
# Energy = -0.43915417790412903
# Variance = 0.07684104144573212
#
# Step #437
# Energy = -0.44171446561813354
# Variance = 0.1173400729894638
#
# Step #438
# Energy = -0.4387112557888031
# Variance = 0.08103669434785843
#
# Step #439
# Energy = -0.4356696903705597
# Variance = 0.10317996144294739
#
# Step #440
# Energy = -0.44063296914100647
# Variance = 0.08701755106449127
#
# Saved training quantitites for step 440 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #441
# Energy = -0.43857353925704956
# Variance = 0.10802270472049713
#
# Step #442
# Energy = -0.43633362650871277
# Variance = 0.07364804297685623
#
# Step #443
# Energy = -0.4360550045967102
# Variance = 0.07194656133651733
#
# Step #444
# Energy = -0.43815159797668457
# Variance = 0.0673498883843422
#
# Step #445
# Energy = -0.4374757707118988
# Variance = 0.11309785395860672
#
# Step #446
# Energy = -0.4360540807247162
# Variance = 0.06035593897104263
#
# Step #447
# Energy = -0.4322373867034912
# Variance = 0.07024458795785904
#
# Step #448
# Energy = -0.4376923143863678
# Variance = 0.08540040254592896
#
# Step #449
# Energy = -0.43862149119377136
# Variance = 0.2450045496225357
#
# Step #450
# Energy = -0.43909943103790283
# Variance = 0.05949731543660164
#
# Saved training quantitites for step 450 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #451
# Energy = -0.4354531168937683
# Variance = 0.06691282987594604
#
# Step #452
# Energy = -0.43573012948036194
# Variance = 0.05517047643661499
#
# Step #453
# Energy = -0.43773016333580017
# Variance = 0.061507564038038254
#
# Step #454
# Energy = -0.4375469982624054
# Variance = 0.06892062723636627
#
# Step #455
# Energy = -0.43884196877479553
# Variance = 0.08239419013261795
#
# Step #456
# Energy = -0.4371727406978607
# Variance = 0.05699477717280388
#
# Step #457
# Energy = -0.43954700231552124
# Variance = 0.0728965774178505
#
# Step #458
# Energy = -0.43607398867607117
# Variance = 0.06514113396406174
#
# Step #459
# Energy = -0.43578311800956726
# Variance = 0.10545328259468079
#
# Step #460
# Energy = -0.43662646412849426
# Variance = 0.11434482783079147
#
# Saved training quantitites for step 460 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #461
# Energy = -0.44684603810310364
# Variance = 0.6629671454429626
#
# Step #462
# Energy = -0.4367588460445404
# Variance = 0.21906612813472748
#
# Step #463
# Energy = -0.43421727418899536
# Variance = 0.061295874416828156
#
# Step #464
# Energy = -0.43335241079330444
# Variance = 0.11221762001514435
#
# Step #465
# Energy = -0.436237096786499
# Variance = 0.06621358543634415
#
# Step #466
# Energy = -0.437183678150177
# Variance = 0.08220794796943665
#
# Step #467
# Energy = -0.4374223053455353
# Variance = 0.19267264008522034
#
# Step #468
# Energy = -0.43752285838127136
# Variance = 0.07320629805326462
#
# Step #469
# Energy = -0.43727758526802063
# Variance = 0.07931718230247498
#
# Step #470
# Energy = -0.43679773807525635
# Variance = 0.09380410611629486
#
# Saved training quantitites for step 470 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #471
# Energy = -0.4400578439235687
# Variance = 0.10544838011264801
#
# Step #472
# Energy = -0.43694376945495605
# Variance = 0.07441699504852295
#
# Step #473
# Energy = -0.436280757188797
# Variance = 0.05737347528338432
#
# Step #474
# Energy = -0.4326685965061188
# Variance = 0.11377987265586853
#
# Step #475
# Energy = -0.439003586769104
# Variance = 0.17473354935646057
#
# Step #476
# Energy = -0.4379698932170868
# Variance = 0.08086197078227997
#
# Step #477
# Energy = -0.43196526169776917
# Variance = 0.08406838774681091
#
# Step #478
# Energy = -0.43559718132019043
# Variance = 0.07928352802991867
#
# Step #479
# Energy = -0.4345457851886749
# Variance = 0.06371498107910156
#
# Step #480
# Energy = -0.43082886934280396
# Variance = 0.08960629999637604
#
# Saved training quantitites for step 480 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #481
# Energy = -0.4371602237224579
# Variance = 0.07872738689184189
#
# Step #482
# Energy = -0.43620848655700684
# Variance = 0.25512751936912537
#
# Step #483
# Energy = -0.43247076869010925
# Variance = 0.09444398432970047
#
# Step #484
# Energy = -0.43379026651382446
# Variance = 0.07455696165561676
#
# Step #485
# Energy = -0.43595439195632935
# Variance = 0.11399389058351517
#
# Step #486
# Energy = -0.4363420307636261
# Variance = 0.11503033339977264
#
# Step #487
# Energy = -0.4361409842967987
# Variance = 0.1866457462310791
#
# Step #488
# Energy = -0.43473201990127563
# Variance = 0.08428341895341873
#
# Step #489
# Energy = -0.4341732859611511
# Variance = 0.12017662823200226
#
# Step #490
# Energy = -0.4391266703605652
# Variance = 0.07904253900051117
#
# Saved training quantitites for step 490 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Step #491
# Energy = -0.4372010827064514
# Variance = 0.1564289927482605
#
# Step #492
# Energy = -0.43715938925743103
# Variance = 0.10172874480485916
#
# Step #493
# Energy = -0.4335184097290039
# Variance = 0.10760978609323502
#
# Step #494
# Energy = -0.4386909008026123
# Variance = 0.07197413593530655
#
# Step #495
# Energy = -0.4358167052268982
# Variance = 0.08261464536190033
#
# Step #496
# Energy = -0.43364760279655457
# Variance = 0.07173220068216324
#
# Step #497
# Energy = -0.43519771099090576
# Variance = 0.1200997605919838
#
# Step #498
# Energy = -0.4323277473449707
# Variance = 0.08678694069385529
#
# Step #499
# Energy = -0.4325483739376068
# Variance = 0.0742984265089035
#
# Step #500
# Energy = -0.4394495189189911
# Variance = 0.06495624035596848
#
# Saved training quantitites for step 500 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.
# Saved training quantities for the FINAL step 500 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_old.

# %%
plot_E(e_old,exact_E,16,len(e_old))
# Out:
# Final Energy -0.43512310253249276 (Exact Energy is -0.4534132086591546)
# Final Error after 500 epochs is 0.01829010612666182
# The lowest energy achieved by the model was -0.47599324584007263.
# -0.43512310253249276

# %%
plot_var(v_old,16,len(v_old))
# Out:
# Final Variance after 500 epochs is 0.09703040371338527
# 0.09703040371338527

# %% [markdown]
# ### New OneD RNN

# %%
def main():
    config = {
        'name': 'Benchmark_Data_OneD_new', # A name for each experiment
        'Lx': 4,  # number of sites in x-direction                    
        'Ly': 4,  # number of sites in the y-direction
        'V': 7.,
        'Omega': 1.,
        'delta': 1.,
        'sweep_rate':15,
        
        'nh': 32,  # number of memory/hidden units
        'lr': 1e-3,  # learning rate
        'weight_sharing': True,
        'trunc': 100,
        'seed': 1234,
        
        'RNN': 'OneD',
        'version':'New',
        'MDGRU': True,
        'VMC_epochs':0,
        'Data_epochs':200,
        
        'ns': 1000,
        'batch_size': 100,
        
        'Print':True,
        'Write_Data': True,
        'CKPT':False,
        'Plot': True
        }
    
    return Train_w_Data(config)


if __name__ == "__main__":
    model_new,e_new,v_new,c_new = main()
# Out:
# Training a one-D RNN wave function with 32 hidden units and shared weights.
# OneD RNN adapted from Heisenberg-Kagome project.
# gru_1/gru_cell_1/kernel:0 (192,)
# gru_1/gru_cell_1/recurrent_kernel:0 (3072,)
# gru_1/gru_cell_1/bias:0 (192,)
# RNNWF_dense_0/kernel:0 (64,)
# RNNWF_dense_0/bias:0 (2,)
# The sum of params is 3522
# The experimental parameters are: V = 7.0, delta = 1.0, Omega = 1.0.
# The system is an array of 4 by 4 Rydberg Atoms
# getting energy function!
# CKPT OFF. Initializing from scratch.
# Tracing!
# Tracing!
# Step #1
# Energy = 0.5703041553497314
# Variance = 15.686444282531738
#
# Step #2
# Energy = 0.10815521329641342
# Variance = 7.038118362426758
#
# Step #3
# Energy = -0.020747214555740356
# Variance = 5.02666711807251
#
# Step #4
# Energy = -0.06224316731095314
# Variance = 4.092535972595215
#
# Step #5
# Energy = -0.0297061949968338
# Variance = 4.989920139312744
#
# Step #6
# Energy = -0.01933187060058117
# Variance = 5.05437707901001
#
# Step #7
# Energy = -0.04150921851396561
# Variance = 4.142836570739746
#
# Step #8
# Energy = -0.11473602056503296
# Variance = 3.583806037902832
#
# Step #9
# Energy = -0.10378292202949524
# Variance = 3.2860515117645264
#
# Step #10
# Energy = -0.1356358528137207
# Variance = 3.3757569789886475
#
# Saved training quantitites for step 10 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_new.
# Step #11
# Energy = -0.11877729743719101
# Variance = 2.899603843688965
#
# Step #12
# Energy = -0.17603608965873718
# Variance = 2.435917854309082
#
# Step #13
# Energy = -0.16453436017036438
# Variance = 2.470036029815674
#
# Step #14
# Energy = -0.2118712216615677
# Variance = 2.0401077270507812
#
# Step #15
# Energy = -0.2182241678237915
# Variance = 1.7854748964309692
#
# Step #16
# Energy = -0.23392392694950104
# Variance = 1.476064682006836
#
# Step #17
# Energy = -0.2575322389602661
# Variance = 1.4401381015777588
#
# Step #18
# Energy = -0.25156170129776
# Variance = 1.4991096258163452
#
# Step #19
# Energy = -0.25287503004074097
# Variance = 1.467796802520752
#
# Step #20
# Energy = -0.24959303438663483
# Variance = 1.4289883375167847
#
# Saved training quantitites for step 20 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_new.
# Step #21
# Energy = -0.2582967281341553
# Variance = 1.4449214935302734
#
# Step #22
# Energy = -0.24984677135944366
# Variance = 1.5382511615753174
#
# Step #23
# Energy = -0.27583369612693787
# Variance = 1.2950102090835571
#
# Step #24
# Energy = -0.288568913936615
# Variance = 1.0913664102554321
#
# Step #25
# Energy = -0.2895847260951996
# Variance = 1.19673490524292
#
# Step #26
# Energy = -0.30263030529022217
# Variance = 1.0790419578552246
#
# Step #27
# Energy = -0.32011619210243225
# Variance = 0.8747524619102478
#
# Step #28
# Energy = -0.34025371074676514
# Variance = 0.7536288499832153
#
# Step #29
# Energy = -0.34251195192337036
# Variance = 0.751223087310791
#
# Step #30
# Energy = -0.35193198919296265
# Variance = 0.5957947969436646
#
# Saved training quantitites for step 30 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_new.
# Step #31
# Energy = -0.36048126220703125
# Variance = 0.5903026461601257
#
# Step #32
# Energy = -0.3408450186252594
# Variance = 0.6895675659179688
#
# Step #33
# Energy = -0.36546099185943604
# Variance = 0.5226983428001404
#
# Step #34
# Energy = -0.36927855014801025
# Variance = 0.5270432233810425
#
# Step #35
# Energy = -0.37262678146362305
# Variance = 0.5140506029129028
#
# Step #36
# Energy = -0.3654569685459137
# Variance = 0.5447182655334473
#
# Step #37
# Energy = -0.38248443603515625
# Variance = 0.4052280783653259
#
# Step #38
# Energy = -0.3775811195373535
# Variance = 0.5149537324905396
#
# Step #39
# Energy = -0.3671038746833801
# Variance = 0.5462415814399719
#
# Step #40
# Energy = -0.3708004057407379
# Variance = 0.4873740077018738
#
# Saved training quantitites for step 40 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_new.
# Step #41
# Energy = -0.374483197927475
# Variance = 0.45495373010635376
#
# Step #42
# Energy = -0.3872787356376648
# Variance = 0.37080273032188416
#
# Step #43
# Energy = -0.39479753375053406
# Variance = 0.31390026211738586
#
# Step #44
# Energy = -0.3941008448600769
# Variance = 0.3324596583843231
#
# Step #45
# Energy = -0.3971445560455322
# Variance = 0.3132396936416626
#
# Step #46
# Energy = -0.39905545115470886
# Variance = 0.31516027450561523
#
# Step #47
# Energy = -0.3883805274963379
# Variance = 0.3533070683479309
#
# Step #48
# Energy = -0.3774169087409973
# Variance = 0.44443970918655396
#
# Step #49
# Energy = -0.39654284715652466
# Variance = 0.32851824164390564
#
# Step #50
# Energy = -0.4046975076198578
# Variance = 0.2816688120365143
#
# Saved training quantitites for step 50 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_new.
# Step #51
# Energy = -0.39993277192115784
# Variance = 0.3086753785610199
#
# Step #52
# Energy = -0.39107248187065125
# Variance = 0.36186084151268005
#
# Step #53
# Energy = -0.4026404619216919
# Variance = 0.2918010950088501
#
# Step #54
# Energy = -0.4030206799507141
# Variance = 0.26480627059936523
#
# Step #55
# Energy = -0.39454203844070435
# Variance = 0.3281136751174927
#
# Step #56
# Energy = -0.40656664967536926
# Variance = 0.28098180890083313
#
# Step #57
# Energy = -0.4002474844455719
# Variance = 0.2847227454185486
#
# Step #58
# Energy = -0.41271257400512695
# Variance = 0.22386635839939117
#
# Step #59
# Energy = -0.4098665714263916
# Variance = 0.24027322232723236
#
# Step #60
# Energy = -0.40234094858169556
# Variance = 0.2952328026294708
#
# Saved training quantitites for step 60 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_new.
# Step #61
# Energy = -0.39751577377319336
# Variance = 0.32886406779289246
#
# Step #62
# Energy = -0.39518946409225464
# Variance = 0.2943156659603119
#
# Step #63
# Energy = -0.3951099216938019
# Variance = 0.3007146418094635
#
# Step #64
# Energy = -0.4065707325935364
# Variance = 0.2393951117992401
#
# Step #65
# Energy = -0.40642333030700684
# Variance = 0.22763101756572723
#
# Step #66
# Energy = -0.40430140495300293
# Variance = 0.26311007142066956
#
# Step #67
# Energy = -0.4030899703502655
# Variance = 0.2717655301094055
#
# Step #68
# Energy = -0.39243796467781067
# Variance = 0.3474331796169281
#
# Step #69
# Energy = -0.40148839354515076
# Variance = 0.3009952902793884
#
# Step #70
# Energy = -0.3964540660381317
# Variance = 0.3135380148887634
#
# Saved training quantitites for step 70 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_new.
# Step #71
# Energy = -0.3985522389411926
# Variance = 0.2924191951751709
#
# Step #72
# Energy = -0.39477741718292236
# Variance = 0.3512868881225586
#
# Step #73
# Energy = -0.4054691195487976
# Variance = 0.24406291544437408
#
# Step #74
# Energy = -0.41058871150016785
# Variance = 0.2471689134836197
#
# Step #75
# Energy = -0.39626988768577576
# Variance = 0.30351343750953674
#
# Step #76
# Energy = -0.4024234414100647
# Variance = 0.2942894399166107
#
# Step #77
# Energy = -0.40304335951805115
# Variance = 0.2645075023174286
#
# Step #78
# Energy = -0.4096328616142273
# Variance = 0.27281180024147034
#
# Step #79
# Energy = -0.4026064872741699
# Variance = 0.2903149425983429
#
# Step #80
# Energy = -0.41078880429267883
# Variance = 0.26396018266677856
#
# Saved training quantitites for step 80 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_new.
# Step #81
# Energy = -0.407708078622818
# Variance = 0.25742632150650024
#
# Step #82
# Energy = -0.4103752672672272
# Variance = 0.2763878107070923
#
# Step #83
# Energy = -0.4047376811504364
# Variance = 0.31566107273101807
#
# Step #84
# Energy = -0.40415576100349426
# Variance = 0.28266218304634094
#
# Step #85
# Energy = -0.40370509028434753
# Variance = 0.25484344363212585
#
# Step #86
# Energy = -0.41408079862594604
# Variance = 0.23666128516197205
#
# Step #87
# Energy = -0.4115384519100189
# Variance = 0.2398308962583542
#
# Step #88
# Energy = -0.40613311529159546
# Variance = 0.2602558732032776
#
# Step #89
# Energy = -0.41758325695991516
# Variance = 0.18243996798992157
#
# Step #90
# Energy = -0.4118248522281647
# Variance = 0.23738329112529755
#
# Saved training quantitites for step 90 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_new.
# Step #91
# Energy = -0.4015611410140991
# Variance = 0.29481324553489685
#
# Step #92
# Energy = -0.40817487239837646
# Variance = 0.2316400110721588
#
# Step #93
# Energy = -0.41219332814216614
# Variance = 0.25088268518447876
#
# Step #94
# Energy = -0.413930743932724
# Variance = 0.24154330790042877
#
# Step #95
# Energy = -0.41500285267829895
# Variance = 0.22304512560367584
#
# Step #96
# Energy = -0.4135534167289734
# Variance = 0.21127673983573914
#
# Step #97
# Energy = -0.40244075655937195
# Variance = 0.302331805229187
#
# Step #98
# Energy = -0.3977159261703491
# Variance = 0.3474232852458954
# Step #99
# Energy = -0.4214535653591156
# Variance = 0.16592377424240112
#
# Step #100
# Energy = -0.41271135210990906
# Variance = 0.2252093404531479
#
# Saved training quantitites for step 100 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_new.
# Step #101
# Energy = -0.4080137312412262
# Variance = 0.3181250989437103
#
# Step #102
# Energy = -0.4169140160083771
# Variance = 0.21805228292942047
#
# Step #103
# Energy = -0.4086340665817261
# Variance = 0.2664421498775482
#
# Step #104
# Energy = -0.41579657793045044
# Variance = 0.21480907499790192
#
# Step #105
# Energy = -0.41013550758361816
# Variance = 0.2577205002307892
#
# Step #106
# Energy = -0.4104306697845459
# Variance = 0.2327340543270111
#
# Step #107
# Energy = -0.4192867577075958
# Variance = 0.19909034669399261
#
# Step #108
# Energy = -0.41788896918296814
# Variance = 0.21303896605968475
#
# Step #109
# Energy = -0.424053430557251
# Variance = 0.19273123145103455
#
# Step #110
# Energy = -0.4143127501010895
# Variance = 0.2077624797821045
#
# Saved training quantitites for step 110 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_new.
# Step #111
# Energy = -0.40851500630378723
# Variance = 0.26338788866996765
#
# Step #112
# Energy = -0.4138522446155548
# Variance = 0.26022157073020935
#
# Step #113
# Energy = -0.4205324649810791
# Variance = 0.20126068592071533
#
# Step #114
# Energy = -0.4183555245399475
# Variance = 0.17568564414978027
#
# Step #115
# Energy = -0.41538453102111816
# Variance = 0.2219855636358261
#
# Step #116
# Energy = -0.4159349501132965
# Variance = 0.1826755404472351
#
# Step #117
# Energy = -0.4210415184497833
# Variance = 0.1926776021718979
#
# Step #118
# Energy = -0.420685350894928
# Variance = 0.1723846048116684
#
# Step #119
# Energy = -0.42098551988601685
# Variance = 0.2150743454694748
#
# Step #120
# Energy = -0.4279932379722595
# Variance = 0.17740637063980103
#
# Saved training quantitites for step 120 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_new.
# Step #121
# Energy = -0.4208603501319885
# Variance = 0.17053426802158356
#
# Step #122
# Energy = -0.420503705739975
# Variance = 0.1856808215379715
#
# Step #123
# Energy = -0.4188292324542999
# Variance = 0.1920015811920166
#
# Step #124
# Energy = -0.4248834550380707
# Variance = 0.15685272216796875
#
# Step #125
# Energy = -0.4147487282752991
# Variance = 0.23024359345436096
#
# Step #126
# Energy = -0.41730156540870667
# Variance = 0.2199988067150116
#
# Step #127
# Energy = -0.4158160984516144
# Variance = 0.2037973701953888
#
# Step #128
# Energy = -0.41947346925735474
# Variance = 0.20464634895324707
#
# Step #129
# Energy = -0.42047736048698425
# Variance = 0.20716401934623718
#
# Step #130
# Energy = -0.4277639091014862
# Variance = 0.15282520651817322
#
# Saved training quantitites for step 130 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_new.
# Step #131
# Energy = -0.4225887954235077
# Variance = 0.18864545226097107
#
# Step #132
# Energy = -0.4174298048019409
# Variance = 0.16806942224502563
#
# Step #133
# Energy = -0.42009276151657104
# Variance = 0.16591677069664001
#
# Step #134
# Energy = -0.4230896532535553
# Variance = 0.17519497871398926
#
# Step #135
# Energy = -0.42272940278053284
# Variance = 0.17468155920505524
#
# Step #136
# Energy = -0.4214724898338318
# Variance = 0.1859835833311081
#
# Step #137
# Energy = -0.4220135509967804
# Variance = 0.20442020893096924
#
# Step #138
# Energy = -0.41820982098579407
# Variance = 0.19443386793136597
#
# Step #139
# Energy = -0.4231117069721222
# Variance = 0.17279592156410217
#
# Step #140
# Energy = -0.4179408550262451
# Variance = 0.23969842493534088
#
# Saved training quantitites for step 140 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_new.
# Step #141
# Energy = -0.4215667247772217
# Variance = 0.1850346028804779
#
# Step #142
# Energy = -0.4226142466068268
# Variance = 0.18523284792900085
#
# Step #143
# Energy = -0.424923837184906
# Variance = 0.16954532265663147
#
# Step #144
# Energy = -0.42564821243286133
# Variance = 0.15749268233776093
#
# Step #145
# Energy = -0.4242875277996063
# Variance = 0.17349360883235931
#
# Step #146
# Energy = -0.4201332926750183
# Variance = 0.17202486097812653
#
# Step #147
# Energy = -0.4201686680316925
# Variance = 0.3476111888885498
#
# Step #148
# Energy = -0.4194737672805786
# Variance = 0.20321440696716309
#
# Step #149
# Energy = -0.42164456844329834
# Variance = 0.19481658935546875
#
# Step #150
# Energy = -0.4237483739852905
# Variance = 0.16624829173088074
#
# Saved training quantitites for step 150 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_new.
# Step #151
# Energy = -0.4140245020389557
# Variance = 0.26608678698539734
#
# Step #152
# Energy = -0.4274507462978363
# Variance = 0.12246475368738174
#
# Step #153
# Energy = -0.423587828874588
# Variance = 0.17551682889461517
#
# Step #154
# Energy = -0.4218296408653259
# Variance = 0.20651285350322723
#
# Step #155
# Energy = -0.41456863284111023
# Variance = 0.24892352521419525
#
# Step #156
# Energy = -0.42880314588546753
# Variance = 0.1665424257516861
#
# Step #157
# Energy = -0.42213138937950134
# Variance = 0.16559772193431854
#
# Step #158
# Energy = -0.4242238700389862
# Variance = 0.16059650480747223
#
# Step #159
# Energy = -0.4243471622467041
# Variance = 0.16584616899490356
#
# Step #160
# Energy = -0.41849538683891296
# Variance = 0.2022894322872162
#
# Saved training quantitites for step 160 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_new.
# Step #161
# Energy = -0.42997413873672485
# Variance = 0.13666602969169617
#
# Step #162
# Energy = -0.4176185727119446
# Variance = 0.21640731394290924
#
# Step #163
# Energy = -0.4268384575843811
# Variance = 0.1401037573814392
#
# Step #164
# Energy = -0.42415475845336914
# Variance = 0.17529819905757904
#
# Step #165
# Energy = -0.42270323634147644
# Variance = 0.18177847564220428
#
# Step #166
# Energy = -0.4298251271247864
# Variance = 0.14475548267364502
#
# Step #167
# Energy = -0.43309715390205383
# Variance = 0.1430022269487381
#
# Step #168
# Energy = -0.4297354519367218
# Variance = 0.13080772757530212
#
# Step #169
# Energy = -0.4249272346496582
# Variance = 0.17572733759880066
#
# Step #170
# Energy = -0.43100327253341675
# Variance = 0.16159765422344208
#
# Saved training quantitites for step 170 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_new.
# Step #171
# Energy = -0.4211258590221405
# Variance = 0.18543292582035065
#
# Step #172
# Energy = -0.4254417419433594
# Variance = 0.15847203135490417
#
# Step #173
# Energy = -0.4241841435432434
# Variance = 0.1530720293521881
#
# Step #174
# Energy = -0.42363664507865906
# Variance = 0.16441188752651215
#
# Step #175
# Energy = -0.4265285134315491
# Variance = 0.15965771675109863
#
# Step #176
# Energy = -0.4282648265361786
# Variance = 0.13680818676948547
#
# Step #177
# Energy = -0.43086299300193787
# Variance = 0.10535652190446854
#
# Step #178
# Energy = -0.4195297956466675
# Variance = 0.1995192915201187
#
# Step #179
# Energy = -0.4309145510196686
# Variance = 0.1138760969042778
#
# Step #180
# Energy = -0.4267939329147339
# Variance = 0.17684629559516907
#
# Saved training quantitites for step 180 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_new.
# Step #181
# Energy = -0.42624297738075256
# Variance = 0.164870947599411
#
# Step #182
# Energy = -0.42295604944229126
# Variance = 0.18364934623241425
#
# Step #183
# Energy = -0.4295729398727417
# Variance = 0.1227111965417862
#
# Step #184
# Energy = -0.42538899183273315
# Variance = 0.14323434233665466
#
# Step #185
# Energy = -0.4236511290073395
# Variance = 0.1814073771238327
#
# Step #186
# Energy = -0.4296371638774872
# Variance = 0.13540060818195343
#
# Step #187
# Energy = -0.4329948425292969
# Variance = 0.12826912105083466
#
# Step #188
# Energy = -0.42871570587158203
# Variance = 0.12887319922447205
#
# Step #189
# Energy = -0.4328233003616333
# Variance = 0.11133836209774017
#
# Step #190
# Energy = -0.4236754775047302
# Variance = 0.151422381401062
#
# Saved training quantitites for step 190 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_new.
# Step #191
# Energy = -0.42570778727531433
# Variance = 0.13699057698249817
#
# Step #192
# Energy = -0.42819494009017944
# Variance = 0.1397322416305542
#
# Step #193
# Energy = -0.4311979115009308
# Variance = 0.1303446739912033
#
# Step #194
# Energy = -0.43096300959587097
# Variance = 0.13690005242824554
#
# Step #195
# Energy = -0.431143581867218
# Variance = 0.13874021172523499
#
# Step #196
# Energy = -0.4315422475337982
# Variance = 0.1406823694705963
#
# Step #197
# Energy = -0.435237318277359
# Variance = 0.12286154925823212
#
# Step #198
# Energy = -0.42663586139678955
# Variance = 0.14600010216236115
#
# Step #199
# Energy = -0.4321747422218323
# Variance = 0.1043904721736908
#
# Step #200
# Energy = -0.43472692370414734
# Variance = 0.11360803246498108
#
# Saved training quantitites for step 200 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_new.
# Saved training quantities for the FINAL step 200 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_new.

# %%
plot_E(e_new,exact_E,16,len(e_new))
# Out:
# Final Energy -0.43031082219547695 (Exact Energy is -0.4534132086591546)
# Final Error after 200 epochs is 0.023102386463677627
# The lowest energy achieved by the model was -0.435237318277359.
# -0.43031082219547695

# %%
plot_var(v_new,16,len(v_new))
# Out:
# Final Variance after 200 epochs is 0.13296024998029074
# 0.13296024998029074

# %%
import matplotlib.pylab as plt

# %%
plt.plot(np.arange(len(v_new)),v_new)
plt.ylim(0,50)
plt.show()

# %% [markdown]
# # Frankenstein Model

# %%
import numpy as np
import tensorflow as tf

# %%
from train_data import Train_w_Data

# %%
def main():
    config = {
        'name': 'Benchmark_Data_OneD_tests', # A name for each experiment
        'Lx': 4,  # number of sites in x-direction                    
        'Ly': 4,  # number of sites in the y-direction
        'V': 7.,
        'Omega': 1.,
        'delta': 1.,
        'sweep_rate':15,
        
        'nh': 32,  # number of memory/hidden units
        'lr': 1e-3,  # learning rate
        'weight_sharing': True,
        'trunc': 100,
        'seed': 1234,
        
        'RNN': 'OneD',
        'version':'Old',
        'MDGRU': True,
        'VMC_epochs':0,
        'Data_epochs':200,
        
        'ns': 1000,
        'batch_size': 100,
        
        'Print':True,
        'Write_Data': True,
        'CKPT':False,
        'Plot': True
        }
    
    return Train_w_Data(config)


if __name__ == "__main__":
    model_new,e_new,v_new,c_new = main()
# Out:
# 2022-12-13 16:00:37.626884: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Training a one-D RNN wave function with 32 hidden units and shared weights.
# OneD RNN used in previous Rydberg project.
# gru/gru_cell/kernel:0 (192,)
# gru/gru_cell/recurrent_kernel:0 (3072,)
# gru/gru_cell/bias:0 (192,)
# dense/kernel:0 (64,)
# dense/bias:0 (2,)
# The sum of params is 3522
# The experimental parameters are: V = 7.0, delta = 1.0, Omega = 1.0.
# The system is an array of 4 by 4 Rydberg Atoms
# getting energy function!
# CKPT OFF. Initializing from scratch.
# Tracing!
# Tracing!
# Step #1
# Energy = 0.5703042149543762
# Variance = 15.686445236206055
#
# Step #2
# Energy = 0.10815521329641342
# Variance = 7.038118839263916
#
# Step #3
# Energy = -0.02074720896780491
# Variance = 5.02666711807251
#
# Step #4
# Energy = -0.06224315986037254
# Variance = 4.092535495758057
#
# Step #5
# Energy = -0.0297061949968338
# Variance = 4.989920139312744
#
# Step #6
# Energy = -0.01933187246322632
# Variance = 5.05437707901001
#
# Step #7
# Energy = -0.04150921851396561
# Variance = 4.142836570739746
#
# Step #8
# Energy = -0.11473602056503296
# Variance = 3.583805799484253
#
# Step #9
# Energy = -0.10378292202949524
# Variance = 3.2860515117645264
#
# Step #10
# Energy = -0.1356358528137207
# Variance = 3.3757572174072266
#
# Saved training quantitites for step 10 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_tests.
# Step #11
# Energy = -0.11877728998661041
# Variance = 2.899604082107544
#
# Step #12
# Energy = -0.17603608965873718
# Variance = 2.435917854309082
#
# Step #13
# Energy = -0.16453437507152557
# Variance = 2.470036029815674
#
# Step #14
# Energy = -0.2118712067604065
# Variance = 2.0401077270507812
#
# Step #15
# Energy = -0.2182241529226303
# Variance = 1.7854748964309692
#
# Step #16
# Energy = -0.23392392694950104
# Variance = 1.476064682006836
#
# Step #17
# Energy = -0.2575322389602661
# Variance = 1.4401381015777588
#
# Step #18
# Energy = -0.2515616714954376
# Variance = 1.4991096258163452
#
# Step #19
# Energy = -0.25287503004074097
# Variance = 1.467796802520752
#
# Step #20
# Energy = -0.24959304928779602
# Variance = 1.4289883375167847
#
# Saved training quantitites for step 20 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_tests.
# Step #21
# Energy = -0.2582967281341553
# Variance = 1.4449214935302734
#
# Step #22
# Energy = -0.24984677135944366
# Variance = 1.5382513999938965
#
# Step #23
# Energy = -0.27583372592926025
# Variance = 1.2950102090835571
#
# Step #24
# Energy = -0.288568913936615
# Variance = 1.0913664102554321
#
# Step #25
# Energy = -0.2895847260951996
# Variance = 1.19673490524292
#
# Step #26
# Energy = -0.30263030529022217
# Variance = 1.079041838645935
#
# Step #27
# Energy = -0.32011616230010986
# Variance = 0.8747525811195374
#
# Step #28
# Energy = -0.3402537405490875
# Variance = 0.7536289095878601
#
# Step #29
# Energy = -0.34251195192337036
# Variance = 0.7512231469154358
#
# Step #30
# Energy = -0.35193198919296265
# Variance = 0.5957948565483093
#
# Saved training quantitites for step 30 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_tests.
# Step #31
# Energy = -0.36048126220703125
# Variance = 0.5903024673461914
#
# Step #32
# Energy = -0.3408450186252594
# Variance = 0.689567506313324
#
# Step #33
# Energy = -0.36546099185943604
# Variance = 0.5226982831954956
#
# Step #34
# Energy = -0.3692784905433655
# Variance = 0.5270431041717529
#
# Step #35
# Energy = -0.37262678146362305
# Variance = 0.5140505433082581
#
# Step #36
# Energy = -0.3654569685459137
# Variance = 0.5447182655334473
#
# Step #37
# Energy = -0.38248443603515625
# Variance = 0.4052281379699707
#
# Step #38
# Energy = -0.3775811195373535
# Variance = 0.5149537324905396
#
# Step #39
# Energy = -0.3671038746833801
# Variance = 0.5462416410446167
#
# Step #40
# Energy = -0.3708004057407379
# Variance = 0.487373948097229
#
# Saved training quantitites for step 40 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_tests.
# Step #41
# Energy = -0.374483197927475
# Variance = 0.45495373010635376
#
# Step #42
# Energy = -0.3872787356376648
# Variance = 0.37080273032188416
#
# Step #43
# Energy = -0.39479753375053406
# Variance = 0.31390026211738586
#
# Step #44
# Energy = -0.3941008448600769
# Variance = 0.3324596881866455
#
# Step #45
# Energy = -0.39714452624320984
# Variance = 0.3132396936416626
#
# Step #46
# Energy = -0.39905548095703125
# Variance = 0.31516021490097046
#
# Step #47
# Energy = -0.3883805274963379
# Variance = 0.35330700874328613
#
# Step #48
# Energy = -0.3774169087409973
# Variance = 0.4444396495819092
#
# Step #49
# Energy = -0.39654287695884705
# Variance = 0.32851824164390564
#
# Step #50
# Energy = -0.4046975374221802
# Variance = 0.2816688120365143
#
# Saved training quantitites for step 50 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_tests.
# Step #51
# Energy = -0.39993277192115784
# Variance = 0.3086753785610199
#
# Step #52
# Energy = -0.39107248187065125
# Variance = 0.36186084151268005
#
# Step #53
# Energy = -0.4026404619216919
# Variance = 0.2918010652065277
#
# Step #54
# Energy = -0.4030206799507141
# Variance = 0.26480627059936523
#
# Step #55
# Energy = -0.39454203844070435
# Variance = 0.3281136453151703
#
# Step #56
# Energy = -0.40656664967536926
# Variance = 0.28098180890083313
#
# Step #57
# Energy = -0.4002474844455719
# Variance = 0.28472277522087097
#
# Step #58
# Energy = -0.41271257400512695
# Variance = 0.22386634349822998
#
# Step #59
# Energy = -0.4098665714263916
# Variance = 0.24027325212955475
#
# Step #60
# Energy = -0.40234094858169556
# Variance = 0.2952328324317932
#
# Saved training quantitites for step 60 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_tests.
# Step #61
# Energy = -0.39751577377319336
# Variance = 0.3288640081882477
#
# Step #62
# Energy = -0.39518943428993225
# Variance = 0.2943156957626343
#
# Step #63
# Energy = -0.3951099216938019
# Variance = 0.30071473121643066
#
# Step #64
# Energy = -0.4065707325935364
# Variance = 0.23939508199691772
#
# Step #65
# Energy = -0.40642333030700684
# Variance = 0.22763098776340485
#
# Step #66
# Energy = -0.40430140495300293
# Variance = 0.26311004161834717
#
# Step #67
# Energy = -0.4030899405479431
# Variance = 0.27176547050476074
#
# Step #68
# Energy = -0.3924379348754883
# Variance = 0.3474331498146057
#
# Step #69
# Energy = -0.40148839354515076
# Variance = 0.3009953200817108
#
# Step #70
# Energy = -0.3964540958404541
# Variance = 0.3135380148887634
#
# Saved training quantitites for step 70 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_tests.
# Step #71
# Energy = -0.3985522389411926
# Variance = 0.2924191951751709
#
# Step #72
# Energy = -0.39477741718292236
# Variance = 0.35128694772720337
#
# Step #73
# Energy = -0.4054691195487976
# Variance = 0.24406293034553528
#
# Step #74
# Energy = -0.41058871150016785
# Variance = 0.24716895818710327
#
# Step #75
# Energy = -0.39626988768577576
# Variance = 0.30351343750953674
#
# Step #76
# Energy = -0.4024234116077423
# Variance = 0.2942894995212555
#
# Step #77
# Energy = -0.40304335951805115
# Variance = 0.2645075023174286
#
# Step #78
# Energy = -0.4096328020095825
# Variance = 0.2728117108345032
#
# Step #79
# Energy = -0.4026064872741699
# Variance = 0.2903149425983429
#
# Step #80
# Energy = -0.41078874468803406
# Variance = 0.26396021246910095
#
# Saved training quantitites for step 80 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_tests.
# Step #81
# Energy = -0.407708078622818
# Variance = 0.25742632150650024
#
# Step #82
# Energy = -0.4103752672672272
# Variance = 0.2763877511024475
#
# Step #83
# Energy = -0.4047376811504364
# Variance = 0.31566107273101807
#
# Step #84
# Energy = -0.40415579080581665
# Variance = 0.28266221284866333
#
# Step #85
# Energy = -0.4037051200866699
# Variance = 0.25484350323677063
#
# Step #86
# Energy = -0.4140808582305908
# Variance = 0.23666130006313324
#
# Step #87
# Energy = -0.4115384519100189
# Variance = 0.2398308515548706
#
# Step #88
# Energy = -0.40613314509391785
# Variance = 0.2602558732032776
#
# Step #89
# Energy = -0.4175832271575928
# Variance = 0.18243993818759918
#
# Step #90
# Energy = -0.4118248522281647
# Variance = 0.23738326132297516
#
# Saved training quantitites for step 90 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_tests.
# Step #91
# Energy = -0.4015611410140991
# Variance = 0.29481321573257446
#
# Step #92
# Energy = -0.40817487239837646
# Variance = 0.23163995146751404
#
# Step #93
# Energy = -0.41219332814216614
# Variance = 0.25088268518447876
#
# Step #94
# Energy = -0.413930743932724
# Variance = 0.24154327809810638
#
# Step #95
# Energy = -0.41500285267829895
# Variance = 0.22304511070251465
#
# Step #96
# Energy = -0.4135534167289734
# Variance = 0.21127673983573914
#
# Step #97
# Energy = -0.40244072675704956
# Variance = 0.3023317754268646
#
# Step #98
# Energy = -0.39771586656570435
# Variance = 0.3474232852458954
# Step #99
# Energy = -0.4214535653591156
# Variance = 0.16592377424240112
#
# Step #100
# Energy = -0.41271135210990906
# Variance = 0.2252092808485031
#
# Saved training quantitites for step 100 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_tests.
# Step #101
# Energy = -0.4080137610435486
# Variance = 0.31812506914138794
#
# Step #102
# Energy = -0.4169140160083771
# Variance = 0.21805225312709808
#
# Step #103
# Energy = -0.4086340665817261
# Variance = 0.26644209027290344
#
# Step #104
# Energy = -0.41579654812812805
# Variance = 0.2148090898990631
#
# Step #105
# Energy = -0.41013550758361816
# Variance = 0.2577205300331116
#
# Step #106
# Energy = -0.4104306995868683
# Variance = 0.23273403942584991
#
# Step #107
# Energy = -0.4192867577075958
# Variance = 0.19909034669399261
#
# Step #108
# Energy = -0.41788896918296814
# Variance = 0.21303895115852356
#
# Step #109
# Energy = -0.4240534007549286
# Variance = 0.19273117184638977
#
# Step #110
# Energy = -0.4143127501010895
# Variance = 0.2077624797821045
#
# Saved training quantitites for step 110 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_tests.
# Step #111
# Energy = -0.40851500630378723
# Variance = 0.26338788866996765
#
# Step #112
# Energy = -0.4138522446155548
# Variance = 0.2602216303348541
#
# Step #113
# Energy = -0.4205324649810791
# Variance = 0.20126062631607056
#
# Step #114
# Energy = -0.4183555245399475
# Variance = 0.17568561434745789
#
# Step #115
# Energy = -0.41538453102111816
# Variance = 0.2219855785369873
#
# Step #116
# Energy = -0.4159349501132965
# Variance = 0.1826755255460739
#
# Step #117
# Energy = -0.4210415184497833
# Variance = 0.1926776021718979
#
# Step #118
# Energy = -0.42068538069725037
# Variance = 0.17238469421863556
#
# Step #119
# Energy = -0.42098551988601685
# Variance = 0.21507439017295837
#
# Step #120
# Energy = -0.4279932379722595
# Variance = 0.1774064302444458
#
# Saved training quantitites for step 120 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_tests.
# Step #121
# Energy = -0.4208603501319885
# Variance = 0.17053425312042236
#
# Step #122
# Energy = -0.4205036759376526
# Variance = 0.1856808364391327
#
# Step #123
# Energy = -0.4188292324542999
# Variance = 0.1920015513896942
#
# Step #124
# Energy = -0.42488348484039307
# Variance = 0.15685269236564636
#
# Step #125
# Energy = -0.4147487282752991
# Variance = 0.23024356365203857
#
# Step #126
# Energy = -0.41730156540870667
# Variance = 0.21999883651733398
#
# Step #127
# Energy = -0.4158160984516144
# Variance = 0.2037973701953888
#
# Step #128
# Energy = -0.4194734990596771
# Variance = 0.20464631915092468
#
# Step #129
# Energy = -0.42047736048698425
# Variance = 0.20716404914855957
#
# Step #130
# Energy = -0.4277639091014862
# Variance = 0.15282519161701202
#
# Saved training quantitites for step 130 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_tests.
# Step #131
# Energy = -0.4225888252258301
# Variance = 0.18864545226097107
#
# Step #132
# Energy = -0.4174298048019409
# Variance = 0.16806945204734802
#
# Step #133
# Energy = -0.42009276151657104
# Variance = 0.1659168154001236
#
# Step #134
# Energy = -0.4230896532535553
# Variance = 0.17519499361515045
#
# Step #135
# Energy = -0.4227294325828552
# Variance = 0.17468160390853882
#
# Step #136
# Energy = -0.4214725196361542
# Variance = 0.1859835833311081
#
# Step #137
# Energy = -0.4220135509967804
# Variance = 0.2044202983379364
#
# Step #138
# Energy = -0.41820982098579407
# Variance = 0.19443382322788239
#
# Step #139
# Energy = -0.4231117069721222
# Variance = 0.17279589176177979
#
# Step #140
# Energy = -0.4179408550262451
# Variance = 0.2396984100341797
#
# Saved training quantitites for step 140 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_tests.
# Step #141
# Energy = -0.4215667247772217
# Variance = 0.1850346028804779
#
# Step #142
# Energy = -0.42261427640914917
# Variance = 0.18523290753364563
#
# Step #143
# Energy = -0.424923837184906
# Variance = 0.16954532265663147
#
# Step #144
# Energy = -0.42564821243286133
# Variance = 0.15749268233776093
#
# Step #145
# Energy = -0.4242875277996063
# Variance = 0.1734936237335205
#
# Step #146
# Energy = -0.4201332926750183
# Variance = 0.1720248907804489
#
# Step #147
# Energy = -0.4201686680316925
# Variance = 0.34761106967926025
#
# Step #148
# Energy = -0.4194737672805786
# Variance = 0.20321446657180786
#
# Step #149
# Energy = -0.42164453864097595
# Variance = 0.1948166787624359
#
# Step #150
# Energy = -0.4237483739852905
# Variance = 0.1662483811378479
#
# Saved training quantitites for step 150 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_tests.
# Step #151
# Energy = -0.4140245020389557
# Variance = 0.266086608171463
#
# Step #152
# Energy = -0.4274507462978363
# Variance = 0.12246476858854294
#
# Step #153
# Energy = -0.4235877990722656
# Variance = 0.17551687359809875
#
# Step #154
# Energy = -0.4218296408653259
# Variance = 0.20651288330554962
#
# Step #155
# Energy = -0.41456863284111023
# Variance = 0.24892348051071167
#
# Step #156
# Energy = -0.42880314588546753
# Variance = 0.1665424257516861
#
# Step #157
# Energy = -0.42213138937950134
# Variance = 0.16559772193431854
#
# Step #158
# Energy = -0.424223929643631
# Variance = 0.160596564412117
#
# Step #159
# Energy = -0.4243471622467041
# Variance = 0.16584622859954834
#
# Step #160
# Energy = -0.41849541664123535
# Variance = 0.2022894322872162
#
# Saved training quantitites for step 160 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_tests.
# Step #161
# Energy = -0.42997416853904724
# Variance = 0.13666604459285736
#
# Step #162
# Energy = -0.4176185429096222
# Variance = 0.21640731394290924
#
# Step #163
# Energy = -0.4268384277820587
# Variance = 0.1401037573814392
#
# Step #164
# Energy = -0.42415475845336914
# Variance = 0.17529821395874023
#
# Step #165
# Energy = -0.42270323634147644
# Variance = 0.18177850544452667
#
# Step #166
# Energy = -0.4298251271247864
# Variance = 0.14475548267364502
#
# Step #167
# Energy = -0.43309715390205383
# Variance = 0.14300225675106049
#
# Step #168
# Energy = -0.4297354519367218
# Variance = 0.13080774247646332
#
# Step #169
# Energy = -0.4249272346496582
# Variance = 0.17572729289531708
#
# Step #170
# Energy = -0.43100327253341675
# Variance = 0.1615976244211197
#
# Saved training quantitites for step 170 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_tests.
# Step #171
# Energy = -0.4211258590221405
# Variance = 0.18543297052383423
#
# Step #172
# Energy = -0.425441712141037
# Variance = 0.15847203135490417
#
# Step #173
# Energy = -0.4241841435432434
# Variance = 0.1530720591545105
#
# Step #174
# Energy = -0.42363664507865906
# Variance = 0.16441190242767334
#
# Step #175
# Energy = -0.4265285134315491
# Variance = 0.15965774655342102
#
# Step #176
# Energy = -0.4282648265361786
# Variance = 0.13680818676948547
#
# Step #177
# Energy = -0.43086302280426025
# Variance = 0.10535649955272675
#
# Step #178
# Energy = -0.4195297658443451
# Variance = 0.1995193511247635
#
# Step #179
# Energy = -0.4309145510196686
# Variance = 0.11387614160776138
#
# Step #180
# Energy = -0.4267939329147339
# Variance = 0.1768462359905243
#
# Saved training quantitites for step 180 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_tests.
# Step #181
# Energy = -0.42624297738075256
# Variance = 0.164870947599411
#
# Step #182
# Energy = -0.42295604944229126
# Variance = 0.18364936113357544
#
# Step #183
# Energy = -0.4295729100704193
# Variance = 0.12271123379468918
#
# Step #184
# Energy = -0.42538899183273315
# Variance = 0.14323437213897705
#
# Step #185
# Energy = -0.4236511290073395
# Variance = 0.1814073622226715
#
# Step #186
# Energy = -0.4296371340751648
# Variance = 0.135400652885437
#
# Step #187
# Energy = -0.4329948425292969
# Variance = 0.12826916575431824
#
# Step #188
# Energy = -0.42871570587158203
# Variance = 0.12887319922447205
#
# Step #189
# Energy = -0.4328233003616333
# Variance = 0.11133836954832077
#
# Step #190
# Energy = -0.4236755073070526
# Variance = 0.15142245590686798
#
# Saved training quantitites for step 190 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_tests.
# Step #191
# Energy = -0.42570778727531433
# Variance = 0.13699065148830414
#
# Step #192
# Energy = -0.42819494009017944
# Variance = 0.1397322714328766
#
# Step #193
# Energy = -0.4311979413032532
# Variance = 0.13034465909004211
#
# Step #194
# Energy = -0.43096300959587097
# Variance = 0.1368999183177948
#
# Step #195
# Energy = -0.431143581867218
# Variance = 0.13874033093452454
#
# Step #196
# Energy = -0.4315422773361206
# Variance = 0.1406824290752411
#
# Step #197
# Energy = -0.4352372884750366
# Variance = 0.12286148220300674
#
# Step #198
# Energy = -0.42663586139678955
# Variance = 0.14600008726119995
# Step #199
# Energy = -0.43217477202415466
# Variance = 0.10439049452543259
#
# Step #200
# Energy = -0.43472692370414734
# Variance = 0.11360810697078705
#
# Saved training quantitites for step 200 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_tests.
# Saved training quantities for the FINAL step 200 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD_tests.
