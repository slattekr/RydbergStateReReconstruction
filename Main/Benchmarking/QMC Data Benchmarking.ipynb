# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import tensorflow as tf

# %%
from train_data import Train_w_Data

# %%
import sys
sys.path.append('..')
from dset_helpers import load_exact_Es
from plots import plot_E, plot_var, plot_loss

# %%
exact_E = load_exact_Es(4)

# %% [markdown]
# # One-D, Data

# %%
def main():
    config = {
        'name': 'Benchmark_Data_OneD', # A name for each experiment
        'Lx': 4,  # number of sites in x-direction                    
        'Ly': 4,  # number of sites in the y-direction
        'V': 7.,
        'Omega': 1.,
        'delta': 1.,
        'sweep_rate':15,
        
        'nh': 32,  # number of memory/hidden units
        'lr': 1e-3,  # learning rate
        'weight_sharing': True,
        'trunc': 100,
        'seed': 1234,
        
        'RNN': 'OneD',
        'MDGRU': True,
        'VMC_epochs':0,
        'Data_epochs':200,
        
        'ns': 1000,
        'batch_size': 100,
        
        'Print':True,
        'Write_Data': True,
        'CKPT':True,
        'Plot': True
        }
    
    return Train_w_Data(config)


if __name__ == "__main__":
    model,e,v,c = main()
# Out:
# 2022-12-08 21:26:25.472011: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Training a one-D RNN wave function with 32 hidden units and shared weights.
# gru/gru_cell/kernel:0 (192,)
# gru/gru_cell/recurrent_kernel:0 (3072,)
# gru/gru_cell/bias:0 (192,)
# RNNWF_dense_0/kernel:0 (64,)
# RNNWF_dense_0/bias:0 (2,)
# The sum of params is 3522
# The experimental parameters are: V = 7.0, delta = 1.0, Omega = 1.0.
# The system is an array of 4 by 4 Rydberg Atoms
# getting energy function!
# CKPT ON and ckpt found.
# Restored from ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD/ckpt-21
# Continuing at step 0
# Tracing!
# Step #1
# Energy = -0.5617348551750183
# Variance = 9.341094970703125
#
# Step #2
# Energy = -0.6754217147827148
# Variance = 97.52713775634766
#
# Step #3
# Energy = -0.6088328957557678
# Variance = 34.73033142089844
#
# Step #4
# Energy = -0.5866498947143555
# Variance = 20.78533935546875
#
# Step #5
# Energy = -0.6106751561164856
# Variance = 16.192777633666992
#
# Step #6
# Energy = -0.6336262226104736
# Variance = 22.817975997924805
#
# Step #7
# Energy = -0.5756325125694275
# Variance = 8.896241188049316
#
# Step #8
# Energy = -0.625438928604126
# Variance = 16.44195556640625
#
# Step #9
# Energy = -0.6165704131126404
# Variance = 16.844152450561523
#
# Step #10
# Energy = -0.6215441823005676
# Variance = 50.051048278808594
#
# 50.051048278808594  VS  10000
# Saved checkpoint for step 10 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD.
# Saved training quantitites for step 10 in ./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD.
# Step #11
# Energy = -0.559626579284668
# Variance = 5.555301189422607
#
# Step #12
# Energy = -0.590221643447876
# Variance = 14.28927993774414
#
# Step #13
# Energy = -0.5821739435195923
# Variance = 7.135722637176514
#
# Step #14
# Energy = -0.6299347877502441
# Variance = 59.29914093017578
#
# Step #15
# Energy = -0.7236002087593079
# Variance = 88.3139877319336
#
# Step #16
# Energy = -0.5814128518104553
# Variance = 12.183601379394531
#
# Step #17
# Energy = -0.6346526741981506
# Variance = 37.36126708984375
#
# Step #18
# Energy = -0.6193323731422424
# Variance = 43.07990646362305
#
# Step #19
# Energy = -0.6418266892433167
# Variance = 39.3287467956543
#
# Step #20
# Energy = -0.7172961235046387
# Variance = 296.2604064941406
#
# 296.2604064941406  VS  29.462805461883548
# Variance exploding. Earlier ckpt kept.
# Step #21
# Energy = -0.7622889280319214
# Variance = 223.33749389648438
#
# Step #22
# Energy = -0.7411267161369324
# Variance = 300.2848205566406
#
# Step #23
# Energy = -0.6369160413742065
# Variance = 20.790733337402344
#
# Step #24
# Energy = -0.6292124390602112
# Variance = 54.29026794433594
#
# Step #25
# Energy = -0.5718816518783569
# Variance = 9.678142547607422
#
# Step #26
# Energy = -0.6861817836761475
# Variance = 227.6230926513672
#
# Step #27
# Energy = -0.5763183832168579
# Variance = 40.28792190551758
#
# Step #28
# Energy = -0.6700377464294434
# Variance = 121.75213623046875
#
# Step #29
# Energy = -0.7374475002288818
# Variance = 184.1220245361328
#
# Step #30
# Energy = -0.5847927927970886
# Variance = 15.992243766784668
#
# 15.992243766784668  VS  0
# Variance exploding. Earlier ckpt kept.
# Step #31
# Energy = -0.6013103127479553
# Variance = 14.453482627868652
#
# Step #32
# Energy = -0.6450265049934387
# Variance = 53.07036209106445
#
# Step #33
# Energy = -0.5641241669654846
# Variance = 5.525710105895996
#
# Step #34
# Energy = -0.659343421459198
# Variance = 37.14789962768555
#
# Step #35
# Energy = -0.5578791499137878
# Variance = 8.65392780303955
#
# Step #36
# Energy = -0.5948000550270081
# Variance = 22.884601593017578
#
# Step #37
# Energy = -0.5665099024772644
# Variance = 4.844721794128418
#
# Step #38
# Energy = -0.5881296992301941
# Variance = 10.205416679382324
#
# Step #39
# Energy = -0.7791032791137695
# Variance = 183.26780700683594
#
# Step #40
# Energy = -0.8751317262649536
# Variance = 182.2683563232422
#
# 182.2683563232422  VS  0
# Variance exploding. Earlier ckpt kept.
# Step #41
# Energy = -0.6960853934288025
# Variance = 108.27400970458984
#
# Step #42
# Energy = -0.6170452833175659
# Variance = 20.076454162597656
#
# Step #43
# Energy = -0.6646268963813782
# Variance = 37.682125091552734
#
# Step #44
# Energy = -0.5763458013534546
# Variance = 8.137922286987305
#
# Step #45
# Energy = -0.6741933822631836
# Variance = 58.22857666015625
#
# Step #46
# Energy = -0.6541059613227844
# Variance = 188.9737091064453
#
# Step #47
# Energy = -0.6561994552612305
# Variance = 39.76442337036133
#
# Step #48
# Energy = -0.6124732494354248
# Variance = 21.317153930664062
#
# Step #49
# Energy = -0.5410236716270447
# Variance = 5.194393157958984
#
# Step #50
# Energy = -0.5843084454536438
# Variance = 12.867168426513672
#
# 12.867168426513672  VS  0
# Variance exploding. Earlier ckpt kept.
# Step #51
# Energy = -0.6358910202980042
# Variance = 36.97298812866211
#
# Step #52
# Energy = -0.6217455267906189
# Variance = 11.929369926452637
#
# Step #53
# Energy = -0.5854287147521973
# Variance = 9.438891410827637
#
# Step #54
# Energy = -0.5961912870407104
# Variance = 16.1212100982666
#
# Step #55
# Energy = -0.5494781732559204
# Variance = 4.80633544921875
#
# Step #56
# Energy = -0.7103093266487122
# Variance = 179.3900604248047
#
# Step #57
# Energy = -0.6486539840698242
# Variance = 32.978538513183594
#
# Step #58
# Energy = -0.6582524180412292
# Variance = 24.493675231933594
#
# Step #59
# Energy = -0.5899580121040344
# Variance = 13.471855163574219
#
# Step #60
# Energy = -0.599197506904602
# Variance = 19.737018585205078
#
# 19.737018585205078  VS  0
# Variance exploding. Earlier ckpt kept.
# Step #61
# Energy = -0.6020686626434326
# Variance = 26.9389591217041
#
# Step #62
# Energy = -0.6115333437919617
# Variance = 16.37796401977539
#
# Step #63
# Energy = -0.6821830868721008
# Variance = 114.35388946533203
#
# Step #64
# Energy = -0.5879096388816833
# Variance = 21.8487491607666
#
# Step #65
# Energy = -0.7111438512802124
# Variance = 146.49655151367188
#
# Step #66
# Energy = -0.6220680475234985
# Variance = 18.802438735961914
#
# Step #67
# Energy = -0.572396993637085
# Variance = 8.94868278503418
#
# Step #68
# Energy = -0.5831478238105774
# Variance = 23.10654640197754
#
# Step #69
# Energy = -0.6355979442596436
# Variance = 26.120519638061523
#
# Step #70
# Energy = -0.5923885703086853
# Variance = 9.305488586425781
#
# 9.305488586425781  VS  0
# Variance exploding. Earlier ckpt kept.
# Step #71
# Energy = -0.6320905089378357
# Variance = 33.057796478271484
#
# Step #72
# Energy = -0.5964130163192749
# Variance = 32.540130615234375
#
# Step #73
# Energy = -0.6561471223831177
# Variance = 110.79219818115234
#
# Step #74
# Energy = -0.6748703122138977
# Variance = 46.26140594482422
#
# Step #75
# Energy = -0.6703283786773682
# Variance = 51.01572799682617
#
# Step #76
# Energy = -0.5562728047370911
# Variance = 7.521017074584961
#
# Step #77
# Energy = -0.5815454721450806
# Variance = 13.234427452087402
#
# Step #78
# Energy = -0.6564418077468872
# Variance = 103.7646255493164
#
# Step #79
# Energy = -0.7000830173492432
# Variance = 146.21810913085938
#
# Step #80
# Energy = -0.5890787839889526
# Variance = 11.447107315063477
#
# 11.447107315063477  VS  0
# Variance exploding. Earlier ckpt kept.
# Step #81
# Energy = -0.6607263088226318
# Variance = 127.79252624511719
#
# Step #82
# Energy = -0.5680593848228455
# Variance = 9.804875373840332
#
# Step #83
# Energy = -0.55785071849823
# Variance = 25.348562240600586
#
# Step #84
# Energy = -0.6104916930198669
# Variance = 14.576713562011719
#
# Step #85
# Energy = -0.6192302107810974
# Variance = 39.13364028930664
#
# Step #86
# Energy = -0.5667409896850586
# Variance = 9.921526908874512
#
# Step #87
# Energy = -0.577157199382782
# Variance = 32.01534652709961
#
# Step #88
# Energy = -0.5800075531005859
# Variance = 7.872228145599365
#
# Step #89
# Energy = -0.5650216341018677
# Variance = 10.338866233825684
#
# Step #90
# Energy = -0.5859795212745667
# Variance = 12.74220085144043
#
# 12.74220085144043  VS  0
# Variance exploding. Earlier ckpt kept.
# Step #91
# Energy = -0.7419496774673462
# Variance = 168.03065490722656
#
# Step #92
# Energy = -0.6681038737297058
# Variance = 96.94003295898438
#
# Step #93
# Energy = -0.5934745073318481
# Variance = 19.867399215698242
#
# Step #94
# Energy = -0.8142719864845276
# Variance = 546.6268920898438
#
# Step #95
# Energy = -0.6668353080749512
# Variance = 43.29079055786133
#
# Step #96
# Energy = -0.61155766248703
# Variance = 22.672649383544922
#
# Step #97
# Energy = -0.6509066224098206
# Variance = 58.40800094604492
#
# Step #98
# Energy = -0.6476638317108154
# Variance = 51.60723114013672
#
# Step #99
# Energy = -0.5922749042510986
# Variance = 16.829021453857422
#
# Step #100
# Energy = -0.5659487247467041
# Variance = 6.044029235839844
#
# 6.044029235839844  VS  0
# Variance exploding. Earlier ckpt kept.
# Step #101
# Energy = -1.0262138843536377
# Variance = 2752.09912109375
#
# Step #102
# Energy = -0.5893617272377014
# Variance = 41.58161926269531
#
# Step #103
# Energy = -0.6306113004684448
# Variance = 25.808969497680664
#
# Step #104
# Energy = -0.6491722464561462
# Variance = 52.9725456237793
#
# Step #105
# Energy = -0.6385989189147949
# Variance = 47.79058837890625
#
# Step #106
# Energy = -0.6443583965301514
# Variance = 22.726049423217773
#
# Step #107
# Energy = -0.6366627812385559
# Variance = 49.1227912902832
#
# Step #108
# Energy = -0.6339898705482483
# Variance = 25.46934700012207
#
# Step #109
# Energy = -0.5931767821311951
# Variance = 16.058502197265625
#
# Step #110
# Energy = -0.6661683320999146
# Variance = 22.314199447631836
#
# 22.314199447631836  VS  0
# Variance exploding. Earlier ckpt kept.
# Step #111
# Energy = -0.692258894443512
# Variance = 80.64755249023438
#
# Step #112
# Energy = -0.737518310546875
# Variance = 181.87225341796875
#
# Step #113
# Energy = -0.6046636700630188
# Variance = 18.491195678710938
#
# Step #114
# Energy = -0.6561500430107117
# Variance = 48.91261672973633
#
# Step #115
# Energy = -0.6057015657424927
# Variance = 13.51884651184082
#
# Step #116
# Energy = -0.5896226763725281
# Variance = 10.586084365844727
#
# Step #117
# Energy = -0.6134732961654663
# Variance = 35.39644241333008
#
# Step #118
# Energy = -0.7041354179382324
# Variance = 165.0009002685547
#
# Step #119
# Energy = -0.5835829377174377
# Variance = 8.123187065124512
#
# Step #120
# Energy = -0.5990720391273499
# Variance = 17.017663955688477
#
# 17.017663955688477  VS  0
# Variance exploding. Earlier ckpt kept.
# Step #121
# Energy = -0.6289902329444885
# Variance = 50.29582977294922
#
# Step #122
# Energy = -0.5995445847511292
# Variance = 12.011482238769531
#
# Step #123
# Energy = -0.6151646375656128
# Variance = 35.06196212768555
#
# Step #124
# Energy = -0.657689094543457
# Variance = 60.51595687866211
#
# Step #125
# Energy = -0.6633895039558411
# Variance = 59.38605499267578
#
# Step #126
# Energy = -0.5674821138381958
# Variance = 13.288887977600098
#
# Step #127
# Energy = -0.7259336113929749
# Variance = 127.7957763671875
#
# Step #128
# Energy = -0.640373170375824
# Variance = 30.566444396972656
#
# Step #129
# Energy = -0.6840593218803406
# Variance = 43.46371841430664
#
# Step #130
# Energy = -0.574216365814209
# Variance = 10.68838882446289
#
# 10.68838882446289  VS  0
# Variance exploding. Earlier ckpt kept.
# Step #131
# Energy = -0.6033064126968384
# Variance = 11.623570442199707
#
# Step #132
# Energy = -0.6383548378944397
# Variance = 26.85689926147461
#
# Step #133
# Energy = -1.0411829948425293
# Variance = 3172.9697265625
#
# Step #134
# Energy = -0.6522457599639893
# Variance = 71.39454650878906
#
# Step #135
# Energy = -0.636358380317688
# Variance = 48.513023376464844
#
# Step #136
# Energy = -0.6438233256340027
# Variance = 30.802875518798828
#
# Step #137
# Energy = -0.6301686763763428
# Variance = 27.10019874572754
#
# Step #138
# Energy = -0.7668381333351135
# Variance = 587.353759765625
#
# Step #139
# Energy = -0.5909067392349243
# Variance = 14.312928199768066
#
# Step #140
# Energy = -0.6668843030929565
# Variance = 67.22027587890625
#
# 67.22027587890625  VS  0
# Variance exploding. Earlier ckpt kept.
# Step #141
# Energy = -0.5903841257095337
# Variance = 29.501689910888672
#
# Step #142
# Energy = -0.5465826392173767
# Variance = 6.12246561050415
#
# Step #143
# Energy = -0.6472811102867126
# Variance = 41.11170196533203
#
# Step #144
# Energy = -0.6035448312759399
# Variance = 34.16399002075195
#
# Step #145
# Energy = -0.5857016444206238
# Variance = 17.625850677490234
#
# Step #146
# Energy = -0.5794991254806519
# Variance = 24.670883178710938
#
# Step #147
# Energy = -1.3930573463439941
# Variance = 8322.6318359375
#
# Step #148
# Energy = -1.151520013809204
# Variance = 5042.958984375
#
# Step #149
# Energy = -0.642819344997406
# Variance = 31.12921714782715
#
# Step #150
# Energy = -0.6984718441963196
# Variance = 210.92872619628906
#
# 210.92872619628906  VS  0
# Variance exploding. Earlier ckpt kept.
# Step #151
# Energy = -0.6966396570205688
# Variance = 151.698974609375
#
# Step #152
# Energy = -0.6269067525863647
# Variance = 36.31203842163086
#
# Step #153
# Energy = -0.5873456001281738
# Variance = 9.99673843383789
#
# Step #154
# Energy = -0.6523501873016357
# Variance = 46.13935089111328
#
# Step #155
# Energy = -0.6149480938911438
# Variance = 33.56316375732422
#
# Step #156
# Energy = -0.7358354330062866
# Variance = 144.13436889648438
#
# Step #157
# Energy = -0.5897272825241089
# Variance = 8.643769264221191
#
# Step #158
# Energy = -0.576258659362793
# Variance = 10.691488265991211
#
# Step #159
# Energy = -0.6257199645042419
# Variance = 18.522741317749023
#
# Step #160
# Energy = -0.6431024074554443
# Variance = 20.009429931640625
#
# 20.009429931640625  VS  0
# Variance exploding. Earlier ckpt kept.
# Step #161
# Energy = -0.6003255844116211
# Variance = 61.043983459472656
#
# Step #162
# Energy = -0.6890616416931152
# Variance = 138.8748321533203
#
# Step #163
# Energy = -0.5507296323776245
# Variance = 8.917304039001465
#
# Step #164
# Energy = -0.5793938636779785
# Variance = 12.870344161987305
#
# Step #165
# Energy = -0.6398113965988159
# Variance = 22.307415008544922
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [6], in <cell line: 34>()
#      31     return Train_w_Data(config)
#      34 if __name__ == "__main__":
# ---> 35     model,e,v,c = main()
#
# Input In [6], in main()
#       1 def main():
#       2     config = {
#       3         'name': 'Benchmark_Data_OneD', # A name for each experiment
#       4         'Lx': 4,  # number of sites in x-direction
#    (...)
#      28         'Plot': True
#      29         }
# ---> 31     return Train_w_Data(config)
#
# File ~/Documents/Github/RydbergStateReReconstruction/Main/Benchmarking/train_data.py:140, in Train_w_Data(config)
#     136 loss = []
#     138 for i, batch in enumerate(dset):
#     139     # Evaluate the loss function in AD mode
# --> 140     batch_loss = train_step(batch)
#     141     loss.append(batch_loss)
#     143 global_step.assign_add(1)
#
# File ~/miniconda3/envs/2DRNN/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/2DRNN/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniconda3/envs/2DRNN/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:954, in Function._call(self, *args, **kwds)
#     951 self._lock.release()
#     952 # In this case we have not created variables on the first call. So we can
#     953 # run the first trace but we should fail if variables are created.
# --> 954 results = self._stateful_fn(*args, **kwds)
#     955 if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     956   raise ValueError("Creating variables on a non-first call to a function"
#     957                    " decorated with tf.function.")
#
# File ~/miniconda3/envs/2DRNN/lib/python3.9/site-packages/tensorflow/python/eager/function.py:2956, in Function.__call__(self, *args, **kwargs)
#    2953 with self._lock:
#    2954   (graph_function,
#    2955    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956 return graph_function._call_flat(
#    2957     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/miniconda3/envs/2DRNN/lib/python3.9/site-packages/tensorflow/python/eager/function.py:1853, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1849 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1850 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1851     and executing_eagerly):
#    1852   # No tape is watching; skip to running the function.
# -> 1853   return self._build_call_outputs(self._inference_function.call(
#    1854       ctx, args, cancellation_manager=cancellation_manager))
#    1855 forward_backward = self._select_forward_and_backward_functions(
#    1856     args,
#    1857     possible_gradient_type,
#    1858     executing_eagerly)
#    1859 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniconda3/envs/2DRNN/lib/python3.9/site-packages/tensorflow/python/eager/function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File ~/miniconda3/envs/2DRNN/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
path = "./data/N_16/delta_1.0/OneD_rnn/Benchmark_Data_OneD"
energy = np.load(path+'/Energy.npy')
variance = np.load(path+'/Variance.npy')
loss = np.load(path+'/Cost.npy')

# %%
plot_E(energy,exact_E,16,len(energy))
# Out:
# Final Energy -0.43031082881821525 (Exact Energy is -0.4534132086591546)
# Final Error after 200 epochs is 0.023102379840939324
# The lowest energy achieved by the model was -0.4352372884750366.
# -0.43031082881821525

# %%
plot_var(variance,16,len(variance))
# Out:
# Final Variance after 200 epochs is 0.1329602582587136
# 0.1329602582587136

# %% [markdown]
# # Two-D, Data

# %%
def main():
    config = {
        'name': 'Benchmark_Data_TwoD', # A name for each experiment
        'Lx': 4,  # number of sites in x-direction                    
        'Ly': 4,  # number of sites in the y-direction
        'V': 7.,
        'Omega': 1.,
        'delta': 1.,
        'sweep_rate':15,
        
        'nh': 32,  # number of memory/hidden units
        'lr': 1e-5,  # learning rate
        'weight_sharing': True,
        'trunc': 100,
        'seed': 1234,
        
        'RNN': 'TwoD',
        'MDGRU': True,
        'VMC_epochs':0,
        'Data_epochs':400,
        
        'ns': 1000,
        'batch_size': 100,
        
        'Print':True,
        'Write_Data': True,
        'CKPT':True,
        'Plot': True
        }
    
    return Train_w_Data(config)


if __name__ == "__main__":
    model,e,v,c = main()
# Out:
# Training a two-D RNN wave function with 32 hidden units and shared weights = True.
# Using GRU cell.
# W_RNN:0 (8192,)
# b_RNN:0 (32,)
# Wg_RNN:0 (8192,)
# bg_RNN:0 (32,)
# Wmerge_RNN:0 (2048,)
# Dense/kernel:0 (64,)
# Dense/bias:0 (2,)
# The sum of params is 18562
# The experimental parameters are: V = 7.0, delta = 1.0, Omega = 1.0.
# The system is an array of 4 by 4 Rydberg Atoms
# getting energy function!
# CKPT ON and ckpt found.
# Restored from ./data/N_16/delta_1.0/TwoD_rnn/Benchmark_Data_TwoD/ckpt-24
# Continuing at step 240
# Tracing!
# /Users/mschuylerm/miniconda3/envs/2DRNN/lib/python3.9/site-packages/keras/legacy_tf_layers/base.py:573: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   _add_elements_to_collection(self.updates, tf.compat.v1.GraphKeys.UPDATE_OPS)
# Step #241
# Energy = -0.2360640913248062
# Variance = 4.042912006378174
#
# Step #242
# Energy = -0.22309155762195587
# Variance = 2.8262431621551514
#
# Step #243
# Energy = -0.22342193126678467
# Variance = 3.410875082015991
#
# Step #244
# Energy = -0.22823476791381836
# Variance = 3.122230052947998
#
# Step #245
# Energy = -0.22986207902431488
# Variance = 3.691875696182251
#
# Step #246
# Energy = -0.24684405326843262
# Variance = 4.059799671173096
#
# Step #247
# Energy = -0.23147451877593994
# Variance = 3.92940616607666
#
# Step #248
# Energy = -0.2549014985561371
# Variance = 2.7080585956573486
#
# Step #249
# Energy = -0.2579582929611206
# Variance = 2.8510279655456543
#
# Step #250
# Energy = -0.2500861883163452
# Variance = 3.6029245853424072
#
# 3.6029245853424072  VS  3.524535298347473
# Variance exploding. Earlier ckpt kept.
# Step #251
# Energy = -0.2383197396993637
# Variance = 2.8027641773223877
#
# Step #252
# Energy = -0.29004573822021484
# Variance = 3.5002148151397705
#
# Step #253
# Energy = -0.2884588837623596
# Variance = 2.9298434257507324
#
# Step #254
# Energy = -0.27383533120155334
# Variance = 2.456112861633301
#
# Step #255
# Energy = -0.28022247552871704
# Variance = 5.042287826538086
#
# Step #256
# Energy = -0.2681395411491394
# Variance = 2.9234209060668945
#
# Step #257
# Energy = -0.28080785274505615
# Variance = 3.288236379623413
#
# Step #258
# Energy = -0.26585206389427185
# Variance = 2.571669340133667
#
# Step #259
# Energy = -0.27243635058403015
# Variance = 3.4180901050567627
#
# Step #260
# Energy = -0.33324652910232544
# Variance = 16.24442481994629
#
# 16.24442481994629  VS  0
# Variance exploding. Earlier ckpt kept.
# Step #261
# Energy = -0.26735249161720276
# Variance = 3.3889529705047607
#
# Step #262
# Energy = -0.27780359983444214
# Variance = 2.983858585357666
#
# Step #263
# Energy = -0.28401103615760803
# Variance = 3.7645022869110107
#
# Step #264
# Energy = -0.3117111921310425
# Variance = 25.185163497924805
#
# Step #265
# Energy = -0.31146350502967834
# Variance = 7.798799991607666
#
# Step #266
# Energy = -0.2912128269672394
# Variance = 2.72316837310791
#
# Step #267
# Energy = -0.31354010105133057
# Variance = 3.604391574859619
#
# Step #268
# Energy = -0.29963815212249756
# Variance = 3.6287529468536377
#
# Step #269
# Energy = -0.30021268129348755
# Variance = 2.9111196994781494
#
# Step #270
# Energy = -0.3177613317966461
# Variance = 3.230686902999878
#
# 3.230686902999878  VS  0
# Variance exploding. Earlier ckpt kept.
# Step #271
# Energy = -0.3061681389808655
# Variance = 2.4999377727508545
#
# Step #272
# Energy = -0.2996505796909332
# Variance = 4.226229667663574
#
# Step #273
# Energy = -0.34191563725471497
# Variance = 15.438231468200684
#
# Step #274
# Energy = -0.33646780252456665
# Variance = 9.821189880371094
#
# Step #275
# Energy = -0.342926949262619
# Variance = 6.345072269439697
#
# Step #276
# Energy = -0.3088214695453644
# Variance = 3.8450255393981934
#
# Step #277
# Energy = -0.2947375476360321
# Variance = 3.6157777309417725
#
# Step #278
# Energy = -0.34125226736068726
# Variance = 2.9112040996551514
#
# Step #279
# Energy = -0.292229026556015
# Variance = 2.304035186767578
#
# Step #280
# Energy = -0.3421185314655304
# Variance = 5.114899635314941
#
# 5.114899635314941  VS  0
# Variance exploding. Earlier ckpt kept.
# Step #281
# Energy = -0.3339618146419525
# Variance = 4.111099720001221
#
# Step #282
# Energy = -0.3191892206668854
# Variance = 3.6944990158081055
#
# Step #283
# Energy = -0.3607136905193329
# Variance = 7.173651218414307
#
# Step #284
# Energy = -0.34442102909088135
# Variance = 5.751290798187256
#
# Step #285
# Energy = -0.30431056022644043
# Variance = 3.8872978687286377
#
# Step #286
# Energy = -0.33623260259628296
# Variance = 4.012099266052246
#
# Step #287
# Energy = -0.3307773470878601
# Variance = 2.970134973526001
#
# Step #288
# Energy = -0.33401232957839966
# Variance = 3.9939849376678467
#
# Step #289
# Energy = -0.35139867663383484
# Variance = 5.710375785827637
#
# Step #290
# Energy = -0.3565431535243988
# Variance = 4.453608989715576
#
# 4.453608989715576  VS  0
# Variance exploding. Earlier ckpt kept.
# Step #291
# Energy = -0.4077838063240051
# Variance = 53.517974853515625
#
# Step #292
# Energy = -0.38288432359695435
# Variance = 7.435067176818848
#
# Step #293
# Energy = -0.33072569966316223
# Variance = 2.4314780235290527
#
# Step #294
# Energy = -0.35217925906181335
# Variance = 3.460639715194702
#
# Step #295
# Energy = -0.3977699875831604
# Variance = 37.015689849853516
#
# Step #296
# Energy = -0.3497191071510315
# Variance = 10.020389556884766
#
# Step #297
# Energy = -0.3626135289669037
# Variance = 6.9120402336120605
#
# Step #298
# Energy = -0.3312934637069702
# Variance = 2.616048812866211
#
# Step #299
# Energy = -0.3553183972835541
# Variance = 4.142272472381592
#
# Step #300
# Energy = -0.3877295255661011
# Variance = 12.066088676452637
#
# 12.066088676452637  VS  0
# Variance exploding. Earlier ckpt kept.
# Step #301
# Energy = -0.38124096393585205
# Variance = 8.055099487304688
#
# Step #302
# Energy = -0.3695949614048004
# Variance = 5.504515647888184
#
# Step #303
# Energy = -0.404180645942688
# Variance = 8.03964614868164
#
# Step #304
# Energy = -0.35444170236587524
# Variance = 5.207043647766113
#
# Step #305
# Energy = -0.35823962092399597
# Variance = 8.133556365966797
#
# Step #306
# Energy = -0.35182929039001465
# Variance = 3.2083418369293213
#
# Step #307
# Energy = -0.38443446159362793
# Variance = 12.589974403381348
#
# Step #308
# Energy = -0.3355411887168884
# Variance = 2.632176160812378
#
# Step #309
# Energy = -0.37892386317253113
# Variance = 5.695510387420654
#
# Step #310
# Energy = -0.34477514028549194
# Variance = 4.25880765914917
#
# 4.25880765914917  VS  0
# Variance exploding. Earlier ckpt kept.
# Step #311
# Energy = -0.3290136158466339
# Variance = 2.9095091819763184
#
# Step #312
# Energy = -0.381294846534729
# Variance = 5.995641708374023
#
# Step #313
# Energy = -0.362336128950119
# Variance = 4.597846508026123
#
# Step #314
# Energy = -0.40880969166755676
# Variance = 13.059287071228027
#
# Step #315
# Energy = -0.35928741097450256
# Variance = 3.1599535942077637
#
# Step #316
# Energy = -0.40078362822532654
# Variance = 10.769109725952148
#
# Step #317
# Energy = -0.36295807361602783
# Variance = 3.4680352210998535
#
# Step #318
# Energy = -0.3720339834690094
# Variance = 3.290902853012085
#
# Step #319
# Energy = -0.4056282639503479
# Variance = 11.962294578552246
#
# Step #320
# Energy = -0.39945629239082336
# Variance = 5.22574520111084
#
# 5.22574520111084  VS  0
# Variance exploding. Earlier ckpt kept.
# Step #321
# Energy = -0.363993763923645
# Variance = 4.635654449462891
#
# Step #322
# Energy = -0.38113611936569214
# Variance = 6.244479179382324
#
# Step #323
# Energy = -0.38555243611335754
# Variance = 5.255438804626465
#
# Step #324
# Energy = -0.3780759572982788
# Variance = 3.7192728519439697
#
# Step #325
# Energy = -0.3816406726837158
# Variance = 8.78276252746582
#
# Step #326
# Energy = -0.38155099749565125
# Variance = 3.8632919788360596
#
# Step #327
# Energy = -0.4261097311973572
# Variance = 20.494102478027344
#
# Step #328
# Energy = -0.3535589575767517
# Variance = 2.9930315017700195
#
# Step #329
# Energy = -0.4447580873966217
# Variance = 27.447309494018555
#
# Step #330
# Energy = -0.407888799905777
# Variance = 6.007092475891113
#
# 6.007092475891113  VS  0
# Variance exploding. Earlier ckpt kept.
# Step #331
# Energy = -0.40733641386032104
# Variance = 4.741747856140137
#
# Step #332
# Energy = -0.361779123544693
# Variance = 3.233513355255127
#
# Step #333
# Energy = -0.41246166825294495
# Variance = 6.722196102142334
#
# Step #334
# Energy = -0.3571551442146301
# Variance = 3.460710048675537
#
# Step #335
# Energy = -0.4307934641838074
# Variance = 8.682376861572266
#
# Step #336
# Energy = -0.3833644390106201
# Variance = 6.589858531951904
#
# Step #337
# Energy = -0.3872435390949249
# Variance = 3.6179358959198
#
# Step #338
# Energy = -0.3888823986053467
# Variance = 22.970943450927734
#
# Step #339
# Energy = -0.40755873918533325
# Variance = 14.381786346435547
#
# Step #340
# Energy = -0.39721930027008057
# Variance = 6.116870403289795
#
# 6.116870403289795  VS  0
# Variance exploding. Earlier ckpt kept.
# Step #341
# Energy = -0.3706449568271637
# Variance = 2.5405101776123047
#
# Step #342
# Energy = -0.38117682933807373
# Variance = 2.9588451385498047
#
# Step #343
# Energy = -0.4355935752391815
# Variance = 16.423236846923828
#
# Step #344
# Energy = -0.39071306586265564
# Variance = 4.692831993103027
#
# Step #345
# Energy = -0.39066675305366516
# Variance = 3.7461981773376465
#
# Step #346
# Energy = -0.38108593225479126
# Variance = 5.275799751281738
#
# Step #347
# Energy = -0.4298047423362732
# Variance = 22.83595848083496
# Step #348
# Energy = -0.41932743787765503
# Variance = 4.777685642242432
#
# Step #349
# Energy = -0.41497841477394104
# Variance = 20.146587371826172
#
# Step #350
# Energy = -0.40438640117645264
# Variance = 6.162318229675293
#
# 6.162318229675293  VS  0
# Variance exploding. Earlier ckpt kept.
# Step #351
# Energy = -0.3954545259475708
# Variance = 5.8885297775268555
#
# Step #352
# Energy = -0.4167386293411255
# Variance = 6.213256359100342
#
# Step #353
# Energy = -0.43667149543762207
# Variance = 12.110560417175293
#
# Step #354
# Energy = -0.40186798572540283
# Variance = 3.380016803741455
#
# Step #355
# Energy = -0.3966321647167206
# Variance = 7.31446647644043
#
# Step #356
# Energy = -0.4395807981491089
# Variance = 5.284244537353516
#
# Step #357
# Energy = -0.412781298160553
# Variance = 20.262636184692383
#
# Step #358
# Energy = -0.43990570306777954
# Variance = 15.52353572845459
#
# Step #359
# Energy = -0.43270742893218994
# Variance = 10.367345809936523
#
# Step #360
# Energy = -0.41117236018180847
# Variance = 5.7942376136779785
#
# 5.7942376136779785  VS  0
# Variance exploding. Earlier ckpt kept.
# Step #361
# Energy = -0.4411979615688324
# Variance = 8.733877182006836
#
# Step #362
# Energy = -0.4029299318790436
# Variance = 3.477097749710083
#
# Step #363
# Energy = -0.41399699449539185
# Variance = 26.70198631286621
#
# Step #364
# Energy = -0.442963182926178
# Variance = 9.84760570526123
#
# Step #365
# Energy = -0.4416920840740204
# Variance = 17.215272903442383
#
# Step #366
# Energy = -0.4272678792476654
# Variance = 7.154658317565918
#
# Step #367
# Energy = -0.4330044388771057
# Variance = 8.898228645324707
#
# Step #368
# Energy = -0.42434221506118774
# Variance = 10.836517333984375
#
# Step #369
# Energy = -0.4416387677192688
# Variance = 9.225929260253906
#
# Step #370
# Energy = -0.40534260869026184
# Variance = 7.201442241668701
#
# 7.201442241668701  VS  0
# Variance exploding. Earlier ckpt kept.
# Step #371
# Energy = -0.4119318127632141
# Variance = 20.39006996154785
#
# Step #372
# Energy = -0.40042153000831604
# Variance = 4.3435516357421875
#
# Step #373
# Energy = -0.4325728714466095
# Variance = 26.07267189025879
#
# Step #374
# Energy = -0.5669420957565308
# Variance = 131.3177490234375
#
# Step #375
# Energy = -0.3782569468021393
# Variance = 2.275296926498413
#
# Step #376
# Energy = -0.43685880303382874
# Variance = 11.749812126159668
#
# Step #377
# Energy = -0.4056738317012787
# Variance = 3.281209945678711
#
# Step #378
# Energy = -0.433042049407959
# Variance = 4.587314605712891
#
# Step #379
# Energy = -0.43555545806884766
# Variance = 23.542552947998047
#
# Step #380
# Energy = -0.45568498969078064
# Variance = 9.253952980041504
#
# 9.253952980041504  VS  0
# Variance exploding. Earlier ckpt kept.
# Step #381
# Energy = -0.41223546862602234
# Variance = 5.344038009643555
#
# Step #382
# Energy = -0.42776936292648315
# Variance = 19.572738647460938
#
# Step #383
# Energy = -0.4747534692287445
# Variance = 27.59269142150879
#
# Step #384
# Energy = -0.451108455657959
# Variance = 17.982019424438477
#
# Step #385
# Energy = -0.38471993803977966
# Variance = 2.7976880073547363
#
# Step #386
# Energy = -0.4153148829936981
# Variance = 5.958553791046143
#
# Step #387
# Energy = -0.4585263729095459
# Variance = 5.838433742523193
#
# Step #388
# Energy = -0.4424344003200531
# Variance = 16.12717628479004
#
# Step #389
# Energy = -0.4477844834327698
# Variance = 14.736031532287598
#
# Step #390
# Energy = -0.4057035446166992
# Variance = 2.788459300994873
#
# 2.788459300994873  VS  0
# Variance exploding. Earlier ckpt kept.
# Step #391
# Energy = -0.39822420477867126
# Variance = 4.017193794250488
#
# Step #392
# Energy = -0.44395822286605835
# Variance = 14.649683952331543
#
# Step #393
# Energy = -0.4111945331096649
# Variance = 4.003791809082031
#
# Step #394
# Energy = -0.41719532012939453
# Variance = 6.95818567276001
#
# Step #395
# Energy = -0.5669045448303223
# Variance = 225.83209228515625
#
# Step #396
# Energy = -0.43796154856681824
# Variance = 6.126519680023193
#
# Step #397
# Energy = -0.4508274495601654
# Variance = 9.590773582458496
#
# Step #398
# Energy = -0.4271928668022156
# Variance = 4.614009857177734
#
# Step #399
# Energy = -0.4396108090877533
# Variance = 5.402709007263184
#
# Step #400
# Energy = -0.46511584520339966
# Variance = 42.36549758911133
#
# 42.36549758911133  VS  0
# Variance exploding. Earlier ckpt kept.
# Saved training quantities for the FINAL step 400 in ./data/N_16/delta_1.0/TwoD_rnn/Benchmark_Data_TwoD.

# %%
path2 = "./data/N_16/delta_1.0/TwoD_rnn/Benchmark_Data_TwoD"
energy2 = np.load(path2+'/Energy.npy')
variance2 = np.load(path2+'/Variance.npy')
loss2 = np.load(path2+'/Cost.npy')

# %%
plot_E(energy2,exact_E,16,len(energy2))
# Out:
# Final Energy -0.4436743888590071 (Exact Energy is -0.4534132086591546)
# Final Error after 400 epochs is 0.009738819800147458
# The lowest energy achieved by the model was -0.5669420957565308.
# -0.4436743888590071

# %%
plot_var(variance2,16,len(variance2),log_scale=False,limit=True)
# Out:
# Final Variance after 400 epochs is 31.243884404500324
# 31.243884404500324
