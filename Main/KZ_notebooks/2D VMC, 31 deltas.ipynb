# %%
import numpy as np
import matplotlib.pylab as plt

# %% [markdown]
# Variables that will get used a lot

# %%
basepath = './data/N_256/TwoD_VMC_alldeltas/TwoD_rnn/delta_'
energy = 'Energy.npy'
variance = 'Variance.npy'
nsteps = 10000
xaxis = np.arange(nsteps)

# %% [markdown]
# delta = -1.545

# %%
path_m1545 = basepath + '-1.545/'
energy_m1545 = np.load(path_m1545+energy)
var_m1545 = np.load(path_m1545+variance)
energies = energy_m1545
variances = var_m1545

# %% [markdown]
# delta = -1.045

# %%
path_m1045 = basepath + '-1.045/'
energy_m1045 = np.load(path_m1045+energy)
var_m1045 = np.load(path_m1045+variance)
energies = np.vstack([energies,energy_m1045])
variances = np.vstack([variances,var_m1045])

# %% [markdown]
# delta = -0.545

# %%
path_m0545 = basepath + '-0.545/'
energy_m0545 = np.load(path_m0545+energy)
var_m0545 = np.load(path_m0545+variance)
energies = np.vstack([energies,energy_m0545])
variances = np.vstack([variances,var_m0545])

# %% [markdown]
# delta = -0.045

# %%
path_m0045 = basepath + '-0.045/'
energy_m0045 = np.load(path_m0045+energy)
var_m0045 = np.load(path_m0045+variance)
energies = np.vstack([energies,energy_m0045])
variances = np.vstack([variances,var_m0045])

# %% [markdown]
# delta = 0.455

# %%
path_0455 = basepath + '0.455/'
energy_0455 = np.load(path_0455+energy)
var_0455 = np.load(path_0455+variance)
energies = np.vstack([energies,energy_0455])
variances = np.vstack([variances,var_0455])

# %% [markdown]
# delta = 0.955

# %%
path_0955 = basepath + '0.955/'
energy_0955 = np.load(path_0955+energy)
var_0955 = np.load(path_0955+variance)
energies = np.vstack([energies,energy_0955])
variances = np.vstack([variances,var_0955])

# %% [markdown]
# delta = 1.455

# %%
path_1455 = basepath + '1.455/'
energy_1455 = np.load(path_1455+energy)
var_1455 = np.load(path_1455+variance)
energies = np.vstack([energies,energy_1455])
variances = np.vstack([variances,var_1455])

# %% [markdown]
# delta = 1.955

# %%
path_1955 = basepath + '1.955/'
energy_1955 = np.load(path_1955+energy)
var_1955 = np.load(path_1955+variance)
energies = np.vstack([energies,energy_1955])
variances = np.vstack([variances,var_1955])

# %% [markdown]
# delta = 2.455

# %%
path_2455 = basepath + '2.455/'
energy_2455 = np.load(path_2455+energy)
var_2455 = np.load(path_2455+variance)
energies = np.vstack([energies,energy_2455])
variances = np.vstack([variances,var_2455])

# %% [markdown]
# delta = 2.955

# %%
path_2955 = basepath + '2.955/'
energy_2955 = np.load(path_2955+energy)
var_2955 = np.load(path_2955+variance)
energies = np.vstack([energies,energy_2955])
variances = np.vstack([variances,var_2955])

# %% [markdown]
# delta = 3.455

# %%
path_3455 = basepath + '3.455/'
energy_3455 = np.load(path_3455+energy)
var_3455 = np.load(path_3455+variance)
energies = np.vstack([energies,energy_3455])
variances = np.vstack([variances,var_3455])

# %% [markdown]
# delta = 3.955

# %%
path_3955 = basepath + '3.955/'
energy_3955 = np.load(path_3955+energy)
var_3955 = np.load(path_3955+variance)
energies = np.vstack([energies,energy_3955])
variances = np.vstack([variances,var_3955])

# %% [markdown]
# delta = 4.455

# %%
path_4455 = basepath + '4.455/'
energy_4455 = np.load(path_4455+energy)
var_4455 = np.load(path_4455+variance)
energies = np.vstack([energies,energy_4455])
variances = np.vstack([variances,var_4455])

# %% [markdown]
# delta = 4.955

# %%
path_4955 = basepath + '4.955/'
energy_4955 = np.load(path_4955+energy)
var_4955 = np.load(path_4955+variance)
energies = np.vstack([energies,energy_4955])
variances = np.vstack([variances,var_4955])

# %% [markdown]
# delta = 5.455

# %%
path_5455 = basepath + '5.455/'
energy_5455 = np.load(path_5455+energy)
var_5455 = np.load(path_5455+variance)
energies = np.vstack([energies,energy_5455])
variances = np.vstack([variances,var_5455])

# %% [markdown]
# delta = 5.955

# %%
path_5955 = basepath + '5.955/'
energy_5955 = np.load(path_5955+energy)
var_5955 = np.load(path_5955+variance)
energies = np.vstack([energies,energy_5955])
variances = np.vstack([variances,var_5955])

# %% [markdown]
# delta = 6.455

# %%
path_6455 = basepath + '6.455/'
energy_6455 = np.load(path_6455+energy)
var_6455 = np.load(path_6455+variance)
energies = np.vstack([energies,energy_6455])
variances = np.vstack([variances,var_6455])

# %% [markdown]
# delta = 6.955

# %%
path_6955 = basepath + '6.955/'
energy_6955 = np.load(path_6955+energy)
var_6955 = np.load(path_6955+variance)
energies = np.vstack([energies,energy_6955])
variances = np.vstack([variances,var_6955])

# %% [markdown]
# delta = 7.455

# %%
path_7455 = basepath + '7.455/'
energy_7455 = np.load(path_7455+energy)
var_7455 = np.load(path_7455+variance)
energies = np.vstack([energies,energy_7455])
variances = np.vstack([variances,var_7455])

# %% [markdown]
# delta = 7.955

# %%
path_7955 = basepath + '7.955/'
energy_7955 = np.load(path_7955+energy)
var_7955 = np.load(path_7955+variance)
energies = np.vstack([energies,energy_7955])
variances = np.vstack([variances,var_7955])

# %% [markdown]
# delta = 8.455

# %%
path_8455 = basepath + '8.455/'
energy_8455 = np.load(path_8455+energy)
var_8455 = np.load(path_8455+variance)
energies = np.vstack([energies,energy_8455])
variances = np.vstack([variances,var_8455])

# %% [markdown]
# delta = 8.955

# %%
path_8955 = basepath + '8.955/'
energy_8955 = np.load(path_8955+energy)
var_8955 = np.load(path_8955+variance)
energies = np.vstack([energies,energy_8955])
variances = np.vstack([variances,var_8955])

# %% [markdown]
# delta = 9.455

# %%
path_9455 = basepath + '9.455/'
energy_9455 = np.load(path_9455+energy)
var_9455 = np.load(path_9455+variance)
energies = np.vstack([energies,energy_9455])
variances = np.vstack([variances,var_9455])

# %% [markdown]
# delta = 9.955

# %%
path_9955 = basepath + '9.955/'
energy_9955 = np.load(path_9955+energy)
var_9955 = np.load(path_9955+variance)
energies = np.vstack([energies,energy_9955])
variances = np.vstack([variances,var_9955])

# %% [markdown]
# delta = 10.455

# %%
path_10455 = basepath + '10.455/'
energy_10455 = np.load(path_10455+energy)
var_10455 = np.load(path_10455+variance)
energies = np.vstack([energies,energy_10455])
variances = np.vstack([variances,var_10455])

# %% [markdown]
# delta = 10.955

# %%
path_10955 = basepath + '10.955/'
energy_10955 = np.load(path_10955+energy)
var_10955 = np.load(path_10955+variance)
energies = np.vstack([energies,energy_10955])
variances = np.vstack([variances,var_10955])

# %% [markdown]
# delta = 11.455

# %%
path_11455 = basepath + '11.455/'
energy_11455 = np.load(path_11455+energy)
var_11455 = np.load(path_11455+variance)
energies = np.vstack([energies,energy_11455])
variances = np.vstack([variances,var_11455])

# %% [markdown]
# delta = 11.955

# %%
path_11955 = basepath + '11.955/'
energy_11955 = np.load(path_11955+energy)
var_11955 = np.load(path_11955+variance)
energies = np.vstack([energies,energy_11955])
variances = np.vstack([variances,var_11955])

# %% [markdown]
# delta = 12.455

# %%
path_12455 = basepath + '12.455/'
energy_12455 = np.load(path_12455+energy)
var_12455 = np.load(path_12455+variance)
energies = np.vstack([energies,energy_12455])
variances = np.vstack([variances,var_12455])

# %% [markdown]
# delta = 12.955

# %%
path_12955 = basepath + '12.955/'
energy_12955 = np.load(path_12955+energy)
var_12955 = np.load(path_12955+variance)
energies = np.vstack([energies,energy_12955])
variances = np.vstack([variances,var_12955])

# %% [markdown]
# delta = 13.455

# %%
path_13455 = basepath + '13.455/'
energy_13455 = np.load(path_13455+energy)
var_13455 = np.load(path_13455+variance)
energies = np.vstack([energies,energy_13455])
variances = np.vstack([variances,var_13455])

# %%
print(np.shape(energies))
print(np.shape(variances))
# Out:
# (31, 10000)
# (31, 10000)

# %%
def plot_all_es(array):
    fig = plt.figure(1,figsize=(8,5), dpi=120, facecolor='w', edgecolor='k')
    deltas,steps = np.shape(array)
    xaxis = np.arange(steps)
    delta = -1.545
    cmap = plt.get_cmap('Reds')
    for i in range(deltas):
        delta_str = str(delta)
        plt.plot(xaxis,array[i,:],label = delta_str,color=cmap(i/deltas))
        delta += 0.5
        delta = round(delta,3)
    plt.ylim(-6,0)
    plt.legend(ncol=2,loc='center left', bbox_to_anchor=(1, 0.5))
    plt.xlabel('steps')
    plt.ylabel('$\\langle H \\rangle$')
    plt.title('Energy Convergence, 2D RNN')
    plt.show()
    
def plot_all_vs(array):
    fig = plt.figure(1,figsize=(8,5), dpi=120, facecolor='w', edgecolor='k')
    deltas,steps = np.shape(array)
    xaxis = np.arange(steps)
    delta = -1.545
    cmap = plt.get_cmap('Blues')
    for i in range(deltas):
        delta_str = str(delta)
        plt.plot(xaxis,array[i,:],label = delta_str,color=cmap(i/deltas))
        delta += 0.5
        delta = round(delta,3)
#     plt.ylim(-0.1,10)
    plt.yscale('log')
    plt.legend(ncol=2,loc='center left', bbox_to_anchor=(1, 0.5))
    plt.xlabel('steps')
    plt.ylabel('Var($\\langle H \\rangle$)')
    plt.title('Variance Convergence, 2D RNN')
    plt.show()

# %%
plot_all_es(energies)
plot_all_vs(variances)
