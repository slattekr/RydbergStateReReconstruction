# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('..')
import numpy as np
import tensorflow as tf
from dset_helpers import data_given_param

# %%
from train_VMC import Train_w_VMC
from train_data import Train_w_Data

# %% [markdown]
# # System Parameters

# %%
Lx = 16
Ly = 16
Omega = 4.24
Rb = 1.15
V0 = Rb**6 * Omega
sweep_rate = 15
low = -1.545
midlow = 4.455
midhigh = 4.955
high = 13.455

# %% [markdown]
# # Train Models

# %%
energy = []
variance = []
cost = []

def main():
    config = {
        'name': 'test', # A very random name for each experiment
        'Lx': Lx,  # number of sites in x-direction                    
        'Ly': Ly,  # number of sites in the y-direction
        'V': V0,
        'Omega': Omega,
        'delta': low,
        'sweep_rate':15,
        
        'nh': 32,  # number of memory/hidden units
        'lr': 1e-3,  # learning rate
        'weight_sharing': True,
        'trunc': 100,
        'seed': 1234,
        
        'RNN': 'OneD',
        'MDGRU': True,
        'VMC_epochs':0,
        'Data_epochs': 500,
        
        'ns': 1000,
        'batch_size': 100,
        
        'Print':True,
        'Write_Data': False,
        'Plot': True
        }
    
    return Train_w_Data(config,energy,variance,cost)


if __name__ == "__main__":
    model,e,v,c = main()
# Out:
# Training a one-D RNN wave function with 32 hidden units and shared weights.
# gru_1/gru_cell_1/kernel:0 (192,)
# gru_1/gru_cell_1/recurrent_kernel:0 (3072,)
# gru_1/gru_cell_1/bias:0 (192,)
# dense_1/kernel:0 (64,)
# dense_1/bias:0 (2,)
# The sum of params is 3522
# The experimental parameters are: V = 9.807377646249996, delta = -1.545, Omega = 4.24.
# The system is an array of 16 by 16 Rydberg Atoms
# Tracing!
# Tracing!
# Step #1
# Energy = 0.8437874913215637
# Variance = 64.22846221923828
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [7], in <cell line: 37>()
#      34     return Train_w_Data(config,energy,variance,cost)
#      37 if __name__ == "__main__":
# ---> 38     model,e,v,c = main()
#
# Input In [7], in main()
#       5 def main():
#       6     config = {
#       7         'name': 'test', # A very random name for each experiment
#       8         'Lx': Lx,  # number of sites in x-direction
#    (...)
#      31         'Plot': True
#      32         }
# ---> 34     return Train_w_Data(config,energy,variance,cost)
#
# File ~/Documents/Github/RydbergStateReReconstruction/Main/KZ_notebooks/../train_data.py:86, in Train_w_Data(config, energy, variance, cost)
#      84 samples, _ = wavefxn.sample(ns)
#      85 sample_logpsi = wavefxn.logpsi(samples)
# ---> 86 sample_eloc = wavefxn.localenergy(samples, sample_logpsi)
#      87 energies = sample_eloc.numpy()
#      88 avg_E = np.mean(energies)/float(wavefxn.N)
#
# File ~/Documents/Github/RydbergStateReReconstruction/Main/KZ_notebooks/../OneD_RNN.py:102, in OneD_RNN_wavefxn.localenergy(self, samples, logpsi)
#     100     eloc += - self.delta * tf.cast(samples[:,j],tf.float32)
#     101 for n in range(len(self.interactions)):
# --> 102     eloc += (self.V/self.interactions[n][0]) * tf.cast(samples[:,self.interactions[n][1]]*samples[:,self.interactions[n][2]],tf.float32)
#     103 flip_logpsi = tf.zeros(shape=[tf.shape(samples)[0]])
#     104 # Off-diagonal part
#
# File ~/miniconda3/envs/2DRNN/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/2DRNN/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/miniconda3/envs/2DRNN/lib/python3.9/site-packages/tensorflow/python/ops/math_ops.py:1002, in cast(x, dtype, name)
#    1000   x = ops.convert_to_tensor(x, name="x")
#    1001   if x.dtype.base_dtype != base_type:
# -> 1002     x = gen_math_ops.cast(x, base_type, name=name)
#    1003 if x.dtype.is_complex and base_type.is_floating:
#    1004   logging.warn("Casting complex to real discards imaginary part.")
#
# File ~/miniconda3/envs/2DRNN/lib/python3.9/site-packages/tensorflow/python/ops/gen_math_ops.py:1997, in cast(x, DstT, Truncate, name)
#    1995 if tld.is_eager:
#    1996   try:
# -> 1997     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    1998       _ctx, "Cast", name, x, "DstT", DstT, "Truncate", Truncate)
#    1999     return _result
#    2000   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
energy = []
variance = []
cost = []

def main():
    config = {
        'name': 'test', # A very random name for each experiment
        'Lx': Lx,  # number of sites in x-direction                    
        'Ly': Ly,  # number of sites in the y-direction
        'V': V0,
        'Omega': Omega,
        'delta': low,
        'sweep_rate':15,
        
        'nh': 32,  # number of memory/hidden units
        'lr': 1e-3,  # learning rate
        'weight_sharing': True,
        'trunc': 100,
        'seed': 1234,
        
        'RNN': 'TwoD',
        'MDGRU': True,
        'VMC_epochs':0,
        'Data_epochs': 500,
        
        'ns': 1000,
        'batch_size': 100,
        
        'Print':True,
        'Write_Data': False,
        'Plot': True
        }
    
    return Train_w_Data(config,energy,variance,cost)


if __name__ == "__main__":
    model,e,v,c = main()
# Out:
# Training a two-D RNN wave function with 32 hidden units and shared weights = True.
# Using GRU cell.
# W_RNN:0 (8192,)
# b_RNN:0 (32,)
# Wg_RNN:0 (8192,)
# bg_RNN:0 (32,)
# Wmerge_RNN:0 (2048,)
# Dense/kernel:0 (64,)
# Dense/bias:0 (2,)
# The sum of params is 18562
# got wavefunction!!!!!
# The experimental parameters are: V = 9.807377646249996, delta = -1.545, Omega = 4.24.
# The system is an array of 16 by 16 Rydberg Atoms
# Tracing!
# /Users/mschuylerm/miniconda3/envs/2DRNN/lib/python3.9/site-packages/keras/legacy_tf_layers/base.py:573: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   _add_elements_to_collection(self.updates, tf.compat.v1.GraphKeys.UPDATE_OPS)
# Tracing!
# Step #1
# Energy = -1.3880767822265625
# Variance = 57.4113655090332
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [6], in <cell line: 37>()
#      34     return Train_w_Data(config,energy,variance,cost)
#      37 if __name__ == "__main__":
# ---> 38     model,e,v,c = main()
#
# Input In [6], in main()
#       5 def main():
#       6     config = {
#       7         'name': 'test', # A very random name for each experiment
#       8         'Lx': Lx,  # number of sites in x-direction
#    (...)
#      31         'Plot': True
#      32         }
# ---> 34     return Train_w_Data(config,energy,variance,cost)
#
# File ~/Documents/Github/RydbergStateReReconstruction/Main/KZ_notebooks/../train_data.py:88, in Train_w_Data(config, energy, variance, cost)
#      86 samples, _ = wavefxn.sample(ns)
#      87 sample_logpsi = wavefxn.logpsi(samples)
# ---> 88 sample_eloc = wavefxn.localenergy(samples, sample_logpsi)
#      89 energies = sample_eloc.numpy()
#      90 avg_E = np.mean(energies)/float(wavefxn.N)
#
# File ~/Documents/Github/RydbergStateReReconstruction/Main/KZ_notebooks/../TwoD_RNN.py:452, in MDRNNWavefunction.localenergy(self, samples, logpsi)
#     449     eloc += - self.delta * tf.cast(samples[:,j],tf.float32)
#     451 for n in range(len(self.interactions)):
# --> 452     eloc += (self.V/self.interactions[n][0]) * tf.cast(samples[:,self.interactions[n][1]]*samples[:,self.interactions[n][2]],tf.float32)
#     454 flip_logpsi = tf.zeros(shape=[tf.shape(samples)[0]])
#     456 # Off-diagonal part
#
# File ~/miniconda3/envs/2DRNN/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/2DRNN/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/miniconda3/envs/2DRNN/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py:1039, in _slice_helper(tensor, slice_spec, var)
#    1033 with ops.name_scope(
#    1034     None,
#    1035     "strided_slice", [tensor] + begin + end + strides,
#    1036     skip_on_eager=False) as name:
#    1037   if begin:
#    1038     packed_begin, packed_end, packed_strides = (stack(begin), stack(end),
# -> 1039                                                 stack(strides))
#    1040     if (packed_begin.dtype == dtypes.int64 or
#    1041         packed_end.dtype == dtypes.int64 or
#    1042         packed_strides.dtype == dtypes.int64):
#    1043       if packed_begin.dtype != dtypes.int64:
#
# File ~/miniconda3/envs/2DRNN/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/2DRNN/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/miniconda3/envs/2DRNN/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py:1424, in stack(values, axis, name)
#    1421 if axis == 0:
#    1422   try:
#    1423     # If the input is a constant list, it can be converted to a constant op
# -> 1424     return ops.convert_to_tensor(values, name=name)
#    1425   except (TypeError, ValueError):
#    1426     pass  # Input list contains non-constant tensors
#
# File ~/miniconda3/envs/2DRNN/lib/python3.9/site-packages/tensorflow/python/profiler/trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/2DRNN/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:1695, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1690       raise TypeError("convert_to_tensor did not convert to "
#    1691                       "the preferred dtype: %s vs %s " %
#    1692                       (ret.dtype.base_dtype, preferred_dtype.base_dtype))
#    1694 if ret is None:
# -> 1695   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1697 if ret is NotImplemented:
#    1698   continue
#
# File ~/miniconda3/envs/2DRNN/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py:343, in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     340 def _constant_tensor_conversion_function(v, dtype=None, name=None,
#     341                                          as_ref=False):
#     342   _ = as_ref
# --> 343   return constant(v, dtype=dtype, name=name)
#
# File ~/miniconda3/envs/2DRNN/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py:267, in constant(value, dtype, shape, name)
#     170 @tf_export("constant", v1=[])
#     171 def constant(value, dtype=None, shape=None, name="Const"):
#     172   """Creates a constant tensor from a tensor-like object.
#     173
#     174   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)
#     265     ValueError: if called on a symbolic tensor.
#     266   """
# --> 267   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     268                         allow_broadcast=True)
#
# File ~/miniconda3/envs/2DRNN/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py:279, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     277     with trace.Trace("tf.constant"):
#     278       return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 279   return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     281 g = ops.get_default_graph()
#     282 tensor_value = attr_value_pb2.AttrValue()
#
# File ~/miniconda3/envs/2DRNN/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py:304, in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     302 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     303   """Creates a constant on the current device."""
# --> 304   t = convert_to_eager_tensor(value, ctx, dtype)
#     305   if shape is None:
#     306     return t
#
# File ~/miniconda3/envs/2DRNN/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py:102, in convert_to_eager_tensor(value, ctx, dtype)
#     100     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101 ctx.ensure_initialized()
# --> 102 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# KeyboardInterrupt:

# %% [markdown]
# Can see that both the OneD and TwoD RNNs train with data yay! At least no bugs in terms of how the data is being read in and passed to the model...

# %% [markdown]
# One thing to note: the initialization of the OneD RNN is WAY slower than for the TwoD RNN which is wierd because the TwoD RNN is way bigger... should look into this and generally optimize the code to make the training faster
