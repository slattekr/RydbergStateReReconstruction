# %%
import numpy as np
import matplotlib.pylab as plt

# %% [markdown]
# # OneD RNNs

# %% [markdown]
# ### VMC Only

# %%
VMC_oned_lowdelta = "data/N_256/delta_-1.545/OneD_rnn/ns100/"
VMC_oned_lowdelta_e = np.load(VMC_oned_lowdelta+"Energy.npy")
VMC_oned_lowdelta_v = np.load(VMC_oned_lowdelta+"Variance.npy")
VMC_oned_lowdelta_c = np.load(VMC_oned_lowdelta+"Cost.npy")

VMC_oned_midlowdelta = "data/N_256/delta_4.455/OneD_rnn/ns100/"
VMC_oned_midlowdelta_e = np.load(VMC_oned_midlowdelta+"Energy.npy")
VMC_oned_midlowdelta_v = np.load(VMC_oned_midlowdelta+"Variance.npy")
VMC_oned_midlowdelta_c = np.load(VMC_oned_midlowdelta+"Cost.npy")

VMC_oned_midhighdelta = "data/N_256/delta_4.955/OneD_rnn/ns100/"
VMC_oned_midhighdelta_e = np.load(VMC_oned_midhighdelta+"Energy.npy")
VMC_oned_midhighdelta_v = np.load(VMC_oned_midhighdelta+"Variance.npy")
VMC_oned_midhighdelta_c = np.load(VMC_oned_midhighdelta+"Cost.npy")

VMC_oned_highdelta = "data/N_256/delta_13.455/OneD_rnn/ns100/"
VMC_oned_highdelta_e = np.load(VMC_oned_highdelta+"Energy.npy")
VMC_oned_highdelta_v = np.load(VMC_oned_highdelta+"Variance.npy")
VMC_oned_highdelta_c = np.load(VMC_oned_highdelta+"Cost.npy")

# %%
fig = plt.figure(1,figsize=(8,5), dpi=120, facecolor='w', edgecolor='k')
plt.plot(np.arange(len(VMC_oned_lowdelta_e)),VMC_oned_lowdelta_e,label='delta = -1.545')
plt.plot(np.arange(len(VMC_oned_midlowdelta_e)),VMC_oned_midlowdelta_e,label='delta = 4.455')
plt.plot(np.arange(len(VMC_oned_midhighdelta_e)),VMC_oned_midhighdelta_e,label='delta = 4.955')
plt.plot(np.arange(len(VMC_oned_highdelta_e)),VMC_oned_highdelta_e,label='delta = 13.455')
plt.legend()
plt.ylim(-5,0)
plt.title('(OneD, VMC) Energy Convergence',fontsize=25)
plt.ylabel('$\\langle H \\rangle$',fontsize=20)
plt.xlabel('training steps',fontsize=20)
plt.show()

# %%
fig = plt.figure(1,figsize=(8,5), dpi=120, facecolor='w', edgecolor='k')
plt.plot(np.arange(len(VMC_oned_lowdelta_v)),VMC_oned_lowdelta_v,label='delta = -1.545')
plt.plot(np.arange(len(VMC_oned_midlowdelta_v)),VMC_oned_midlowdelta_v,label='delta = 4.455')
plt.plot(np.arange(len(VMC_oned_midhighdelta_v)),VMC_oned_midhighdelta_v,label='delta = 4.955')
plt.plot(np.arange(len(VMC_oned_highdelta_v)),VMC_oned_highdelta_v,label='delta = 13.455')
plt.legend()
plt.ylim(-0.1,15)
plt.title('(OneD, VMC) Variance Convergence',fontsize=25)
plt.ylabel('Var($\\langle H \\rangle$)',fontsize=20)
plt.xlabel('training steps',fontsize=20)
plt.show()

# %% [markdown]
# ### Data Only

# %%
data_oned_lowdelta = "data/N_256/delta_-1.545/OneD_rnn/ns100_bs100/"
data_oned_lowdelta_e = np.load(data_oned_lowdelta+"Energy.npy")
data_oned_lowdelta_v = np.load(data_oned_lowdelta+"Variance.npy")
data_oned_lowdelta_c = np.load(data_oned_lowdelta+"Cost.npy")

data_oned_midlowdelta = "data/N_256/delta_4.455/OneD_rnn/ns100_bs100/"
data_oned_midlowdelta_e = np.load(data_oned_midlowdelta+"Energy.npy")
data_oned_midlowdelta_v = np.load(data_oned_midlowdelta+"Variance.npy")
data_oned_midlowdelta_c = np.load(data_oned_midlowdelta+"Cost.npy")

data_oned_midhighdelta = "data/N_256/delta_4.955/OneD_rnn/ns100_bs100/"
data_oned_midhighdelta_e = np.load(data_oned_midhighdelta+"Energy.npy")
data_oned_midhighdelta_v = np.load(data_oned_midhighdelta+"Variance.npy")
data_oned_midhighdelta_c = np.load(data_oned_midhighdelta+"Cost.npy")

data_oned_highdelta = "data/N_256/delta_13.455/OneD_rnn/ns100_bs100/"
data_oned_highdelta_e = np.load(data_oned_highdelta+"Energy.npy")
data_oned_highdelta_v = np.load(data_oned_highdelta+"Variance.npy")
data_oned_highdelta_c = np.load(data_oned_highdelta+"Cost.npy")

# %%
fig = plt.figure(1,figsize=(8,5), dpi=120, facecolor='w', edgecolor='k')
plt.plot(np.arange(len(data_oned_lowdelta_e)),data_oned_lowdelta_e,label='delta = -1.545')
plt.plot(np.arange(len(data_oned_midlowdelta_e)),data_oned_midlowdelta_e,label='delta = 4.455')
plt.plot(np.arange(len(data_oned_midhighdelta_e)),data_oned_midhighdelta_e,label='delta = 4.955')
plt.plot(np.arange(len(data_oned_highdelta_e)),data_oned_highdelta_e,label='delta = 13.455')
plt.legend()
# plt.ylim(-5,0)
plt.title('(OneD, Data) Energy Convergence',fontsize=25)
plt.ylabel('$\\langle H \\rangle$',fontsize=20)
plt.xlabel('training steps',fontsize=20)
plt.show()

# %%
fig = plt.figure(1,figsize=(8,5), dpi=120, facecolor='w', edgecolor='k')
plt.plot(np.arange(len(data_oned_lowdelta_v)),data_oned_lowdelta_v,label='delta = -1.545')
plt.plot(np.arange(len(data_oned_midlowdelta_v)),data_oned_midlowdelta_v,label='delta = 4.455')
plt.plot(np.arange(len(data_oned_midhighdelta_v)),data_oned_midhighdelta_v,label='delta = 4.955')
plt.plot(np.arange(len(data_oned_highdelta_v)),data_oned_highdelta_v,label='delta = 13.455')
plt.legend()
plt.ylim(-0.1,15)
plt.title('(OneD, Data) Variance Convergence',fontsize=25)
plt.ylabel('Var($\\langle H \\rangle$)',fontsize=20)
plt.xlabel('training steps',fontsize=20)
plt.show()

# %% [markdown]
# yikes

# %% [markdown]
# # TwoD RNNs

# %% [markdown]
# ### VMC Only

# %%
VMC_twod_lowdelta = "data/N_256/delta_-1.545/TwoD_rnn/ns100/"
VMC_twod_lowdelta_e = np.load(VMC_twod_lowdelta+"Energy.npy")
VMC_twod_lowdelta_v = np.load(VMC_twod_lowdelta+"Variance.npy")
VMC_twod_lowdelta_c = np.load(VMC_twod_lowdelta+"Cost.npy")

VMC_twod_midlowdelta = "data/N_256/delta_4.455/TwoD_rnn/ns100/"
VMC_twod_midlowdelta_e = np.load(VMC_twod_midlowdelta+"Energy.npy")
VMC_twod_midlowdelta_v = np.load(VMC_twod_midlowdelta+"Variance.npy")
VMC_twod_midlowdelta_c = np.load(VMC_twod_midlowdelta+"Cost.npy")

VMC_twod_midhighdelta = "data/N_256/delta_4.955/TwoD_rnn/ns100/"
VMC_twod_midhighdelta_e = np.load(VMC_twod_midhighdelta+"Energy.npy")
VMC_twod_midhighdelta_v = np.load(VMC_twod_midhighdelta+"Variance.npy")
VMC_twod_midhighdelta_c = np.load(VMC_twod_midhighdelta+"Cost.npy")

VMC_twod_highdelta = "data/N_256/delta_13.455/TwoD_rnn/ns100/"
VMC_twod_highdelta_e = np.load(VMC_twod_highdelta+"Energy.npy")
VMC_twod_highdelta_v = np.load(VMC_twod_highdelta+"Variance.npy")
VMC_twod_highdelta_c = np.load(VMC_twod_highdelta+"Cost.npy")

# %%
fig = plt.figure(1,figsize=(8,5), dpi=120, facecolor='w', edgecolor='k')
plt.plot(np.arange(len(VMC_twod_lowdelta_e)),VMC_twod_lowdelta_e,label='delta = -1.545')
plt.plot(np.arange(len(VMC_twod_midlowdelta_e)),VMC_twod_midlowdelta_e,label='delta = 4.455')
plt.plot(np.arange(len(VMC_twod_midhighdelta_e)),VMC_twod_midhighdelta_e,label='delta = 4.955')
plt.plot(np.arange(len(VMC_twod_highdelta_e)),VMC_twod_highdelta_e,label='delta = 13.455')
plt.legend()
# plt.ylim(-5,0)
plt.title('(TwoD, VMC) Energy Convergence',fontsize=25)
plt.ylabel('$\\langle H \\rangle$',fontsize=20)
plt.xlabel('training steps',fontsize=20)
plt.show()

# %%
fig = plt.figure(1,figsize=(8,5), dpi=120, facecolor='w', edgecolor='k')
plt.plot(np.arange(len(VMC_twod_lowdelta_v)),VMC_twod_lowdelta_v,label='delta = -1.545')
plt.plot(np.arange(len(VMC_twod_midlowdelta_v)),VMC_twod_midlowdelta_v,label='delta = 4.455')
plt.plot(np.arange(len(VMC_twod_midhighdelta_v)),VMC_twod_midhighdelta_v,label='delta = 4.955')
plt.plot(np.arange(len(VMC_twod_highdelta_v)),VMC_twod_highdelta_v,label='delta = 13.455')
plt.legend()
# plt.ylim(-0.1,1)
plt.title('(TwoD, VMC) Variance Convergence',fontsize=25)
plt.ylabel('Var($\\langle H \\rangle$)',fontsize=20)
plt.xlabel('training steps',fontsize=20)
plt.show()

# %% [markdown]
# ### Data Only

# %%
data_twod_lowdelta = "data/N_256/delta_-1.545/TwoD_rnn/ns100_bs100_10ksteps/"
data_twod_lowdelta_e = np.load(data_twod_lowdelta+"Energy.npy")
data_twod_lowdelta_v = np.load(data_twod_lowdelta+"Variance.npy")
data_twod_lowdelta_c = np.load(data_twod_lowdelta+"Cost.npy")

data_twod_midlowdelta = "data/N_256/delta_4.455/TwoD_rnn/ns100_bs100_10ksteps/"
data_twod_midlowdelta_e = np.load(data_twod_midlowdelta+"Energy.npy")
data_twod_midlowdelta_v = np.load(data_twod_midlowdelta+"Variance.npy")
data_twod_midlowdelta_c = np.load(data_twod_midlowdelta+"Cost.npy")

data_twod_midhighdelta = "data/N_256/delta_4.955/TwoD_rnn/ns100_bs100_10ksteps/"
data_twod_midhighdelta_e = np.load(data_twod_midhighdelta+"Energy.npy")
data_twod_midhighdelta_v = np.load(data_twod_midhighdelta+"Variance.npy")
data_twod_midhighdelta_c = np.load(data_twod_midhighdelta+"Cost.npy")

data_twod_highdelta = "data/N_256/delta_13.455/TwoD_rnn/ns100_bs100_10ksteps/"
data_twod_highdelta_e = np.load(data_twod_highdelta+"Energy.npy")
data_twod_highdelta_v = np.load(data_twod_highdelta+"Variance.npy")
data_twod_highdelta_c = np.load(data_twod_highdelta+"Cost.npy")

# %%
fig = plt.figure(1,figsize=(8,5), dpi=120, facecolor='w', edgecolor='k')
plt.plot(np.arange(len(data_twod_lowdelta_e)),data_twod_lowdelta_e,label='delta = -1.545')
plt.plot(np.arange(len(data_twod_midlowdelta_e)),data_twod_midlowdelta_e,label='delta = 4.455')
plt.plot(np.arange(len(data_twod_midhighdelta_e)),data_twod_midhighdelta_e,label='delta = 4.955')
plt.plot(np.arange(len(data_twod_highdelta_e)),data_twod_highdelta_e,label='delta = 13.455')
plt.legend()
# plt.ylim(-5,0)
plt.title('(TwoD, Data) Energy Convergence',fontsize=25)
plt.ylabel('$\\langle H \\rangle$',fontsize=20)
plt.xlabel('training steps',fontsize=20)
plt.show()

# %% [markdown]
# trained for 10k steps with lr = 1e-6 (so very small)

# %% [markdown]
# see below for experiments with different learning rates

# %%
fig = plt.figure(1,figsize=(8,5), dpi=120, facecolor='w', edgecolor='k')
plt.plot(np.arange(len(data_twod_lowdelta_v)),data_twod_lowdelta_v,label='delta = -1.545')
plt.plot(np.arange(len(data_twod_midlowdelta_v)),data_twod_midlowdelta_v,label='delta = 4.455')
plt.plot(np.arange(len(data_twod_midhighdelta_v)),data_twod_midhighdelta_v,label='delta = 4.955')
plt.plot(np.arange(len(data_twod_highdelta_v)),data_twod_highdelta_v,label='delta = 13.455')
plt.legend()
plt.ylim(-0.1,15)
plt.title('(TwoD, Data) Variance Convergence',fontsize=25)
plt.ylabel('Var($\\langle H \\rangle$)',fontsize=20)
plt.xlabel('training steps',fontsize=20)
plt.show()

# %% [markdown]
# ### different learning rates for twod + data training (each delta)

# %%
lr6_lowdelta = "data/N_256/delta_-1.545/TwoD_rnn/ns100_bs100_10ksteps/"
lr6_lowdelta_e = np.load(lr6_lowdelta+"Energy.npy")
lr6_lowdelta_v = np.load(lr6_lowdelta+"Variance.npy")
lr6_lowdelta_c = np.load(lr6_lowdelta+"Cost.npy")

lr6_midlowdelta = "data/N_256/delta_4.455/TwoD_rnn/ns100_bs100_10ksteps/"
lr6_midlowdelta_e = np.load(lr6_midlowdelta+"Energy.npy")
lr6_midlowdelta_v = np.load(lr6_midlowdelta+"Variance.npy")
lr6_midlowdelta_c = np.load(lr6_midlowdelta+"Cost.npy")

lr6_midhighdelta = "data/N_256/delta_4.955/TwoD_rnn/ns100_bs100_10ksteps/"
lr6_midhighdelta_e = np.load(lr6_midhighdelta+"Energy.npy")
lr6_midhighdelta_v = np.load(lr6_midhighdelta+"Variance.npy")
lr6_midhighdelta_c = np.load(lr6_midhighdelta+"Cost.npy")

lr6_highdelta = "data/N_256/delta_13.455/TwoD_rnn/ns100_bs100_10ksteps/"
lr6_highdelta_e = np.load(lr6_highdelta+"Energy.npy")
lr6_highdelta_v = np.load(lr6_highdelta+"Variance.npy")
lr6_highdelta_c = np.load(lr6_highdelta+"Cost.npy")

#--- 

lr4_lowdelta = "data/N_256/delta_-1.545/TwoD_rnn/ns100_bs100_lr4/"
lr4_lowdelta_e = np.load(lr4_lowdelta+"Energy.npy")
lr4_lowdelta_v = np.load(lr4_lowdelta+"Variance.npy")
lr4_lowdelta_c = np.load(lr4_lowdelta+"Cost.npy")

lr4_midlowdelta = "data/N_256/delta_4.455/TwoD_rnn/ns100_bs100_lr4/"
lr4_midlowdelta_e = np.load(lr4_midlowdelta+"Energy.npy")
lr4_midlowdelta_v = np.load(lr4_midlowdelta+"Variance.npy")
lr4_midlowdelta_c = np.load(lr4_midlowdelta+"Cost.npy")

lr4_midhighdelta = "data/N_256/delta_4.955/TwoD_rnn/ns100_bs100_lr4/"
lr4_midhighdelta_e = np.load(lr4_midhighdelta+"Energy.npy")
lr4_midhighdelta_v = np.load(lr4_midhighdelta+"Variance.npy")
lr4_midhighdelta_c = np.load(lr4_midhighdelta+"Cost.npy")

lr4_highdelta = "data/N_256/delta_13.455/TwoD_rnn/ns100_bs100_lr4/"
lr4_highdelta_e = np.load(lr4_highdelta+"Energy.npy")
lr4_highdelta_v = np.load(lr4_highdelta+"Variance.npy")
lr4_highdelta_c = np.load(lr4_highdelta+"Cost.npy")

#--- 

lr5_lowdelta = "data/N_256/delta_-1.545/TwoD_rnn/ns100_bs100_lr5/"
lr5_lowdelta_e = np.load(lr5_lowdelta+"Energy.npy")
lr5_lowdelta_v = np.load(lr5_lowdelta+"Variance.npy")
lr5_lowdelta_c = np.load(lr5_lowdelta+"Cost.npy")

lr5_midlowdelta = "data/N_256/delta_4.455/TwoD_rnn/ns100_bs100_lr5/"
lr5_midlowdelta_e = np.load(lr5_midlowdelta+"Energy.npy")
lr5_midlowdelta_v = np.load(lr5_midlowdelta+"Variance.npy")
lr5_midlowdelta_c = np.load(lr5_midlowdelta+"Cost.npy")

lr5_midhighdelta = "data/N_256/delta_4.955/TwoD_rnn/ns100_bs100_lr5/"
lr5_midhighdelta_e = np.load(lr5_midhighdelta+"Energy.npy")
lr5_midhighdelta_v = np.load(lr5_midhighdelta+"Variance.npy")
lr5_midhighdelta_c = np.load(lr5_midhighdelta+"Cost.npy")

lr5_highdelta = "data/N_256/delta_13.455/TwoD_rnn/ns100_bs100_lr5/"
lr5_highdelta_e = np.load(lr5_highdelta+"Energy.npy")
lr5_highdelta_v = np.load(lr5_highdelta+"Variance.npy")
lr5_highdelta_c = np.load(lr5_highdelta+"Cost.npy")

#--- 

lr3_lowdelta = "data/N_256/delta_-1.545/TwoD_rnn/ns100_bs100_largerlr/"
lr3_lowdelta_e = np.load(lr3_lowdelta+"Energy.npy")
lr3_lowdelta_v = np.load(lr3_lowdelta+"Variance.npy")
lr3_lowdelta_c = np.load(lr3_lowdelta+"Cost.npy")

lr3_midlowdelta = "data/N_256/delta_4.455/TwoD_rnn/ns100_bs100_largerlr/"
lr3_midlowdelta_e = np.load(lr3_midlowdelta+"Energy.npy")
lr3_midlowdelta_v = np.load(lr3_midlowdelta+"Variance.npy")
lr3_midlowdelta_c = np.load(lr3_midlowdelta+"Cost.npy")

lr3_midhighdelta = "data/N_256/delta_4.955/TwoD_rnn/ns100_bs100_largerlr/"
lr3_midhighdelta_e = np.load(lr3_midhighdelta+"Energy.npy")
lr3_midhighdelta_v = np.load(lr3_midhighdelta+"Variance.npy")
lr3_midhighdelta_c = np.load(lr3_midhighdelta+"Cost.npy")

lr3_highdelta = "data/N_256/delta_13.455/TwoD_rnn/ns100_bs100_largerlr/"
lr3_highdelta_e = np.load(lr3_highdelta+"Energy.npy")
lr3_highdelta_v = np.load(lr3_highdelta+"Variance.npy")
lr3_highdelta_c = np.load(lr3_highdelta+"Cost.npy")

# %% [markdown]
# fig = plt.figure(1,figsize=(8,5), dpi=120, facecolor='w', edgecolor='k')
# plt.plot(np.arange(len(lr6_lowdelta_e)),lr6_lowdelta_e,label='1e-6')
# plt.plot(np.arange(len(lr5_lowdelta_e)),lr5_lowdelta_e,label='1e-5')
# plt.plot(np.arange(len(lr4_lowdelta_e)),lr4_lowdelta_e,label='1e-4')
# plt.plot(np.arange(len(lr3_lowdelta_e)),lr3_lowdelta_e,label='1e-3')
# plt.legend()
# plt.ylim(-1.1,0)
# plt.title('TwoD, data, delta = -1.545 Energy Convergence\n',fontsize=25)
# plt.ylabel('$\\langle H \\rangle$',fontsize=20)
# plt.xlabel('training steps',fontsize=20)
# plt.show()

# %% [markdown]
# fig = plt.figure(1,figsize=(8,5), dpi=120, facecolor='w', edgecolor='k')
# plt.plot(np.arange(len(lr6_midlowdelta_e)),lr6_midlowdelta_e,label='1e-6')
# plt.plot(np.arange(len(lr5_midlowdelta_e)),lr5_midlowdelta_e,label='1e-5')
# plt.plot(np.arange(len(lr4_midlowdelta_e)),lr4_midlowdelta_e,label='1e-4')
# plt.plot(np.arange(len(lr3_midlowdelta_e)),lr3_midlowdelta_e,label='1e-3')
# plt.legend()
# plt.ylim(-2.5,0)
# plt.title('TwoD, data, delta = 4.455 Energy Convergence\n',fontsize=25)
# plt.ylabel('$\\langle H \\rangle$',fontsize=20)
# plt.xlabel('training steps',fontsize=20)
# plt.show()

# %% [markdown]
# fig = plt.figure(1,figsize=(8,5), dpi=120, facecolor='w', edgecolor='k')
# plt.plot(np.arange(len(lr6_midhighdelta_e)),lr6_midhighdelta_e,label='1e-6')
# plt.plot(np.arange(len(lr5_midhighdelta_e)),lr5_midhighdelta_e,label='1e-5')
# plt.plot(np.arange(len(lr4_midhighdelta_e)),lr4_midhighdelta_e,label='1e-4')
# plt.plot(np.arange(len(lr3_midhighdelta_e)),lr3_midhighdelta_e,label='1e-3')
# plt.legend()
# plt.ylim(-2.5,0)
# plt.title('TwoD, data, delta = 4.955 Energy Convergence\n',fontsize=25)
# plt.ylabel('$\\langle H \\rangle$',fontsize=20)
# plt.xlabel('training steps',fontsize=20)
# plt.show()

# %% [markdown]
# fig = plt.figure(1,figsize=(8,5), dpi=120, facecolor='w', edgecolor='k')
# plt.plot(np.arange(len(lr6_highdelta_e)),lr6_highdelta_e,label='1e-6')
# plt.plot(np.arange(len(lr5_highdelta_e)),lr5_highdelta_e,label='1e-5')
# plt.plot(np.arange(len(lr4_highdelta_e)),lr4_highdelta_e,label='1e-4')
# plt.plot(np.arange(len(lr3_highdelta_e)),lr3_highdelta_e,label='1e-3')
# plt.legend()
# plt.ylim(-6,-3)
# plt.title('TwoD, data, delta = 13.455 Energy Convergence\n',fontsize=25)
# plt.ylabel('$\\langle H \\rangle$',fontsize=20)
# plt.xlabel('training steps',fontsize=20)
# plt.show()

# %% [markdown]
# # Comparing both models and both training methods for each delta

# %% [markdown]
# # delta = -1.545

# %%
fig = plt.figure(1,figsize=(8,5), dpi=120, facecolor='w', edgecolor='k')
blues = plt.get_cmap('Blues')
reds = plt.get_cmap('Reds')
plt.plot(np.arange(len(VMC_oned_lowdelta_e)),VMC_oned_lowdelta_e,color=blues(0.8),label='1D, VMC')
plt.plot(np.arange(len(data_oned_lowdelta_e)),data_oned_lowdelta_e,color=blues(0.3),label='1D, data')
plt.plot(np.arange(len(VMC_twod_lowdelta_e)),VMC_twod_lowdelta_e,color=reds(0.8),label='2D, VMC')
plt.plot(np.arange(len(lr3_lowdelta_e)),lr3_lowdelta_e,color= reds(0.3),label='2D, data, lr = 1e-3')
plt.plot(np.arange(len(lr4_lowdelta_e)),lr4_lowdelta_e,color= reds(0.4),label='2D, data, lr = 1e-4')
plt.plot(np.arange(len(lr5_lowdelta_e)),lr5_lowdelta_e,color= reds(0.5),label='2D, data, lr = 1e-5')
plt.plot(np.arange(len(lr6_lowdelta_e)),lr6_lowdelta_e,color= reds(0.6),label='2D, data, lr = 1e-6')
plt.legend()
plt.ylim(-1.1,0)
plt.xlim(0,1000)
plt.title('delta = -1.545 Energy Convergence',fontsize=25)
plt.ylabel('$\\langle H \\rangle$',fontsize=20)
plt.xlabel('training steps',fontsize=20)
plt.show()

# %% [markdown]
# fig = plt.figure(1,figsize=(8,5), dpi=120, facecolor='w', edgecolor='k')
# plt.plot(np.arange(len(VMC_oned_lowdelta_v)),VMC_oned_lowdelta_v,label='1D, VMC')
# plt.plot(np.arange(len(data_oned_lowdelta_v)),data_oned_lowdelta_v,label='1D, data')
# plt.plot(np.arange(len(VMC_twod_lowdelta_v)),VMC_twod_lowdelta_v,label='2D, VMC')
# plt.plot(np.arange(len(data_twod_lowdelta_v)),data_twod_lowdelta_v,label='2D, data')
# plt.legend()
# plt.ylim(-0.1,5)
# plt.title('delta = -1.545 Variance Convergence',fontsize=25)
# plt.ylabel('$\\langle H \\rangle$',fontsize=20)
# plt.xlabel('training steps',fontsize=20)
# plt.show()

# %% [markdown]
# # delta = 4.455

# %%
fig = plt.figure(1,figsize=(8,5), dpi=120, facecolor='w', edgecolor='k')
blues = plt.get_cmap('Blues')
reds = plt.get_cmap('Reds')
plt.plot(np.arange(len(VMC_oned_midlowdelta_e)),VMC_oned_midlowdelta_e,color=blues(0.8),label='1D, VMC')
plt.plot(np.arange(len(data_oned_midlowdelta_e)),data_oned_midlowdelta_e,color=blues(0.3),label='1D, data')
plt.plot(np.arange(len(VMC_twod_midlowdelta_e)),VMC_twod_midlowdelta_e,color=reds(0.8),label='2D, VMC')
plt.plot(np.arange(len(lr3_midlowdelta_e)),lr3_midlowdelta_e,color= reds(0.3),label='2D, data, lr = 1e-3')
plt.plot(np.arange(len(lr4_midlowdelta_e)),lr4_midlowdelta_e,color= reds(0.4),label='2D, data, lr = 1e-4')
plt.plot(np.arange(len(lr5_midlowdelta_e)),lr5_midlowdelta_e,color= reds(0.5),label='2D, data, lr = 1e-5')
plt.plot(np.arange(len(lr6_midlowdelta_e)),lr6_midlowdelta_e,color= reds(0.6),label='2D, data, lr = 1e-6')
plt.legend()
plt.ylim(-2.3,0)
# plt.xlim(0,2000)
plt.title('delta = 4.455 Energy Convergence',fontsize=25)
plt.ylabel('$\\langle H \\rangle$',fontsize=20)
plt.xlabel('training steps',fontsize=20)
plt.show()

# %% [markdown]
# fig = plt.figure(1,figsize=(8,5), dpi=120, facecolor='w', edgecolor='k')
# plt.plot(np.arange(len(VMC_oned_midlowdelta_v)),VMC_oned_midlowdelta_v,label='1D, VMC')
# plt.plot(np.arange(len(data_oned_midlowdelta_v)),data_oned_midlowdelta_v,label='1D, data')
# plt.plot(np.arange(len(VMC_twod_midlowdelta_v)),VMC_twod_midlowdelta_v,label='2D, VMC')
# plt.plot(np.arange(len(data_twod_midlowdelta_v)),data_twod_midlowdelta_v,label='2D, data')
# plt.legend()
# plt.ylim(-0.1,5)
# plt.title('delta = 4.455 Variance Convergence',fontsize=25)
# plt.ylabel('$\\langle H \\rangle$',fontsize=20)
# plt.xlabel('training steps',fontsize=20)
# plt.show()

# %% [markdown]
# It's amazing how much better the 2D RNN performs!!

# %% [markdown]
# # delta = 4.955

# %%
fig = plt.figure(1,figsize=(8,5), dpi=120, facecolor='w', edgecolor='k')
blues = plt.get_cmap('Blues')
reds = plt.get_cmap('Reds')
plt.plot(np.arange(len(VMC_oned_midhighdelta_e)),VMC_oned_midhighdelta_e,color=blues(0.8),label='1D, VMC')
plt.plot(np.arange(len(data_oned_midhighdelta_e)),data_oned_midhighdelta_e,color=blues(0.3),label='1D, data')
plt.plot(np.arange(len(VMC_twod_midhighdelta_e)),VMC_twod_midhighdelta_e,color=reds(0.8),label='2D, VMC')
plt.plot(np.arange(len(lr3_midhighdelta_e)),lr3_midhighdelta_e,color= reds(0.3),label='2D, data, lr = 1e-3')
plt.plot(np.arange(len(lr4_midhighdelta_e)),lr4_midhighdelta_e,color= reds(0.4),label='2D, data, lr = 1e-4')
plt.plot(np.arange(len(lr5_midhighdelta_e)),lr5_midhighdelta_e,color= reds(0.5),label='2D, data, lr = 1e-5')
plt.plot(np.arange(len(lr6_midhighdelta_e)),lr6_midhighdelta_e,color= reds(0.6),label='2D, data, lr = 1e-6')
plt.legend()
plt.ylim(-2.4,0)
plt.xlim(0,1000)
plt.title('delta = 4.955 Energy Convergence',fontsize=25)
plt.ylabel('$\\langle H \\rangle$',fontsize=20)
plt.xlabel('training steps',fontsize=20)
plt.show()

# %% [markdown]
# fig = plt.figure(1,figsize=(8,5), dpi=120, facecolor='w', edgecolor='k')
# plt.plot(np.arange(len(VMC_oned_midhighdelta_v)),VMC_oned_midhighdelta_v,label='1D, VMC')
# plt.plot(np.arange(len(data_oned_midhighdelta_v)),data_oned_midhighdelta_v,label='1D, data')
# plt.plot(np.arange(len(VMC_twod_midhighdelta_v)),VMC_twod_midhighdelta_v,label='2D, VMC')
# plt.plot(np.arange(len(data_twod_midhighdelta_v)),data_twod_midhighdelta_v,label='2D, data')
# plt.legend()
# plt.ylim(-0.1,5)
# plt.title('delta = 4.955 Variance Convergence',fontsize=25)
# plt.ylabel('$\\langle H \\rangle$',fontsize=20)
# plt.xlabel('training steps',fontsize=20)
# plt.show()

# %% [markdown]
# # delta = 13.455

# %%
fig = plt.figure(1,figsize=(8,5), dpi=120, facecolor='w', edgecolor='k')
blues = plt.get_cmap('Blues')
reds = plt.get_cmap('Reds')
plt.plot(np.arange(len(VMC_oned_highdelta_e)),VMC_oned_highdelta_e,color=blues(0.8),label='1D, VMC')
plt.plot(np.arange(len(data_oned_highdelta_e)),data_oned_highdelta_e,color=blues(0.3),label='1D, data')
plt.plot(np.arange(len(VMC_twod_highdelta_e)),VMC_twod_highdelta_e,color=reds(0.8),label='2D, VMC')
plt.plot(np.arange(len(lr3_highdelta_e)),lr3_highdelta_e,color= reds(0.3),label='2D, data, lr = 1e-3')
plt.plot(np.arange(len(lr4_highdelta_e)),lr4_highdelta_e,color= reds(0.4),label='2D, data, lr = 1e-4')
plt.plot(np.arange(len(lr5_highdelta_e)),lr5_highdelta_e,color= reds(0.5),label='2D, data, lr = 1e-5')
plt.plot(np.arange(len(lr6_highdelta_e)),lr6_highdelta_e,color= reds(0.6),label='2D, data, lr = 1e-6')
plt.legend()
plt.ylim(-6,-3)
plt.xlim(0,1000)
plt.title('delta = 13.455 Energy Convergence',fontsize=25)
plt.ylabel('$\\langle H \\rangle$',fontsize=20)
plt.xlabel('training steps',fontsize=20)
plt.show()

# %% [markdown]
# fig = plt.figure(1,figsize=(8,5), dpi=120, facecolor='w', edgecolor='k')
# plt.plot(np.arange(len(VMC_oned_highdelta_v)),VMC_oned_highdelta_v,label='1D, VMC')
# plt.plot(np.arange(len(data_oned_highdelta_v)),data_oned_highdelta_v,label='1D, data')
# plt.plot(np.arange(len(VMC_twod_highdelta_v)),VMC_twod_highdelta_v,label='2D, VMC')
# plt.plot(np.arange(len(data_twod_highdelta_v)),data_twod_highdelta_v,label='2D, data')
# plt.legend()
# plt.ylim(-0.1,5)
# plt.title('delta = 13.455 Variance Convergence',fontsize=25)
# plt.ylabel('$\\langle H \\rangle$',fontsize=20)
# plt.xlabel('training steps',fontsize=20)
# plt.show()
