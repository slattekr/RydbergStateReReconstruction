# %%
import numpy as np
import matplotlib.pylab as plt

# %% [markdown]
# # One D RNNs

# %% [markdown]
# Not working at all :)

# %% [markdown]
# # Two D RNNs

# %% [markdown]
# ### Train with data only

# %%
data_exp1_path = "data/N_256/delta_-1.545/TwoD_rnn/TwoD_data_lowdelta/"
data_exp1_energy = np.load(data_exp1_path+"Energy.npy")
data_exp1_variance = np.load(data_exp1_path+"Variance.npy")
data_exp1_cost = np.load(data_exp1_path+"Cost.npy")

# %%
plt.plot(np.arange(len(data_exp1_energy)),data_exp1_energy)
plt.ylim(-2,0)
plt.title("Energy")
plt.xlabel("step")
plt.show()

# %%
plt.plot(np.arange(len(data_exp1_variance)),data_exp1_variance)
plt.ylim(15,40)
plt.title("Variance")
plt.xlabel("step")
plt.show()

# %%
plt.plot(np.arange(len(data_exp1_cost)),data_exp1_cost)
plt.title("Cost")
plt.xlabel("step")
plt.show()

# %%
data_exp2_path = "data/N_256/delta_-1.545/TwoD_rnn/TwoD_data_lowdelta_longer/"
data_exp2_energy = np.load(data_exp2_path+"Energy.npy")
data_exp2_variance = np.load(data_exp2_path+"Variance.npy")
data_exp2_cost = np.load(data_exp2_path+"Cost.npy")

# %%
plt.plot(np.arange(len(data_exp2_energy)),data_exp2_energy)
plt.ylim(-2,0)
plt.title("Energy")
plt.xlabel("step")
plt.show()

# %%
plt.plot(np.arange(len(data_exp2_variance)),data_exp2_variance)
plt.ylim(15,40)
plt.title("Variance")
plt.xlabel("step")
plt.show()

# %%
plt.plot(np.arange(len(data_exp2_cost)),data_exp2_cost)
plt.title("Cost")
plt.xlabel("step")
plt.show()

# %% [markdown]
# ### Train with VMC only

# %%
VMC_exp1_path = "data/N_256/delta_-1.545/TwoD_rnn/TwoD_VMC_lowdelta/"
VMC_exp1_energy = np.load(VMC_exp1_path+"Energy.npy")
VMC_exp1_variance = np.load(VMC_exp1_path+"Variance.npy")
VMC_exp1_cost = np.load(VMC_exp1_path+"Cost.npy")

# %%
plt.plot(np.arange(len(VMC_exp1_energy)),VMC_exp1_energy)
plt.ylim(-1.2,0)
plt.title("Energy")
plt.xlabel("step")
plt.show()

# %%
plt.plot(np.arange(len(VMC_exp1_variance)),VMC_exp1_variance)
plt.ylim(-0.01,5)
plt.title("Variance")
plt.xlabel("step")
plt.show()

# %%
plt.plot(np.arange(len(VMC_exp1_cost)),VMC_exp1_cost)
plt.ylim(-10,10)
plt.title("Cost")
plt.xlabel("step")
plt.show()

# %%
VMC_exp2_path = "data/N_256/delta_-1.545/TwoD_rnn/TwoD_VMC_lowdelta_longer/"
VMC_exp2_energy = np.load(VMC_exp2_path+"Energy.npy")
VMC_exp2_variance = np.load(VMC_exp2_path+"Variance.npy")
VMC_exp2_cost = np.load(VMC_exp2_path+"Cost.npy")

# %%
plt.plot(np.arange(len(VMC_exp2_energy)),VMC_exp2_energy)
plt.ylim(-1,0)
plt.title("Energy")
plt.xlabel("step")
plt.show()

# %%
plt.plot(np.arange(len(VMC_exp2_variance)),VMC_exp2_variance)
plt.ylim(-0.01,1)
plt.title("Variance")
plt.xlabel("step")
plt.show()

# %%
print(VMC_exp2_energy[-1])
print(VMC_exp2_variance[-1])
# Out:
# -0.9943845272064209
# 0.030354849994182587

# %%
plt.plot(np.arange(len(VMC_exp2_cost)),VMC_exp2_cost)
plt.ylim(-10,10)
plt.title("Cost")
plt.xlabel("step")
plt.show()
