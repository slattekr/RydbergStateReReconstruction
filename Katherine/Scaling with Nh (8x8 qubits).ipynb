# %% [markdown]
# Training on an 8x8 grid lattice

# %%
# %load_ext autoreload
# %autoreload
import numpy as np
import tensorflow as tf

# %% [markdown]
# In this demo file, I calculate the learning criterion for different numbers of hidden units. The minimum learning criterion for the different numbers of hidden units is stored in the vector "lcminvec."

# %%
from dset_helpers import load_essiqurke_data, create_tf_essiqurke_dataset
from train_data_2 import Train_w_Data

# %%
lcminvec = []

# %%
from train_data_2 import Train_w_Data

energy = []
variance = []
cost = []
learning_criterion_vec = []

def main():
    config = {
        'name': 'test', # Can name each experiment so that results are saved in a unique directory
        'seed': 1234,
        
        #System Parameters
        'L': 8,  # number of atoms
        'V': 7, 
        'Omega': 1,
        'delta': 1.00, # this varies
        
        #RNN Parameters
        'nh': 28,  # number of hidden units
        'lr': 1e-3,  # learning rate
        'trunc': 100, # related to interactions - keep at 100 for all-to-all interactions
        
        #Training Parameters
        'Data_epochs':1000, 
        'ns': 1000,
        'batch_size': 100, # divide dset into batches of this size
        'data_step': 100, # takes care of autocorrelations in QMC data
        
        'Print':True, 
        'Write_Data': False, # save results (helpful when going to larger systems)
        'Plot': True # plot training curves
        }
    
    return Train_w_Data(config,energy,variance,cost, learning_criterion_vec) # make sure this is the same function that is imported above


if __name__ == "__main__":
    model,e,v,c, lc, lcmin28 = main() # can also access e, v, c and make new plots after training is complete (ie to zoom in)
lcminvec.append(lcmin28)
# Out:
# gru_1/gru_cell_1/kernel:0 (168,)
# gru_1/gru_cell_1/recurrent_kernel:0 (2352,)
# gru_1/gru_cell_1/bias:0 (168,)
# dense_1/kernel:0 (56,)
# dense_1/bias:0 (2,)
# The sum of params is 2746
# The experimental parameters are: V = 7, delta = 1.0, Omega = 1.
# The system is a one-D chain of 8 Rydberg Atoms
# Tracing!
# Tracing!
# Final Energy -0.5065769188933902 (Exact Energy is None)
# The lowest energy achieved by the model was -0.5819802284240723.
# Final Variance after 1000 epochs is 1.1488148901197646

# %%
print(lcminvec)
# Out:
# [30.79073704788391, 28.93776340780233, 30.79073704788391, 30.79073704788391]

# %%
energy = []
variance = []
cost = []
learning_criterion_vec = []

def main():
    config = {
        'name': 'test', # Can name each experiment so that results are saved in a unique directory
        'seed': 1234,
        
        #System Parameters
        'L': 8,  # number of atoms
        'V': 7, 
        'Omega': 1,
        'delta': 1.00, # this varies
        
        #RNN Parameters
        'nh': 30,  # number of hidden units
        'lr': 1e-3,  # learning rate
        'trunc': 100, # related to interactions - keep at 100 for all-to-all interactions
        
        #Training Parameters
        'Data_epochs':1000, 
        'ns': 1000,
        'batch_size': 100, # divide dset into batches of this size
        'data_step': 100, # takes care of autocorrelations in QMC data
        
        'Print':True, 
        'Write_Data': False, # save results (helpful when going to larger systems)
        'Plot': True # plot training curves
        }
    
    return Train_w_Data(config,energy,variance,cost, learning_criterion_vec) # make sure this is the same function that is imported above


if __name__ == "__main__":
    model,e,v,c, lc, lcmin30 = main() # can also access e, v, c and make new plots after training is complete (ie to zoom in)
lcminvec.append(lcmin30)
# Out:
# gru_13/gru_cell_13/kernel:0 (180,)
# gru_13/gru_cell_13/recurrent_kernel:0 (2700,)
# gru_13/gru_cell_13/bias:0 (180,)
# dense_13/kernel:0 (60,)
# dense_13/bias:0 (2,)
# The sum of params is 3122
# The experimental parameters are: V = 7, delta = 1.0, Omega = 1.
# The system is a one-D chain of 8 Rydberg Atoms
# Tracing!
# Tracing!
# Final Energy -0.5064210096995035 (Exact Energy is None)
# The lowest energy achieved by the model was -0.5895259976387024.
# Final Variance after 1000 epochs is 2.706334047847324

# %%
energy = []
variance = []
cost = []
learning_criterion_vec = []

def main():
    config = {
        'name': 'test', # Can name each experiment so that results are saved in a unique directory
        'seed': 1234,
        
        #System Parameters
        'L': 8,  # number of atoms
        'V': 7, 
        'Omega': 1,
        'delta': 1.00, # this varies
        
        #RNN Parameters
        'nh': 32,  # number of hidden units
        'lr': 1e-3,  # learning rate
        'trunc': 100, # related to interactions - keep at 100 for all-to-all interactions
        
        #Training Parameters
        'Data_epochs':1000, 
        'ns': 1000,
        'batch_size': 100, # divide dset into batches of this size
        'data_step': 100, # takes care of autocorrelations in QMC data
        
        'Print':True, 
        'Write_Data': False, # save results (helpful when going to larger systems)
        'Plot': True # plot training curves
        }
    
    return Train_w_Data(config,energy,variance,cost, learning_criterion_vec) # make sure this is the same function that is imported above


if __name__ == "__main__":
    model,e,v,c, lc, lcmin32 = main() # can also access e, v, c and make new plots after training is complete (ie to zoom in)
lcminvec.append(lcmin32)
# Out:
# gru_14/gru_cell_14/kernel:0 (192,)
# gru_14/gru_cell_14/recurrent_kernel:0 (3072,)
# gru_14/gru_cell_14/bias:0 (192,)
# dense_14/kernel:0 (64,)
# dense_14/bias:0 (2,)
# The sum of params is 3522
# The experimental parameters are: V = 7, delta = 1.0, Omega = 1.
# The system is a one-D chain of 8 Rydberg Atoms
# Tracing!
# Tracing!
# Final Energy -0.499612698952357 (Exact Energy is None)
# The lowest energy achieved by the model was -0.5816700458526611.
# Final Variance after 1000 epochs is 1.3788969251844618

# %%
energy = []
variance = []
cost = []
learning_criterion_vec = []

def main():
    config = {
        'name': 'test', # Can name each experiment so that results are saved in a unique directory
        'seed': 1234,
        
        #System Parameters
        'L': 8,  # number of atoms
        'V': 7, 
        'Omega': 1,
        'delta': 1.00, # this varies
        
        #RNN Parameters
        'nh': 34,  # number of hidden units
        'lr': 1e-3,  # learning rate
        'trunc': 100, # related to interactions - keep at 100 for all-to-all interactions
        
        #Training Parameters
        'Data_epochs':1000, 
        'ns': 1000,
        'batch_size': 100, # divide dset into batches of this size
        'data_step': 100, # takes care of autocorrelations in QMC data
        
        'Print':True, 
        'Write_Data': False, # save results (helpful when going to larger systems)
        'Plot': True # plot training curves
        }
    
    return Train_w_Data(config,energy,variance,cost, learning_criterion_vec) # make sure this is the same function that is imported above


if __name__ == "__main__":
    model,e,v,c, lc, lcmin34 = main() # can also access e, v, c and make new plots after training is complete (ie to zoom in)
lcminvec.append(lcmin34)
# Out:
# gru_15/gru_cell_15/kernel:0 (204,)
# gru_15/gru_cell_15/recurrent_kernel:0 (3468,)
# gru_15/gru_cell_15/bias:0 (204,)
# dense_15/kernel:0 (68,)
# dense_15/bias:0 (2,)
# The sum of params is 3946
# The experimental parameters are: V = 7, delta = 1.0, Omega = 1.
# The system is a one-D chain of 8 Rydberg Atoms
# Tracing!
# Tracing!
# Final Energy -0.48887913094626534 (Exact Energy is None)
# The lowest energy achieved by the model was -0.582014799118042.
# Final Variance after 1000 epochs is 1.182976974381341

# %%
energy = []
variance = []
cost = []
learning_criterion_vec = []

def main():
    config = {
        'name': 'test', # Can name each experiment so that results are saved in a unique directory
        'seed': 1234,
        
        #System Parameters
        'L': 8,  # number of atoms
        'V': 7, 
        'Omega': 1,
        'delta': 1.00, # this varies
        
        #RNN Parameters
        'nh': 36,  # number of hidden units
        'lr': 1e-3,  # learning rate
        'trunc': 100, # related to interactions - keep at 100 for all-to-all interactions
        
        #Training Parameters
        'Data_epochs':1000, 
        'ns': 1000,
        'batch_size': 100, # divide dset into batches of this size
        'data_step': 100, # takes care of autocorrelations in QMC data
        
        'Print':True, 
        'Write_Data': False, # save results (helpful when going to larger systems)
        'Plot': True # plot training curves
        }
    
    return Train_w_Data(config,energy,variance,cost, learning_criterion_vec) # make sure this is the same function that is imported above


if __name__ == "__main__":
    model,e,v,c, lc, lcmin36 = main() # can also access e, v, c and make new plots after training is complete (ie to zoom in)
lcminvec.append(lcmin36)
# Out:
# gru_16/gru_cell_16/kernel:0 (216,)
# gru_16/gru_cell_16/recurrent_kernel:0 (3888,)
# gru_16/gru_cell_16/bias:0 (216,)
# dense_16/kernel:0 (72,)
# dense_16/bias:0 (2,)
# The sum of params is 4394
# The experimental parameters are: V = 7, delta = 1.0, Omega = 1.
# The system is a one-D chain of 8 Rydberg Atoms
# Tracing!
# Tracing!
# Final Energy -0.4836273789405823 (Exact Energy is None)
# The lowest energy achieved by the model was -0.5821203589439392.
# Final Variance after 1000 epochs is 1.1736310323079426

# %%
energy = []
variance = []
cost = []
learning_criterion_vec = []

def main():
    config = {
        'name': 'test', # Can name each experiment so that results are saved in a unique directory
        'seed': 1234,
        
        #System Parameters
        'L': 8,  # number of atoms
        'V': 7, 
        'Omega': 1,
        'delta': 1.00, # this varies
        
        #RNN Parameters
        'nh': 38,  # number of hidden units
        'lr': 1e-3,  # learning rate
        'trunc': 100, # related to interactions - keep at 100 for all-to-all interactions
        
        #Training Parameters
        'Data_epochs':1000, 
        'ns': 1000,
        'batch_size': 100, # divide dset into batches of this size
        'data_step': 100, # takes care of autocorrelations in QMC data
        
        'Print':True, 
        'Write_Data': False, # save results (helpful when going to larger systems)
        'Plot': True # plot training curves
        }
    
    return Train_w_Data(config,energy,variance,cost, learning_criterion_vec) # make sure this is the same function that is imported above


if __name__ == "__main__":
    model,e,v,c, lc, lcmin38 = main() # can also access e, v, c and make new plots after training is complete (ie to zoom in)
lcminvec.append(lcmin38)
# Out:
# gru_17/gru_cell_17/kernel:0 (228,)
# gru_17/gru_cell_17/recurrent_kernel:0 (4332,)
# gru_17/gru_cell_17/bias:0 (228,)
# dense_17/kernel:0 (76,)
# dense_17/bias:0 (2,)
# The sum of params is 4866
# The experimental parameters are: V = 7, delta = 1.0, Omega = 1.
# The system is a one-D chain of 8 Rydberg Atoms
# Tracing!
# Tracing!
# Final Energy -0.48396409551302594 (Exact Energy is None)
# The lowest energy achieved by the model was -0.5845568776130676.
# Final Variance after 1000 epochs is 1.185830083158281

# %%
print(lcminvec)
# Out:
# [30.79073704788391, 28.93776340780233, 30.79073704788391, 30.79073704788391, 28.93776340780233, 29.177247129560904, 30.31381417118601, 29.48369859244215, 29.465655514606237]

# %%
energy = []
variance = []
cost = []
learning_criterion_vec = []

def main():
    config = {
        'name': 'test', # Can name each experiment so that results are saved in a unique directory
        'seed': 1234,
        
        #System Parameters
        'L': 8,  # number of atoms
        'V': 7, 
        'Omega': 1,
        'delta': 1.00, # this varies
        
        #RNN Parameters
        'nh': 50,  # number of hidden units
        'lr': 1e-3,  # learning rate
        'trunc': 100, # related to interactions - keep at 100 for all-to-all interactions
        
        #Training Parameters
        'Data_epochs':1000, 
        'ns': 1000,
        'batch_size': 100, # divide dset into batches of this size
        'data_step': 100, # takes care of autocorrelations in QMC data
        
        'Print':True, 
        'Write_Data': False, # save results (helpful when going to larger systems)
        'Plot': True # plot training curves
        }
    
    return Train_w_Data(config,energy,variance,cost, learning_criterion_vec) # make sure this is the same function that is imported above


if __name__ == "__main__":
    model,e,v,c, lc, lcmin50 = main() # can also access e, v, c and make new plots after training is complete (ie to zoom in)
lcminvec.append(lcmin50)
# Out:
# gru_18/gru_cell_18/kernel:0 (300,)
# gru_18/gru_cell_18/recurrent_kernel:0 (7500,)
# gru_18/gru_cell_18/bias:0 (300,)
# dense_18/kernel:0 (100,)
# dense_18/bias:0 (2,)
# The sum of params is 8202
# The experimental parameters are: V = 7, delta = 1.0, Omega = 1.
# The system is a one-D chain of 8 Rydberg Atoms
# Tracing!
# Tracing!
# Final Energy -0.4659577939245436 (Exact Energy is None)
# The lowest energy achieved by the model was -0.5792456865310669.
# Final Variance after 1000 epochs is 1.234771404001448

# %%
print(lcmin50)
# Out:
# 28.570956524981337

# %%
energy = []
variance = []
cost = []
learning_criterion_vec = []

def main():
    config = {
        'name': 'test', # Can name each experiment so that results are saved in a unique directory
        'seed': 1234,
        
        #System Parameters
        'L': 8,  # number of atoms
        'V': 7, 
        'Omega': 1,
        'delta': 1.00, # this varies
        
        #RNN Parameters
        'nh': 100,  # number of hidden units
        'lr': 1e-3,  # learning rate
        'trunc': 100, # related to interactions - keep at 100 for all-to-all interactions
        
        #Training Parameters
        'Data_epochs':1000, 
        'ns': 1000,
        'batch_size': 100, # divide dset into batches of this size
        'data_step': 100, # takes care of autocorrelations in QMC data
        
        'Print':True, 
        'Write_Data': False, # save results (helpful when going to larger systems)
        'Plot': True # plot training curves
        }
    
    return Train_w_Data(config,energy,variance,cost, learning_criterion_vec) # make sure this is the same function that is imported above


if __name__ == "__main__":
    model,e,v,c, lc, lcmin100 = main() # can also access e, v, c and make new plots after training is complete (ie to zoom in)
lcminvec.append(lcmin100)
# Out:
# gru_19/gru_cell_19/kernel:0 (600,)
# gru_19/gru_cell_19/recurrent_kernel:0 (30000,)
# gru_19/gru_cell_19/bias:0 (600,)
# dense_19/kernel:0 (200,)
# dense_19/bias:0 (2,)
# The sum of params is 31402
# The experimental parameters are: V = 7, delta = 1.0, Omega = 1.
# The system is a one-D chain of 8 Rydberg Atoms
# Tracing!
# Tracing!
# Final Energy -0.46275533570183647 (Exact Energy is None)
# The lowest energy achieved by the model was -0.5966558456420898.
# Final Variance after 1000 epochs is 1.266992403401269

# %%
print(lcmin100)
# Out:
# 30.330363589936713
